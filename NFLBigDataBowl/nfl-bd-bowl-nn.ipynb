# %%
import os
# os.environ['CUDA_VISIBLE_DEVICES'] = "1"


import numpy as np
import pandas as pd
import sklearn.metrics as mtr
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization
from keras.models import Model
import keras.backend as K
from keras.callbacks import Callback
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import datetime

TRAIN_OFFLINE = False


pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)
# Out:
# Using TensorFlow backend.

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/nfl-big-data-bowl-2020/train.csv
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/sample_submission.csv.encrypted
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/competition.cpython-36m-x86_64-linux-gnu.so
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/test.csv.encrypted
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/__init__.py

# %%
# train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})
if TRAIN_OFFLINE:
    train = pd.read_csv('../input/train.csv', dtype={'WindSpeed': 'object'})
else:
    train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %%
def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"
def preprocess(train):
    ## GameClock
    train['GameClock_sec'] = train['GameClock'].apply(strtoseconds)
    train["GameClock_minute"] = train["GameClock"].apply(lambda x : x.split(":")[0]).astype("object")

    ## Height
    train['PlayerHeight_dense'] = train['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))

    ## Time
    train['TimeHandoff'] = train['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    train['TimeSnap'] = train['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

    train['TimeDelta'] = train.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
    train['PlayerBirthDate'] = train['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

    ## Age
    seconds_in_year = 60*60*24*365.25
    train['PlayerAge'] = train.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
    train["PlayerAge_ob"] = train['PlayerAge'].astype(np.int).astype("object")

    ## WindSpeed
    train['WindSpeed_ob'] = train['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
    train['WindSpeed_dense'] = train['WindSpeed_ob'].apply(strtofloat)

    ## Weather
    train['GameWeather_process'] = train['GameWeather'].str.lower()
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
    train['GameWeather_dense'] = train['GameWeather_process'].apply(map_weather)

    ## Rusher
    train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
    train['IsRusher_ob'] = (train['NflId'] == train['NflIdRusher']).astype("object")
    temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
    train = train.merge(temp, on = "PlayId")
    train["IsRusherTeam"] = train["Team"] == train["RusherTeam"]

    ## dense -> categorical
    train["Quarter_ob"] = train["Quarter"].astype("object")
    train["Down_ob"] = train["Down"].astype("object")
    train["JerseyNumber_ob"] = train["JerseyNumber"].astype("object")
    train["YardLine_ob"] = train["YardLine"].astype("object")
  


    ## Orientation and Dir
    train["Orientation_ob"] = train["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
    train["Dir_ob"] = train["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

    train["Orientation_sin"] = train["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Orientation_cos"] = train["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
    train["Dir_sin"] = train["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Dir_cos"] = train["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))

    ## diff Score
    train["diffScoreBeforePlay"] = train["HomeScoreBeforePlay"] - train["VisitorScoreBeforePlay"]
    train["diffScoreBeforePlay_binary_ob"] = (train["HomeScoreBeforePlay"] > train["VisitorScoreBeforePlay"]).astype("object")

    ## Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)

    ## OffensePersonnel
    temp = train["OffensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(OffensePersonnelSplit(x)))
    temp.columns = ["Offense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## DefensePersonnel
    temp = train["DefensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(DefensePersonnelSplit(x)))
    temp.columns = ["Defense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## sort
#     train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'Team', 'IsRusher']).reset_index(drop = True)
    train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'IsRusherTeam', 'IsRusher']).reset_index(drop = True)
    return train

# %% [markdown]
# ## Functions for anchoring offense moving left from {0,0}

# %%
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense
    
    def rusher_features(df):
        
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Dir', 'S', 'A', 'X', 'Y']]
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS', 'RusherA', 'RusherX', 'RusherY']
        
       
        radian_angle = (90 - rusher['RusherDir']) * np.pi / 180.0
        v_horizontal = np.abs(rusher['RusherS'] * np.cos(radian_angle))
        v_vertical = np.abs(rusher['RusherS'] * np.sin(radian_angle)) 
        
       
        rusher['v_horizontal'] = v_horizontal
        rusher['v_vertical'] = v_vertical
        
        
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS','RusherA','RusherX', 'RusherY','v_horizontal', 'v_vertical']
        
        
        return rusher

    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))
        
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
    
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Quarter','Down','Distance','DefendersInTheBox']].drop_duplicates()

        static_features.fillna(-999,inplace=True)
       

        return static_features


    def combine_features(relative_to_back, defense,rushing, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,rushing,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    rush_feats = rusher_features(df)
    static_feats = static_features(df)
    basetable = combine_features(rel_back, def_feats,rush_feats,static_feats, deploy=deploy)
    
    return basetable

# %%
# %time train_basetable = create_features(train, False)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 5min 11s, sys: 6.18 s, total: 5min 17s
# Wall time: 5min 16s

# %% [markdown]
# # Let's split our data into train/val

# %%
X = train_basetable.copy()
yards = X.Yards

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=12345)

# %%
print(X_train.shape, X_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# (19695, 36) (3476, 36)
# (19695, 199) (3476, 199)

# %% [markdown]
# # Let's build NN

# %%
from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda
from keras.models import Model
import keras.backend as K
import re
from keras.losses import binary_crossentropy
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import codecs

from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from sklearn.metrics import f1_score




class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
def get_model(x_tr,y_tr,x_val,y_val):
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(1024, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    #add lookahead
#     lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
#     lookahead.inject(model) # add into model

    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                                   save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    


    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
    crps = np.round(val_s, 6)

    return model,crps

# %%
from sklearn.model_selection import train_test_split, KFold
import time

losses = []
models = []
crps_csv = []

s_time = time.time()


for k in range(2):
    kfold = KFold(5, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print("-----------")
        tr_x,tr_y = X[tr_inds],y[tr_inds]
        val_x,val_y = X[val_inds],y[val_inds]
        model,crps = get_model(tr_x,tr_y,val_x,val_y)
        models.append(model)
        print("the %d fold crps is %f"%((k_fold+1),crps))
        crps_csv.append(crps)
 
print("mean crps is %f"%np.mean(crps_csv))


def predict(x_te):
    model_num = len(models)
    for k,m in enumerate(models):
        if k==0:
            y_pred = m.predict(x_te,batch_size=1024)
        else:
            y_pred+=m.predict(x_te,batch_size=1024)
            
    y_pred = y_pred / model_num
    
    return y_pred
# Out:
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18536/18536 [==============================] - 3s 168us/step - loss: 5.5808
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08276, saving model to best_model.h5
# Epoch 2/100
# 18536/18536 [==============================] - 2s 102us/step - loss: 5.0959
#
# Epoch 00002: CRPS_score_val improved from 0.08276 to 0.07812, saving model to best_model.h5
# Epoch 3/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 4.6744
#
# Epoch 00003: CRPS_score_val improved from 0.07812 to 0.06442, saving model to best_model.h5
# Epoch 4/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 4.2655
#
# Epoch 00004: CRPS_score_val improved from 0.06442 to 0.04335, saving model to best_model.h5
# Epoch 5/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 3.8904
#
# Epoch 00005: CRPS_score_val improved from 0.04335 to 0.02688, saving model to best_model.h5
# Epoch 6/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 3.5744
#
# Epoch 00006: CRPS_score_val improved from 0.02688 to 0.01882, saving model to best_model.h5
# Epoch 7/100
# 18536/18536 [==============================] - 2s 102us/step - loss: 3.3198
#
# Epoch 00007: CRPS_score_val improved from 0.01882 to 0.01529, saving model to best_model.h5
# Epoch 8/100
# 18536/18536 [==============================] - 2s 111us/step - loss: 3.1398
#
# Epoch 00008: CRPS_score_val improved from 0.01529 to 0.01403, saving model to best_model.h5
# Epoch 9/100
# 18536/18536 [==============================] - 2s 102us/step - loss: 3.0280
#
# Epoch 00009: CRPS_score_val improved from 0.01403 to 0.01360, saving model to best_model.h5
# Epoch 10/100
# 18536/18536 [==============================] - 2s 111us/step - loss: 2.9583
#
# Epoch 00010: CRPS_score_val improved from 0.01360 to 0.01343, saving model to best_model.h5
# Epoch 11/100
# 18536/18536 [==============================] - 2s 112us/step - loss: 2.9029
#
# Epoch 00011: CRPS_score_val improved from 0.01343 to 0.01333, saving model to best_model.h5
# Epoch 12/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.8690
#
# Epoch 00012: CRPS_score_val improved from 0.01333 to 0.01326, saving model to best_model.h5
# Epoch 13/100
# 18536/18536 [==============================] - 2s 110us/step - loss: 2.8443
#
# Epoch 00013: CRPS_score_val improved from 0.01326 to 0.01321, saving model to best_model.h5
# Epoch 14/100
# 18536/18536 [==============================] - 2s 98us/step - loss: 2.8134
#
# Epoch 00014: CRPS_score_val improved from 0.01321 to 0.01317, saving model to best_model.h5
# Epoch 15/100
# 18536/18536 [==============================] - 2s 115us/step - loss: 2.8052
#
# Epoch 00015: CRPS_score_val improved from 0.01317 to 0.01313, saving model to best_model.h5
# Epoch 16/100
# 18536/18536 [==============================] - 2s 109us/step - loss: 2.7913
#
# Epoch 00016: CRPS_score_val improved from 0.01313 to 0.01311, saving model to best_model.h5
# Epoch 17/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.7743
#
# Epoch 00017: CRPS_score_val improved from 0.01311 to 0.01307, saving model to best_model.h5
# Epoch 18/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.7732
#
# Epoch 00018: CRPS_score_val improved from 0.01307 to 0.01304, saving model to best_model.h5
# Epoch 19/100
# 18536/18536 [==============================] - 2s 101us/step - loss: 2.7591
#
# Epoch 00019: CRPS_score_val improved from 0.01304 to 0.01301, saving model to best_model.h5
# Epoch 20/100
# 18536/18536 [==============================] - 2s 115us/step - loss: 2.7470
#
# Epoch 00020: CRPS_score_val improved from 0.01301 to 0.01299, saving model to best_model.h5
# Epoch 21/100
# 18536/18536 [==============================] - 2s 102us/step - loss: 2.7420
#
# Epoch 00021: CRPS_score_val improved from 0.01299 to 0.01297, saving model to best_model.h5
# Epoch 22/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.7431
#
# Epoch 00022: CRPS_score_val did not improve from 0.01297
# Epoch 23/100
# 18536/18536 [==============================] - 2s 101us/step - loss: 2.7310
#
# Epoch 00023: CRPS_score_val improved from 0.01297 to 0.01294, saving model to best_model.h5
# Epoch 24/100
# 18536/18536 [==============================] - 2s 100us/step - loss: 2.7290
#
# Epoch 00024: CRPS_score_val improved from 0.01294 to 0.01292, saving model to best_model.h5
# Epoch 25/100
# 18536/18536 [==============================] - 2s 111us/step - loss: 2.7193
#
# Epoch 00025: CRPS_score_val improved from 0.01292 to 0.01292, saving model to best_model.h5
# Epoch 26/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.7161
#
# Epoch 00026: CRPS_score_val improved from 0.01292 to 0.01291, saving model to best_model.h5
# Epoch 27/100
# 18536/18536 [==============================] - 2s 111us/step - loss: 2.7115
#
# Epoch 00027: CRPS_score_val improved from 0.01291 to 0.01290, saving model to best_model.h5
# Epoch 28/100
# 18536/18536 [==============================] - 2s 117us/step - loss: 2.7136
#
# Epoch 00028: CRPS_score_val did not improve from 0.01290
# Epoch 29/100
# 18536/18536 [==============================] - 2s 110us/step - loss: 2.7052
#
# Epoch 00029: CRPS_score_val did not improve from 0.01290
# Epoch 30/100
# 18536/18536 [==============================] - 2s 113us/step - loss: 2.7020
#
# Epoch 00030: CRPS_score_val did not improve from 0.01290
# Epoch 31/100
# 18536/18536 [==============================] - 2s 101us/step - loss: 2.7013
#
# Epoch 00031: CRPS_score_val did not improve from 0.01290
# Epoch 32/100
# 18536/18536 [==============================] - 2s 112us/step - loss: 2.6908
#
# Epoch 00032: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 33/100
# 18536/18536 [==============================] - 2s 111us/step - loss: 2.6924
#
# Epoch 00033: CRPS_score_val improved from 0.01289 to 0.01287, saving model to best_model.h5
# Epoch 34/100
# 18536/18536 [==============================] - 2s 119us/step - loss: 2.6848
#
# Epoch 00034: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 35/100
# 18536/18536 [==============================] - 2s 112us/step - loss: 2.6850
#
# Epoch 00035: CRPS_score_val did not improve from 0.01286
# Epoch 36/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.6870
#
# Epoch 00036: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 37/100
# 18536/18536 [==============================] - 2s 116us/step - loss: 2.6826
#
# Epoch 00037: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 38/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.6839
#
# Epoch 00038: CRPS_score_val did not improve from 0.01285
# Epoch 39/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.6779
#
# Epoch 00039: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 40/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6696
#
# Epoch 00040: CRPS_score_val did not improve from 0.01285
# Epoch 41/100
# 18536/18536 [==============================] - 2s 102us/step - loss: 2.6732
#
# Epoch 00041: CRPS_score_val did not improve from 0.01285
# Epoch 42/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.6675
#
# Epoch 00042: CRPS_score_val improved from 0.01285 to 0.01282, saving model to best_model.h5
# Epoch 43/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.6641
#
# Epoch 00043: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 44/100
# 18536/18536 [==============================] - 2s 101us/step - loss: 2.6624
#
# Epoch 00044: CRPS_score_val did not improve from 0.01282
# Epoch 45/100
# 18536/18536 [==============================] - 2s 122us/step - loss: 2.6644
#
# Epoch 00045: CRPS_score_val did not improve from 0.01282
# Epoch 46/100
# 18536/18536 [==============================] - 2s 102us/step - loss: 2.6579
#
# Epoch 00046: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 47/100
# 18536/18536 [==============================] - 2s 113us/step - loss: 2.6570
#
# Epoch 00047: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 48/100
# 18536/18536 [==============================] - 2s 98us/step - loss: 2.6565
#
# Epoch 00048: CRPS_score_val did not improve from 0.01282
# Epoch 49/100
# 18536/18536 [==============================] - 2s 102us/step - loss: 2.6530
#
# Epoch 00049: CRPS_score_val did not improve from 0.01282
# Epoch 50/100
# 18536/18536 [==============================] - 2s 100us/step - loss: 2.6498
#
# Epoch 00050: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 51/100
# 18536/18536 [==============================] - 2s 101us/step - loss: 2.6490
#
# Epoch 00051: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 52/100
# 18536/18536 [==============================] - 2s 108us/step - loss: 2.6464
#
# Epoch 00052: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 53/100
# 18536/18536 [==============================] - 2s 102us/step - loss: 2.6449
#
# Epoch 00053: CRPS_score_val did not improve from 0.01280
# Epoch 54/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.6397
#
# Epoch 00054: CRPS_score_val did not improve from 0.01280
# Epoch 55/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6408
#
# Epoch 00055: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 56/100
# 18536/18536 [==============================] - 2s 97us/step - loss: 2.6392
#
# Epoch 00056: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 57/100
# 18536/18536 [==============================] - 2s 111us/step - loss: 2.6355
#
# Epoch 00057: CRPS_score_val did not improve from 0.01279
# Epoch 58/100
# 18536/18536 [==============================] - 2s 108us/step - loss: 2.6337
#
# Epoch 00058: CRPS_score_val did not improve from 0.01279
# Epoch 59/100
# 18536/18536 [==============================] - 2s 115us/step - loss: 2.6356
#
# Epoch 00059: CRPS_score_val did not improve from 0.01279
# Epoch 60/100
# 18536/18536 [==============================] - 2s 117us/step - loss: 2.6266
#
# Epoch 00060: CRPS_score_val improved from 0.01279 to 0.01279, saving model to best_model.h5
# Epoch 61/100
# 18536/18536 [==============================] - 2s 116us/step - loss: 2.6264
#
# Epoch 00061: CRPS_score_val did not improve from 0.01279
# Epoch 62/100
# 18536/18536 [==============================] - 2s 109us/step - loss: 2.6232
#
# Epoch 00062: CRPS_score_val did not improve from 0.01279
# Epoch 63/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6242
#
# Epoch 00063: CRPS_score_val did not improve from 0.01279
# Epoch 64/100
# 18536/18536 [==============================] - 2s 101us/step - loss: 2.6204
#
# Epoch 00064: CRPS_score_val did not improve from 0.01279
# Epoch 65/100
# 18536/18536 [==============================] - 2s 100us/step - loss: 2.6219
#
# Epoch 00065: CRPS_score_val improved from 0.01279 to 0.01279, saving model to best_model.h5
# Epoch 66/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6146
#
# Epoch 00066: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 67/100
# 18536/18536 [==============================] - 2s 108us/step - loss: 2.6158
#
# Epoch 00067: CRPS_score_val did not improve from 0.01278
# Epoch 68/100
# 18536/18536 [==============================] - 2s 100us/step - loss: 2.6099
#
# Epoch 00068: CRPS_score_val did not improve from 0.01278
# Epoch 69/100
# 18536/18536 [==============================] - 2s 102us/step - loss: 2.6082
#
# Epoch 00069: CRPS_score_val did not improve from 0.01278
# Epoch 70/100
# 18536/18536 [==============================] - 2s 101us/step - loss: 2.6094
#
# Epoch 00070: CRPS_score_val did not improve from 0.01278
# Epoch 71/100
# 18536/18536 [==============================] - 2s 107us/step - loss: 2.6075
#
# Epoch 00071: CRPS_score_val did not improve from 0.01278
# Epoch 72/100
# 18536/18536 [==============================] - 2s 105us/step - loss: 2.6012
#
# Epoch 00072: CRPS_score_val did not improve from 0.01278
# Epoch 73/100
# 18536/18536 [==============================] - 2s 102us/step - loss: 2.6044
#
# Epoch 00073: CRPS_score_val did not improve from 0.01278
# Epoch 74/100
# 18536/18536 [==============================] - 2s 109us/step - loss: 2.6007
#
# Epoch 00074: CRPS_score_val did not improve from 0.01278
# Epoch 75/100
# 18536/18536 [==============================] - 2s 106us/step - loss: 2.5982
#
# Epoch 00075: CRPS_score_val did not improve from 0.01278
# Epoch 76/100
# 18536/18536 [==============================] - 2s 124us/step - loss: 2.5945
# Restoring model weights from the end of the best epoch
#
# Epoch 00076: CRPS_score_val did not improve from 0.01278
# Epoch 00076: early stopping
# the 1 fold crps is 0.012779
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 152us/step - loss: 5.5894
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08162, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 5.0658
#
# Epoch 00002: CRPS_score_val improved from 0.08162 to 0.07736, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 4.6422
#
# Epoch 00003: CRPS_score_val improved from 0.07736 to 0.06246, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 4.2420
#
# Epoch 00004: CRPS_score_val improved from 0.06246 to 0.04114, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 3.9103
#
# Epoch 00005: CRPS_score_val improved from 0.04114 to 0.02521, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 3.5782
#
# Epoch 00006: CRPS_score_val improved from 0.02521 to 0.01789, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 3.3076
#
# Epoch 00007: CRPS_score_val improved from 0.01789 to 0.01484, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 119us/step - loss: 3.1103
#
# Epoch 00008: CRPS_score_val improved from 0.01484 to 0.01387, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.9954
#
# Epoch 00009: CRPS_score_val improved from 0.01387 to 0.01347, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 119us/step - loss: 2.9280
#
# Epoch 00010: CRPS_score_val improved from 0.01347 to 0.01332, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.8740
#
# Epoch 00011: CRPS_score_val improved from 0.01332 to 0.01322, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.8531
#
# Epoch 00012: CRPS_score_val improved from 0.01322 to 0.01317, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.8189
#
# Epoch 00013: CRPS_score_val improved from 0.01317 to 0.01312, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.8117
#
# Epoch 00014: CRPS_score_val improved from 0.01312 to 0.01307, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.7869
#
# Epoch 00015: CRPS_score_val improved from 0.01307 to 0.01305, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.7700
#
# Epoch 00016: CRPS_score_val improved from 0.01305 to 0.01302, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.7627
#
# Epoch 00017: CRPS_score_val improved from 0.01302 to 0.01298, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.7548
#
# Epoch 00018: CRPS_score_val improved from 0.01298 to 0.01296, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.7499
#
# Epoch 00019: CRPS_score_val did not improve from 0.01296
# Epoch 20/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.7430
#
# Epoch 00020: CRPS_score_val improved from 0.01296 to 0.01294, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.7362
#
# Epoch 00021: CRPS_score_val improved from 0.01294 to 0.01293, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.7288
#
# Epoch 00022: CRPS_score_val improved from 0.01293 to 0.01290, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.7289
#
# Epoch 00023: CRPS_score_val improved from 0.01290 to 0.01290, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.7196
#
# Epoch 00024: CRPS_score_val improved from 0.01290 to 0.01287, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.7135
#
# Epoch 00025: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.7082
#
# Epoch 00026: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.7038
#
# Epoch 00027: CRPS_score_val did not improve from 0.01285
# Epoch 28/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.7041
#
# Epoch 00028: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6989
#
# Epoch 00029: CRPS_score_val improved from 0.01284 to 0.01284, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 2.6943
#
# Epoch 00030: CRPS_score_val improved from 0.01284 to 0.01282, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6917
#
# Epoch 00031: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 119us/step - loss: 2.6896
#
# Epoch 00032: CRPS_score_val did not improve from 0.01282
# Epoch 33/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6872
#
# Epoch 00033: CRPS_score_val did not improve from 0.01282
# Epoch 34/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 2.6859
#
# Epoch 00034: CRPS_score_val did not improve from 0.01282
# Epoch 35/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.6774
#
# Epoch 00035: CRPS_score_val did not improve from 0.01282
# Epoch 36/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6805
#
# Epoch 00036: CRPS_score_val did not improve from 0.01282
# Epoch 37/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6780
#
# Epoch 00037: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.6754
#
# Epoch 00038: CRPS_score_val did not improve from 0.01281
# Epoch 39/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6725
#
# Epoch 00039: CRPS_score_val did not improve from 0.01281
# Epoch 40/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6696
#
# Epoch 00040: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6658
#
# Epoch 00041: CRPS_score_val did not improve from 0.01280
# Epoch 42/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6654
#
# Epoch 00042: CRPS_score_val did not improve from 0.01280
# Epoch 43/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6619
#
# Epoch 00043: CRPS_score_val did not improve from 0.01280
# Epoch 44/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6596
#
# Epoch 00044: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6583
#
# Epoch 00045: CRPS_score_val did not improve from 0.01280
# Epoch 46/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6542
#
# Epoch 00046: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 47/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6546
#
# Epoch 00047: CRPS_score_val did not improve from 0.01279
# Epoch 48/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6512
#
# Epoch 00048: CRPS_score_val did not improve from 0.01279
# Epoch 49/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6467
#
# Epoch 00049: CRPS_score_val did not improve from 0.01279
# Epoch 50/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.6478
#
# Epoch 00050: CRPS_score_val did not improve from 0.01279
# Epoch 51/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6460
#
# Epoch 00051: CRPS_score_val improved from 0.01279 to 0.01279, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6403
#
# Epoch 00052: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 53/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6380
#
# Epoch 00053: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 54/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.6376
#
# Epoch 00054: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 55/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6319
#
# Epoch 00055: CRPS_score_val did not improve from 0.01277
# Epoch 56/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6367
#
# Epoch 00056: CRPS_score_val did not improve from 0.01277
# Epoch 57/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6285
#
# Epoch 00057: CRPS_score_val did not improve from 0.01277
# Epoch 58/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.6298
#
# Epoch 00058: CRPS_score_val did not improve from 0.01277
# Epoch 59/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6272
#
# Epoch 00059: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 60/100
# 18537/18537 [==============================] - 2s 116us/step - loss: 2.6258
#
# Epoch 00060: CRPS_score_val improved from 0.01276 to 0.01276, saving model to best_model.h5
# Epoch 61/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6203
#
# Epoch 00061: CRPS_score_val did not improve from 0.01276
# Epoch 62/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6165
#
# Epoch 00062: CRPS_score_val did not improve from 0.01276
# Epoch 63/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6213
#
# Epoch 00063: CRPS_score_val did not improve from 0.01276
# Epoch 64/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6151
#
# Epoch 00064: CRPS_score_val did not improve from 0.01276
# Epoch 65/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6180
#
# Epoch 00065: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 66/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6131
#
# Epoch 00066: CRPS_score_val did not improve from 0.01275
# Epoch 67/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6083
#
# Epoch 00067: CRPS_score_val did not improve from 0.01275
# Epoch 68/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6099
#
# Epoch 00068: CRPS_score_val did not improve from 0.01275
# Epoch 69/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6020
#
# Epoch 00069: CRPS_score_val did not improve from 0.01275
# Epoch 70/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.5998
#
# Epoch 00070: CRPS_score_val did not improve from 0.01275
# Epoch 71/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.5956
#
# Epoch 00071: CRPS_score_val did not improve from 0.01275
# Epoch 72/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.5945
#
# Epoch 00072: CRPS_score_val did not improve from 0.01275
# Epoch 73/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.5960
#
# Epoch 00073: CRPS_score_val did not improve from 0.01275
# Epoch 74/100
# 18537/18537 [==============================] - 2s 117us/step - loss: 2.5885
#
# Epoch 00074: CRPS_score_val did not improve from 0.01275
# Epoch 75/100
# 18537/18537 [==============================] - 2s 116us/step - loss: 2.5894
# Restoring model weights from the end of the best epoch
#
# Epoch 00075: CRPS_score_val did not improve from 0.01275
# Epoch 00075: early stopping
# the 2 fold crps is 0.012749
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 158us/step - loss: 5.5617
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08186, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 5.0942
#
# Epoch 00002: CRPS_score_val improved from 0.08186 to 0.07816, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 125us/step - loss: 4.6795
#
# Epoch 00003: CRPS_score_val improved from 0.07816 to 0.06424, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 4.2754
#
# Epoch 00004: CRPS_score_val improved from 0.06424 to 0.04278, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 123us/step - loss: 3.9042
#
# Epoch 00005: CRPS_score_val improved from 0.04278 to 0.02565, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 3.5563
#
# Epoch 00006: CRPS_score_val improved from 0.02565 to 0.01845, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 3.2840
#
# Epoch 00007: CRPS_score_val improved from 0.01845 to 0.01512, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 3.1093
#
# Epoch 00008: CRPS_score_val improved from 0.01512 to 0.01396, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.9993
#
# Epoch 00009: CRPS_score_val improved from 0.01396 to 0.01344, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.9369
#
# Epoch 00010: CRPS_score_val improved from 0.01344 to 0.01325, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.8935
#
# Epoch 00011: CRPS_score_val improved from 0.01325 to 0.01317, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 2.8596
#
# Epoch 00012: CRPS_score_val improved from 0.01317 to 0.01310, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.8283
#
# Epoch 00013: CRPS_score_val improved from 0.01310 to 0.01305, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.8127
#
# Epoch 00014: CRPS_score_val improved from 0.01305 to 0.01302, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.7976
#
# Epoch 00015: CRPS_score_val improved from 0.01302 to 0.01297, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.7807
#
# Epoch 00016: CRPS_score_val improved from 0.01297 to 0.01294, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.7694
#
# Epoch 00017: CRPS_score_val improved from 0.01294 to 0.01292, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 2.7620
#
# Epoch 00018: CRPS_score_val improved from 0.01292 to 0.01287, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 2.7471
#
# Epoch 00019: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 133us/step - loss: 2.7469
#
# Epoch 00020: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.7385
#
# Epoch 00021: CRPS_score_val improved from 0.01286 to 0.01283, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 123us/step - loss: 2.7369
#
# Epoch 00022: CRPS_score_val improved from 0.01283 to 0.01281, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.7254
#
# Epoch 00023: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 2.7218
#
# Epoch 00024: CRPS_score_val improved from 0.01281 to 0.01279, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.7186
#
# Epoch 00025: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 3s 137us/step - loss: 2.7179
#
# Epoch 00026: CRPS_score_val improved from 0.01278 to 0.01276, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 130us/step - loss: 2.7138
#
# Epoch 00027: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 3s 135us/step - loss: 2.7014
#
# Epoch 00028: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 131us/step - loss: 2.7080
#
# Epoch 00029: CRPS_score_val improved from 0.01274 to 0.01274, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 116us/step - loss: 2.6980
#
# Epoch 00030: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 127us/step - loss: 2.6965
#
# Epoch 00031: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 3s 136us/step - loss: 2.6915
#
# Epoch 00032: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 120us/step - loss: 2.6872
#
# Epoch 00033: CRPS_score_val did not improve from 0.01273
# Epoch 34/100
# 18537/18537 [==============================] - 3s 136us/step - loss: 2.6896
#
# Epoch 00034: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 2.6841
#
# Epoch 00035: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 118us/step - loss: 2.6823
#
# Epoch 00036: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6778
#
# Epoch 00037: CRPS_score_val did not improve from 0.01271
# Epoch 38/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6768
#
# Epoch 00038: CRPS_score_val did not improve from 0.01271
# Epoch 39/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6792
#
# Epoch 00039: CRPS_score_val improved from 0.01271 to 0.01269, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6703
#
# Epoch 00040: CRPS_score_val did not improve from 0.01269
# Epoch 41/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6755
#
# Epoch 00041: CRPS_score_val did not improve from 0.01269
# Epoch 42/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.6669
#
# Epoch 00042: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.6680
#
# Epoch 00043: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6613
#
# Epoch 00044: CRPS_score_val did not improve from 0.01268
# Epoch 45/100
# 18537/18537 [==============================] - 2s 121us/step - loss: 2.6590
#
# Epoch 00045: CRPS_score_val did not improve from 0.01268
# Epoch 46/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6630
#
# Epoch 00046: CRPS_score_val did not improve from 0.01268
# Epoch 47/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 2.6569
#
# Epoch 00047: CRPS_score_val did not improve from 0.01268
# Epoch 48/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6581
#
# Epoch 00048: CRPS_score_val did not improve from 0.01268
# Epoch 49/100
# 18537/18537 [==============================] - 2s 117us/step - loss: 2.6535
#
# Epoch 00049: CRPS_score_val did not improve from 0.01268
# Epoch 50/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6475
#
# Epoch 00050: CRPS_score_val did not improve from 0.01268
# Epoch 51/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6415
#
# Epoch 00051: CRPS_score_val did not improve from 0.01268
# Epoch 52/100
# 18537/18537 [==============================] - 2s 115us/step - loss: 2.6447
#
# Epoch 00052: CRPS_score_val did not improve from 0.01268
# Epoch 53/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6438
# Restoring model weights from the end of the best epoch
#
# Epoch 00053: CRPS_score_val did not improve from 0.01268
# Epoch 00053: early stopping
# the 3 fold crps is 0.012683
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 168us/step - loss: 5.5666
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08256, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 5.0897
#
# Epoch 00002: CRPS_score_val improved from 0.08256 to 0.07838, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 4.6772
#
# Epoch 00003: CRPS_score_val improved from 0.07838 to 0.06527, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 4.2867
#
# Epoch 00004: CRPS_score_val improved from 0.06527 to 0.04506, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 3.9013
#
# Epoch 00005: CRPS_score_val improved from 0.04506 to 0.02783, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 3.5787
#
# Epoch 00006: CRPS_score_val improved from 0.02783 to 0.01951, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 3.3057
#
# Epoch 00007: CRPS_score_val improved from 0.01951 to 0.01578, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 3.1294
#
# Epoch 00008: CRPS_score_val improved from 0.01578 to 0.01416, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 3.0106
#
# Epoch 00009: CRPS_score_val improved from 0.01416 to 0.01348, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 2.9431
#
# Epoch 00010: CRPS_score_val improved from 0.01348 to 0.01324, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.8873
#
# Epoch 00011: CRPS_score_val improved from 0.01324 to 0.01309, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.8638
#
# Epoch 00012: CRPS_score_val improved from 0.01309 to 0.01304, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.8347
#
# Epoch 00013: CRPS_score_val improved from 0.01304 to 0.01298, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.8183
#
# Epoch 00014: CRPS_score_val improved from 0.01298 to 0.01293, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.8019
#
# Epoch 00015: CRPS_score_val improved from 0.01293 to 0.01288, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.7834
#
# Epoch 00016: CRPS_score_val improved from 0.01288 to 0.01285, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 2.7773
#
# Epoch 00017: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 2.7618
#
# Epoch 00018: CRPS_score_val improved from 0.01283 to 0.01279, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 2.7571
#
# Epoch 00019: CRPS_score_val did not improve from 0.01279
# Epoch 20/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.7472
#
# Epoch 00020: CRPS_score_val improved from 0.01279 to 0.01277, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 2.7465
#
# Epoch 00021: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.7430
#
# Epoch 00022: CRPS_score_val improved from 0.01276 to 0.01276, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.7276
#
# Epoch 00023: CRPS_score_val improved from 0.01276 to 0.01273, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.7238
#
# Epoch 00024: CRPS_score_val did not improve from 0.01273
# Epoch 25/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.7209
#
# Epoch 00025: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.7200
#
# Epoch 00026: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.7098
#
# Epoch 00027: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 2.7048
#
# Epoch 00028: CRPS_score_val improved from 0.01272 to 0.01269, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.7056
#
# Epoch 00029: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.7001
#
# Epoch 00030: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.7007
#
# Epoch 00031: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 115us/step - loss: 2.6929
#
# Epoch 00032: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6906
#
# Epoch 00033: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.6840
#
# Epoch 00034: CRPS_score_val improved from 0.01265 to 0.01265, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6910
#
# Epoch 00035: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6842
#
# Epoch 00036: CRPS_score_val improved from 0.01264 to 0.01263, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6771
#
# Epoch 00037: CRPS_score_val did not improve from 0.01263
# Epoch 38/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.6792
#
# Epoch 00038: CRPS_score_val did not improve from 0.01263
# Epoch 39/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 2.6734
#
# Epoch 00039: CRPS_score_val did not improve from 0.01263
# Epoch 40/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6717
#
# Epoch 00040: CRPS_score_val did not improve from 0.01263
# Epoch 41/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.6706
#
# Epoch 00041: CRPS_score_val improved from 0.01263 to 0.01262, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6713
#
# Epoch 00042: CRPS_score_val improved from 0.01262 to 0.01261, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6677
#
# Epoch 00043: CRPS_score_val did not improve from 0.01261
# Epoch 44/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6627
#
# Epoch 00044: CRPS_score_val did not improve from 0.01261
# Epoch 45/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6607
#
# Epoch 00045: CRPS_score_val did not improve from 0.01261
# Epoch 46/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.6640
#
# Epoch 00046: CRPS_score_val improved from 0.01261 to 0.01261, saving model to best_model.h5
# Epoch 47/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6545
#
# Epoch 00047: CRPS_score_val did not improve from 0.01261
# Epoch 48/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.6537
#
# Epoch 00048: CRPS_score_val did not improve from 0.01261
# Epoch 49/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6509
#
# Epoch 00049: CRPS_score_val improved from 0.01261 to 0.01260, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.6516
#
# Epoch 00050: CRPS_score_val did not improve from 0.01260
# Epoch 51/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6456
#
# Epoch 00051: CRPS_score_val did not improve from 0.01260
# Epoch 52/100
# 18537/18537 [==============================] - 2s 117us/step - loss: 2.6450
#
# Epoch 00052: CRPS_score_val did not improve from 0.01260
# Epoch 53/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6440
#
# Epoch 00053: CRPS_score_val did not improve from 0.01260
# Epoch 54/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6408
#
# Epoch 00054: CRPS_score_val improved from 0.01260 to 0.01260, saving model to best_model.h5
# Epoch 55/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.6371
#
# Epoch 00055: CRPS_score_val did not improve from 0.01260
# Epoch 56/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.6357
#
# Epoch 00056: CRPS_score_val did not improve from 0.01260
# Epoch 57/100
# 18537/18537 [==============================] - 2s 116us/step - loss: 2.6328
#
# Epoch 00057: CRPS_score_val did not improve from 0.01260
# Epoch 58/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6359
#
# Epoch 00058: CRPS_score_val did not improve from 0.01260
# Epoch 59/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6285
#
# Epoch 00059: CRPS_score_val did not improve from 0.01260
# Epoch 60/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.6317
#
# Epoch 00060: CRPS_score_val did not improve from 0.01260
# Epoch 61/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6241
#
# Epoch 00061: CRPS_score_val improved from 0.01260 to 0.01259, saving model to best_model.h5
# Epoch 62/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6225
#
# Epoch 00062: CRPS_score_val improved from 0.01259 to 0.01258, saving model to best_model.h5
# Epoch 63/100
# 18537/18537 [==============================] - 2s 115us/step - loss: 2.6199
#
# Epoch 00063: CRPS_score_val did not improve from 0.01258
# Epoch 64/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 2.6161
#
# Epoch 00064: CRPS_score_val did not improve from 0.01258
# Epoch 65/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6199
#
# Epoch 00065: CRPS_score_val did not improve from 0.01258
# Epoch 66/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.6171
#
# Epoch 00066: CRPS_score_val did not improve from 0.01258
# Epoch 67/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 2.6150
#
# Epoch 00067: CRPS_score_val did not improve from 0.01258
# Epoch 68/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6099
#
# Epoch 00068: CRPS_score_val did not improve from 0.01258
# Epoch 69/100
# 18537/18537 [==============================] - 2s 118us/step - loss: 2.6068
#
# Epoch 00069: CRPS_score_val did not improve from 0.01258
# Epoch 70/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.6062
#
# Epoch 00070: CRPS_score_val did not improve from 0.01258
# Epoch 71/100
# 18537/18537 [==============================] - 2s 117us/step - loss: 2.6061
#
# Epoch 00071: CRPS_score_val did not improve from 0.01258
# Epoch 72/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.6057
# Restoring model weights from the end of the best epoch
#
# Epoch 00072: CRPS_score_val did not improve from 0.01258
# Epoch 00072: early stopping
# the 4 fold crps is 0.012583
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 4s 201us/step - loss: 5.5838
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08288, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 117us/step - loss: 5.0762
#
# Epoch 00002: CRPS_score_val improved from 0.08288 to 0.07795, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 4.6726
#
# Epoch 00003: CRPS_score_val improved from 0.07795 to 0.06416, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 4.2458
#
# Epoch 00004: CRPS_score_val improved from 0.06416 to 0.04292, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 3.8948
#
# Epoch 00005: CRPS_score_val improved from 0.04292 to 0.02647, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 3.5757
#
# Epoch 00006: CRPS_score_val improved from 0.02647 to 0.01880, saving model to best_model.h5
# Epoch 7/100
# ...
#
# Epoch 00049: CRPS_score_val improved from 0.01335 to 0.01334, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6454
#
# Epoch 00050: CRPS_score_val did not improve from 0.01334
# Epoch 51/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6421
#
# Epoch 00051: CRPS_score_val did not improve from 0.01334
# Epoch 52/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6442
#
# Epoch 00052: CRPS_score_val did not improve from 0.01334
# Epoch 53/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6422
#
# Epoch 00053: CRPS_score_val did not improve from 0.01334
# Epoch 54/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6378
#
# Epoch 00054: CRPS_score_val did not improve from 0.01334
# Epoch 55/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6414
#
# Epoch 00055: CRPS_score_val improved from 0.01334 to 0.01333, saving model to best_model.h5
# Epoch 56/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6300
#
# Epoch 00056: CRPS_score_val did not improve from 0.01333
# Epoch 57/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6243
#
# Epoch 00057: CRPS_score_val did not improve from 0.01333
# Epoch 58/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6340
#
# Epoch 00058: CRPS_score_val did not improve from 0.01333
# Epoch 59/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.6225
#
# Epoch 00059: CRPS_score_val did not improve from 0.01333
# Epoch 60/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6286
#
# Epoch 00060: CRPS_score_val did not improve from 0.01333
# Epoch 61/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 2.6201
#
# Epoch 00061: CRPS_score_val did not improve from 0.01333
# Epoch 62/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.6148
#
# Epoch 00062: CRPS_score_val did not improve from 0.01333
# Epoch 63/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.6158
#
# Epoch 00063: CRPS_score_val did not improve from 0.01333
# Epoch 64/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6092
#
# Epoch 00064: CRPS_score_val did not improve from 0.01333
# Epoch 65/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6083
# Restoring model weights from the end of the best epoch
#
# Epoch 00065: CRPS_score_val did not improve from 0.01333
# Epoch 00065: early stopping
# the 4 fold crps is 0.013329
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 4s 224us/step - loss: 5.5429
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08205, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 5.0587
#
# Epoch 00002: CRPS_score_val improved from 0.08205 to 0.07659, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 115us/step - loss: 4.6519
#
# Epoch 00003: CRPS_score_val improved from 0.07659 to 0.06200, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 4.2650
#
# Epoch 00004: CRPS_score_val improved from 0.06200 to 0.04123, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 3.8996
#
# Epoch 00005: CRPS_score_val improved from 0.04123 to 0.02612, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 3.5852
#
# Epoch 00006: CRPS_score_val improved from 0.02612 to 0.01868, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 3.3181
#
# Epoch 00007: CRPS_score_val improved from 0.01868 to 0.01525, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 3.1284
#
# Epoch 00008: CRPS_score_val improved from 0.01525 to 0.01405, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.9981
#
# Epoch 00009: CRPS_score_val improved from 0.01405 to 0.01352, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 2.9379
#
# Epoch 00010: CRPS_score_val improved from 0.01352 to 0.01326, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.8930
#
# Epoch 00011: CRPS_score_val improved from 0.01326 to 0.01314, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 115us/step - loss: 2.8516
#
# Epoch 00012: CRPS_score_val improved from 0.01314 to 0.01309, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.8346
#
# Epoch 00013: CRPS_score_val improved from 0.01309 to 0.01303, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.8166
#
# Epoch 00014: CRPS_score_val improved from 0.01303 to 0.01300, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.7980
#
# Epoch 00015: CRPS_score_val improved from 0.01300 to 0.01295, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.7804
#
# Epoch 00016: CRPS_score_val improved from 0.01295 to 0.01291, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 115us/step - loss: 2.7750
#
# Epoch 00017: CRPS_score_val improved from 0.01291 to 0.01289, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.7701
#
# Epoch 00018: CRPS_score_val improved from 0.01289 to 0.01289, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.7481
#
# Epoch 00019: CRPS_score_val improved from 0.01289 to 0.01284, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.7420
#
# Epoch 00020: CRPS_score_val improved from 0.01284 to 0.01281, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 115us/step - loss: 2.7346
#
# Epoch 00021: CRPS_score_val improved from 0.01281 to 0.01279, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 4s 191us/step - loss: 2.7319
#
# Epoch 00022: CRPS_score_val improved from 0.01279 to 0.01279, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 2.7258
#
# Epoch 00023: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 2.7276
#
# Epoch 00024: CRPS_score_val improved from 0.01278 to 0.01276, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 125us/step - loss: 2.7176
#
# Epoch 00025: CRPS_score_val improved from 0.01276 to 0.01274, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 2.7123
#
# Epoch 00026: CRPS_score_val improved from 0.01274 to 0.01274, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.7112
#
# Epoch 00027: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.7074
#
# Epoch 00028: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.7053
#
# Epoch 00029: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.7018
#
# Epoch 00030: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 120us/step - loss: 2.6966
#
# Epoch 00031: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.6901
#
# Epoch 00032: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6875
#
# Epoch 00033: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6875
#
# Epoch 00034: CRPS_score_val did not improve from 0.01268
# Epoch 35/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.6845
#
# Epoch 00035: CRPS_score_val did not improve from 0.01268
# Epoch 36/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6821
#
# Epoch 00036: CRPS_score_val did not improve from 0.01268
# Epoch 37/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.6812
#
# Epoch 00037: CRPS_score_val did not improve from 0.01268
# Epoch 38/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6761
#
# Epoch 00038: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 39/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6792
#
# Epoch 00039: CRPS_score_val did not improve from 0.01267
# Epoch 40/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.6700
#
# Epoch 00040: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6684
#
# Epoch 00041: CRPS_score_val improved from 0.01267 to 0.01265, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6718
#
# Epoch 00042: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6664
#
# Epoch 00043: CRPS_score_val did not improve from 0.01264
# Epoch 44/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.6610
#
# Epoch 00044: CRPS_score_val did not improve from 0.01264
# Epoch 45/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6553
#
# Epoch 00045: CRPS_score_val did not improve from 0.01264
# Epoch 46/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6617
#
# Epoch 00046: CRPS_score_val did not improve from 0.01264
# Epoch 47/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6588
#
# Epoch 00047: CRPS_score_val did not improve from 0.01264
# Epoch 48/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6568
#
# Epoch 00048: CRPS_score_val did not improve from 0.01264
# Epoch 49/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.6535
#
# Epoch 00049: CRPS_score_val did not improve from 0.01264
# Epoch 50/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6483
#
# Epoch 00050: CRPS_score_val did not improve from 0.01264
# Epoch 51/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6508
#
# Epoch 00051: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 117us/step - loss: 2.6537
#
# Epoch 00052: CRPS_score_val did not improve from 0.01264
# Epoch 53/100
# 18537/18537 [==============================] - 2s 119us/step - loss: 2.6444
#
# Epoch 00053: CRPS_score_val did not improve from 0.01264
# Epoch 54/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6437
#
# Epoch 00054: CRPS_score_val did not improve from 0.01264
# Epoch 55/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.6364
#
# Epoch 00055: CRPS_score_val did not improve from 0.01264
# Epoch 56/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 2.6342
#
# Epoch 00056: CRPS_score_val did not improve from 0.01264
# Epoch 57/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6325
#
# Epoch 00057: CRPS_score_val improved from 0.01264 to 0.01263, saving model to best_model.h5
# Epoch 58/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 2.6377
#
# Epoch 00058: CRPS_score_val did not improve from 0.01263
# Epoch 59/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.6265
#
# Epoch 00059: CRPS_score_val did not improve from 0.01263
# Epoch 60/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6292
#
# Epoch 00060: CRPS_score_val did not improve from 0.01263
# Epoch 61/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6260
#
# Epoch 00061: CRPS_score_val improved from 0.01263 to 0.01263, saving model to best_model.h5
# Epoch 62/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.6236
#
# Epoch 00062: CRPS_score_val improved from 0.01263 to 0.01261, saving model to best_model.h5
# Epoch 63/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6240
#
# Epoch 00063: CRPS_score_val did not improve from 0.01261
# Epoch 64/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.6199
#
# Epoch 00064: CRPS_score_val did not improve from 0.01261
# Epoch 65/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6163
#
# Epoch 00065: CRPS_score_val did not improve from 0.01261
# Epoch 66/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 2.6154
#
# Epoch 00066: CRPS_score_val did not improve from 0.01261
# Epoch 67/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6144
#
# Epoch 00067: CRPS_score_val did not improve from 0.01261
# Epoch 68/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6126
#
# Epoch 00068: CRPS_score_val did not improve from 0.01261
# Epoch 69/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6101
#
# Epoch 00069: CRPS_score_val did not improve from 0.01261
# Epoch 70/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6110
#
# Epoch 00070: CRPS_score_val improved from 0.01261 to 0.01260, saving model to best_model.h5
# Epoch 71/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6055
#
# Epoch 00071: CRPS_score_val did not improve from 0.01260
# Epoch 72/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6043
#
# Epoch 00072: CRPS_score_val did not improve from 0.01260
# Epoch 73/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.5973
#
# Epoch 00073: CRPS_score_val did not improve from 0.01260
# Epoch 74/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6003
#
# Epoch 00074: CRPS_score_val did not improve from 0.01260
# Epoch 75/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.5950
#
# Epoch 00075: CRPS_score_val did not improve from 0.01260
# Epoch 76/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.5984
#
# Epoch 00076: CRPS_score_val did not improve from 0.01260
# Epoch 77/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.5947
#
# Epoch 00077: CRPS_score_val did not improve from 0.01260
# Epoch 78/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.5905
#
# Epoch 00078: CRPS_score_val did not improve from 0.01260
# Epoch 79/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.5890
#
# Epoch 00079: CRPS_score_val did not improve from 0.01260
# Epoch 80/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.5863
# Restoring model weights from the end of the best epoch
#
# Epoch 00080: CRPS_score_val did not improve from 0.01260
# Epoch 00080: early stopping
# the 5 fold crps is 0.012605
# mean crps is 0.012762

# %%
print("mean crps is %f"%np.mean(crps_csv))
# Out:
# mean crps is 0.012762

# %% [markdown]
# # Time for the actual submission

# %%
# %%time
if  TRAIN_OFFLINE==False:
    from kaggle.competitions import nflrush
    env = nflrush.make_env()
    iter_test = env.iter_test()

    for (test_df, sample_prediction_df) in iter_test:
        basetable = create_features(test_df, deploy=True)
        basetable.drop(['GameId','PlayId'], axis=1, inplace=True)
        scaled_basetable = scaler.transform(basetable)

        y_pred = predict(scaled_basetable)
        y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1).tolist()[0]

        preds_df = pd.DataFrame(data=[y_pred], columns=sample_prediction_df.columns)
        env.predict(preds_df)

    env.write_submission_file()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.
# CPU times: user 14min 41s, sys: 27.8 s, total: 15min 9s
# Wall time: 14min 4s
