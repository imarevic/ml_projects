# %% [markdown]
# # Ensemble averaging from NN, XGB, and LGBM

# %%
import os
import re
import numpy as np
import pandas as pd
import scipy
import sklearn.metrics as mtr
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import f1_score

import xgboost as xgb
import lightgbm as lgb

from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization
from keras.models import Model
import keras.backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from keras.losses import binary_crossentropy
from keras.utils import to_categorical
import codecs
import datetime
import time

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %% [markdown]
# ## Preprocessing and Feature Engineering

# %%
# helper functions for data cleaning
# and feature engineering

def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"
    
def clean_turf_and_teams(train):
    
    ## Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)
    
    ## Teams
    Teams = {'ARI':'ARZ', 'BAL':'BLT', 'CLE':'CLV', 'HOU':'HST'}
    train['HomeTeamAbbr'] = train['HomeTeamAbbr'].map(Teams)
    train['VisitorTeamAbbr'] = train['VisitorTeamAbbr'].map(Teams)

    return train

# %%
# feature engineering (mainly rusher)
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense
    
    def rusher_features(df):
        
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Dir', 'S', 'A', 'X', 'Y']]
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS', 'RusherA', 'RusherX', 'RusherY']
        
       
        radian_angle = (90 - rusher['RusherDir']) * np.pi / 180.0
        v_horizontal = np.abs(rusher['RusherS'] * np.cos(radian_angle))
        v_vertical = np.abs(rusher['RusherS'] * np.sin(radian_angle)) 
        
       
        rusher['v_horizontal'] = v_horizontal
        rusher['v_vertical'] = v_vertical
        
        
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS','RusherA','RusherX', 'RusherY','v_horizontal', 'v_vertical']
        
        
        return rusher

    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))
        
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Weather
        df['GameWeather_process'] = df['GameWeather'].str.lower()
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
        df['GameWeather_dense'] = df['GameWeather_process'].apply(map_weather)
        add_new_feas.append("GameWeather_dense")
        
        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
    
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Quarter','Down','Distance','DefendersInTheBox']].drop_duplicates()

        static_features.fillna(-999,inplace=True)
       

        return static_features


    def combine_features(relative_to_back, defense,rushing, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,rushing,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    df = clean_turf_and_teams(df)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    rush_feats = rusher_features(df)
    static_feats = static_features(df)
    basetable = combine_features(rel_back, 
                                 def_feats,
                                 rush_feats,
                                 static_feats, 
                                 deploy=deploy)
    
    return basetable

# %%
# %time train_basetable = create_features(train, False)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 5min 13s, sys: 5 s, total: 5min 18s
# Wall time: 5min 17s

# %% [markdown]
# # Let's split our data into train/val for NN

# %%
X = train_basetable.copy()
yards = X.Yards

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
print(X_train.shape, X_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# (19695, 37) (3476, 37)
# (19695, 199) (3476, 199)

# %% [markdown]
# # Neural Net (NN) Model

# %%
class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
def get_model(x_tr,y_tr,x_val,y_val):
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(1024, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    #add lookahead
#     lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
#     lookahead.inject(model) # add into model

    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                                   save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    


    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
    crps = np.round(val_s, 6)

    return model,crps

# %%
losses = []
models = []
crps_csv = []

s_time = time.time()


for k in range(2):
    kfold = KFold(5, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print("-----------")
        tr_x,tr_y = X[tr_inds],y[tr_inds]
        val_x,val_y = X[val_inds],y[val_inds]
        model,crps = get_model(tr_x,tr_y,val_x,val_y)
        models.append(model)
        print("the %d fold crps is %f"%((k_fold+1),crps))
        crps_csv.append(crps)
 
print("mean crps is %f"%np.mean(crps_csv))


def predict_nn(x_te):
    model_num = len(models)
    for k,m in enumerate(models):
        if k==0:
            y_pred = m.predict(x_te,batch_size=1024)
        else:
            y_pred+=m.predict(x_te,batch_size=1024)
            
    y_pred = y_pred / model_num
    
    return y_pred
# Out:
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18536/18536 [==============================] - 3s 147us/step - loss: 5.5978
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08284, saving model to best_model.h5
# Epoch 2/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 5.0702
#
# Epoch 00002: CRPS_score_val improved from 0.08284 to 0.07740, saving model to best_model.h5
# Epoch 3/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 4.6510
#
# Epoch 00003: CRPS_score_val improved from 0.07740 to 0.06365, saving model to best_model.h5
# Epoch 4/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 4.2551
#
# Epoch 00004: CRPS_score_val improved from 0.06365 to 0.04227, saving model to best_model.h5
# Epoch 5/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 3.8957
#
# Epoch 00005: CRPS_score_val improved from 0.04227 to 0.02617, saving model to best_model.h5
# Epoch 6/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 3.5637
#
# Epoch 00006: CRPS_score_val improved from 0.02617 to 0.01861, saving model to best_model.h5
# Epoch 7/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 3.3084
#
# Epoch 00007: CRPS_score_val improved from 0.01861 to 0.01554, saving model to best_model.h5
# Epoch 8/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 3.1215
#
# Epoch 00008: CRPS_score_val improved from 0.01554 to 0.01419, saving model to best_model.h5
# Epoch 9/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 3.0088
#
# Epoch 00009: CRPS_score_val improved from 0.01419 to 0.01369, saving model to best_model.h5
# Epoch 10/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.9390
#
# Epoch 00010: CRPS_score_val improved from 0.01369 to 0.01345, saving model to best_model.h5
# Epoch 11/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.9053
#
# Epoch 00011: CRPS_score_val improved from 0.01345 to 0.01333, saving model to best_model.h5
# Epoch 12/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.8625
#
# Epoch 00012: CRPS_score_val improved from 0.01333 to 0.01327, saving model to best_model.h5
# Epoch 13/100
# 18536/18536 [==============================] - 2s 97us/step - loss: 2.8344
#
# Epoch 00013: CRPS_score_val improved from 0.01327 to 0.01323, saving model to best_model.h5
# Epoch 14/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.8216
#
# Epoch 00014: CRPS_score_val improved from 0.01323 to 0.01319, saving model to best_model.h5
# Epoch 15/100
# 18536/18536 [==============================] - 2s 97us/step - loss: 2.8092
#
# Epoch 00015: CRPS_score_val improved from 0.01319 to 0.01315, saving model to best_model.h5
# Epoch 16/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.7857
#
# Epoch 00016: CRPS_score_val improved from 0.01315 to 0.01312, saving model to best_model.h5
# Epoch 17/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.7692
#
# Epoch 00017: CRPS_score_val improved from 0.01312 to 0.01308, saving model to best_model.h5
# Epoch 18/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7696
#
# Epoch 00018: CRPS_score_val improved from 0.01308 to 0.01306, saving model to best_model.h5
# Epoch 19/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7568
#
# Epoch 00019: CRPS_score_val improved from 0.01306 to 0.01304, saving model to best_model.h5
# Epoch 20/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7457
#
# Epoch 00020: CRPS_score_val improved from 0.01304 to 0.01301, saving model to best_model.h5
# Epoch 21/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.7380
#
# Epoch 00021: CRPS_score_val improved from 0.01301 to 0.01300, saving model to best_model.h5
# Epoch 22/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.7365
#
# Epoch 00022: CRPS_score_val improved from 0.01300 to 0.01297, saving model to best_model.h5
# Epoch 23/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.7248
#
# Epoch 00023: CRPS_score_val improved from 0.01297 to 0.01297, saving model to best_model.h5
# Epoch 24/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.7241
#
# Epoch 00024: CRPS_score_val improved from 0.01297 to 0.01295, saving model to best_model.h5
# Epoch 25/100
# 18536/18536 [==============================] - 2s 93us/step - loss: 2.7168
#
# Epoch 00025: CRPS_score_val improved from 0.01295 to 0.01294, saving model to best_model.h5
# Epoch 26/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.7172
#
# Epoch 00026: CRPS_score_val did not improve from 0.01294
# Epoch 27/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.7138
#
# Epoch 00027: CRPS_score_val improved from 0.01294 to 0.01292, saving model to best_model.h5
# Epoch 28/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7089
#
# Epoch 00028: CRPS_score_val improved from 0.01292 to 0.01291, saving model to best_model.h5
# Epoch 29/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7037
#
# Epoch 00029: CRPS_score_val improved from 0.01291 to 0.01291, saving model to best_model.h5
# Epoch 30/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6946
#
# Epoch 00030: CRPS_score_val improved from 0.01291 to 0.01289, saving model to best_model.h5
# Epoch 31/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.7006
#
# Epoch 00031: CRPS_score_val improved from 0.01289 to 0.01289, saving model to best_model.h5
# Epoch 32/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.6935
#
# Epoch 00032: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 33/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.6907
#
# Epoch 00033: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 34/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6887
#
# Epoch 00034: CRPS_score_val improved from 0.01287 to 0.01287, saving model to best_model.h5
# Epoch 35/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6781
#
# Epoch 00035: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 36/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.6806
#
# Epoch 00036: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 37/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.6805
#
# Epoch 00037: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 38/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.6814
#
# Epoch 00038: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 39/100
# 18536/18536 [==============================] - 2s 93us/step - loss: 2.6733
#
# Epoch 00039: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 40/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.6730
#
# Epoch 00040: CRPS_score_val improved from 0.01284 to 0.01284, saving model to best_model.h5
# Epoch 41/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.6631
#
# Epoch 00041: CRPS_score_val improved from 0.01284 to 0.01284, saving model to best_model.h5
# Epoch 42/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.6716
#
# Epoch 00042: CRPS_score_val did not improve from 0.01284
# Epoch 43/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6623
#
# Epoch 00043: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 44/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.6598
#
# Epoch 00044: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# Epoch 45/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6546
#
# Epoch 00045: CRPS_score_val did not improve from 0.01283
# Epoch 46/100
# 18536/18536 [==============================] - 2s 102us/step - loss: 2.6598
#
# Epoch 00046: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 47/100
# 18536/18536 [==============================] - 2s 100us/step - loss: 2.6545
#
# Epoch 00047: CRPS_score_val did not improve from 0.01282
# Epoch 48/100
# 18536/18536 [==============================] - 2s 100us/step - loss: 2.6517
#
# Epoch 00048: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 49/100
# 18536/18536 [==============================] - 2s 100us/step - loss: 2.6496
#
# Epoch 00049: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 50/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.6469
#
# Epoch 00050: CRPS_score_val did not improve from 0.01281
# Epoch 51/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6454
#
# Epoch 00051: CRPS_score_val did not improve from 0.01281
# Epoch 52/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.6421
#
# Epoch 00052: CRPS_score_val did not improve from 0.01281
# Epoch 53/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6410
#
# Epoch 00053: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 54/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.6351
#
# Epoch 00054: CRPS_score_val did not improve from 0.01281
# Epoch 55/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6342
#
# Epoch 00055: CRPS_score_val did not improve from 0.01281
# Epoch 56/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6361
#
# Epoch 00056: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 57/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.6345
#
# Epoch 00057: CRPS_score_val did not improve from 0.01281
# Epoch 58/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6323
#
# Epoch 00058: CRPS_score_val improved from 0.01281 to 0.01278, saving model to best_model.h5
# Epoch 59/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6292
#
# Epoch 00059: CRPS_score_val did not improve from 0.01278
# Epoch 60/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6242
#
# Epoch 00060: CRPS_score_val did not improve from 0.01278
# Epoch 61/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6271
#
# Epoch 00061: CRPS_score_val did not improve from 0.01278
# Epoch 62/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6201
#
# Epoch 00062: CRPS_score_val did not improve from 0.01278
# Epoch 63/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6183
#
# Epoch 00063: CRPS_score_val did not improve from 0.01278
# Epoch 64/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6180
#
# Epoch 00064: CRPS_score_val did not improve from 0.01278
# Epoch 65/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6199
#
# Epoch 00065: CRPS_score_val did not improve from 0.01278
# Epoch 66/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.6154
#
# Epoch 00066: CRPS_score_val did not improve from 0.01278
# Epoch 67/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6093
#
# Epoch 00067: CRPS_score_val did not improve from 0.01278
# Epoch 68/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.6076
# Restoring model weights from the end of the best epoch
#
# Epoch 00068: CRPS_score_val did not improve from 0.01278
# Epoch 00068: early stopping
# the 1 fold crps is 0.012782
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 142us/step - loss: 5.5860
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08197, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 5.0823
#
# Epoch 00002: CRPS_score_val improved from 0.08197 to 0.07772, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 4.6647
#
# Epoch 00003: CRPS_score_val improved from 0.07772 to 0.06535, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 4.2940
#
# Epoch 00004: CRPS_score_val improved from 0.06535 to 0.04608, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.9303
#
# Epoch 00005: CRPS_score_val improved from 0.04608 to 0.02902, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 3.5956
#
# Epoch 00006: CRPS_score_val improved from 0.02902 to 0.01980, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 3.3336
#
# Epoch 00007: CRPS_score_val improved from 0.01980 to 0.01602, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 3.1242
#
# Epoch 00008: CRPS_score_val improved from 0.01602 to 0.01411, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.9984
#
# Epoch 00009: CRPS_score_val improved from 0.01411 to 0.01359, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.9253
#
# Epoch 00010: CRPS_score_val improved from 0.01359 to 0.01337, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.8772
#
# Epoch 00011: CRPS_score_val improved from 0.01337 to 0.01324, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.8427
#
# Epoch 00012: CRPS_score_val improved from 0.01324 to 0.01316, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.8174
#
# Epoch 00013: CRPS_score_val improved from 0.01316 to 0.01312, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.8095
#
# Epoch 00014: CRPS_score_val improved from 0.01312 to 0.01307, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7907
#
# Epoch 00015: CRPS_score_val improved from 0.01307 to 0.01306, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7749
#
# Epoch 00016: CRPS_score_val improved from 0.01306 to 0.01303, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7607
#
# Epoch 00017: CRPS_score_val improved from 0.01303 to 0.01298, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7581
#
# Epoch 00018: CRPS_score_val improved from 0.01298 to 0.01297, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7509
#
# Epoch 00019: CRPS_score_val improved from 0.01297 to 0.01296, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7399
#
# Epoch 00020: CRPS_score_val improved from 0.01296 to 0.01294, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7320
#
# Epoch 00021: CRPS_score_val improved from 0.01294 to 0.01290, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7265
#
# Epoch 00022: CRPS_score_val did not improve from 0.01290
# Epoch 23/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7226
#
# Epoch 00023: CRPS_score_val improved from 0.01290 to 0.01288, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7189
#
# Epoch 00024: CRPS_score_val improved from 0.01288 to 0.01286, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7086
#
# Epoch 00025: CRPS_score_val did not improve from 0.01286
# Epoch 26/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.7157
#
# Epoch 00026: CRPS_score_val did not improve from 0.01286
# Epoch 27/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7041
#
# Epoch 00027: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7006
#
# Epoch 00028: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6911
#
# Epoch 00029: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6907
#
# Epoch 00030: CRPS_score_val improved from 0.01284 to 0.01284, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6957
#
# Epoch 00031: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6877
#
# Epoch 00032: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6849
#
# Epoch 00033: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6830
#
# Epoch 00034: CRPS_score_val did not improve from 0.01282
# Epoch 35/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6767
#
# Epoch 00035: CRPS_score_val improved from 0.01282 to 0.01280, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6799
#
# Epoch 00036: CRPS_score_val did not improve from 0.01280
# Epoch 37/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6763
#
# Epoch 00037: CRPS_score_val did not improve from 0.01280
# Epoch 38/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6709
#
# Epoch 00038: CRPS_score_val did not improve from 0.01280
# Epoch 39/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6717
#
# Epoch 00039: CRPS_score_val did not improve from 0.01280
# Epoch 40/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6666
#
# Epoch 00040: CRPS_score_val did not improve from 0.01280
# Epoch 41/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6599
#
# Epoch 00041: CRPS_score_val did not improve from 0.01280
# Epoch 42/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6629
#
# Epoch 00042: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6585
#
# Epoch 00043: CRPS_score_val improved from 0.01278 to 0.01278, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6616
#
# Epoch 00044: CRPS_score_val did not improve from 0.01278
# Epoch 45/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6545
#
# Epoch 00045: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6546
#
# Epoch 00046: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 47/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6437
#
# Epoch 00047: CRPS_score_val did not improve from 0.01277
# Epoch 48/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6486
#
# Epoch 00048: CRPS_score_val did not improve from 0.01277
# Epoch 49/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6461
#
# Epoch 00049: CRPS_score_val did not improve from 0.01277
# Epoch 50/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6434
#
# Epoch 00050: CRPS_score_val did not improve from 0.01277
# Epoch 51/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6384
#
# Epoch 00051: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6454
#
# Epoch 00052: CRPS_score_val did not improve from 0.01277
# Epoch 53/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6368
#
# Epoch 00053: CRPS_score_val did not improve from 0.01277
# Epoch 54/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6374
#
# Epoch 00054: CRPS_score_val did not improve from 0.01277
# Epoch 55/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6276
#
# Epoch 00055: CRPS_score_val did not improve from 0.01277
# Epoch 56/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6313
#
# Epoch 00056: CRPS_score_val did not improve from 0.01277
# Epoch 57/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6330
#
# Epoch 00057: CRPS_score_val did not improve from 0.01277
# Epoch 58/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6332
#
# Epoch 00058: CRPS_score_val did not improve from 0.01277
# Epoch 59/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6262
#
# Epoch 00059: CRPS_score_val did not improve from 0.01277
# Epoch 60/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6235
#
# Epoch 00060: CRPS_score_val did not improve from 0.01277
# Epoch 61/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6216
# Restoring model weights from the end of the best epoch
#
# Epoch 00061: CRPS_score_val did not improve from 0.01277
# Epoch 00061: early stopping
# the 2 fold crps is 0.012765
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 151us/step - loss: 5.5635
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08207, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 5.0760
#
# Epoch 00002: CRPS_score_val improved from 0.08207 to 0.07777, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 4.6629
#
# Epoch 00003: CRPS_score_val improved from 0.07777 to 0.06375, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 4.2705
#
# Epoch 00004: CRPS_score_val improved from 0.06375 to 0.04390, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.8995
#
# Epoch 00005: CRPS_score_val improved from 0.04390 to 0.02788, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.5556
#
# Epoch 00006: CRPS_score_val improved from 0.02788 to 0.01909, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.3073
#
# Epoch 00007: CRPS_score_val improved from 0.01909 to 0.01553, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 3.1149
#
# Epoch 00008: CRPS_score_val improved from 0.01553 to 0.01412, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 3.0177
#
# Epoch 00009: CRPS_score_val improved from 0.01412 to 0.01357, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.9287
#
# Epoch 00010: CRPS_score_val improved from 0.01357 to 0.01338, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8953
#
# Epoch 00011: CRPS_score_val improved from 0.01338 to 0.01322, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8528
#
# Epoch 00012: CRPS_score_val improved from 0.01322 to 0.01313, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8265
#
# Epoch 00013: CRPS_score_val improved from 0.01313 to 0.01309, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8200
#
# Epoch 00014: CRPS_score_val improved from 0.01309 to 0.01304, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7934
#
# Epoch 00015: CRPS_score_val improved from 0.01304 to 0.01298, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7803
#
# Epoch 00016: CRPS_score_val improved from 0.01298 to 0.01294, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7733
#
# Epoch 00017: CRPS_score_val improved from 0.01294 to 0.01292, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7666
#
# Epoch 00018: CRPS_score_val improved from 0.01292 to 0.01289, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7570
#
# Epoch 00019: CRPS_score_val improved from 0.01289 to 0.01285, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7487
#
# Epoch 00020: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7350
#
# Epoch 00021: CRPS_score_val improved from 0.01283 to 0.01281, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7347
#
# Epoch 00022: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7287
#
# Epoch 00023: CRPS_score_val improved from 0.01281 to 0.01279, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7240
#
# Epoch 00024: CRPS_score_val improved from 0.01279 to 0.01279, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7204
#
# Epoch 00025: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7136
#
# Epoch 00026: CRPS_score_val improved from 0.01278 to 0.01276, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7075
#
# Epoch 00027: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7047
#
# Epoch 00028: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6974
#
# Epoch 00029: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6962
#
# Epoch 00030: CRPS_score_val did not improve from 0.01273
# Epoch 31/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6972
#
# Epoch 00031: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6955
#
# Epoch 00032: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6891
#
# Epoch 00033: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6846
#
# Epoch 00034: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6864
#
# Epoch 00035: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6804
#
# Epoch 00036: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6809
#
# Epoch 00037: CRPS_score_val did not improve from 0.01270
# Epoch 38/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6733
#
# Epoch 00038: CRPS_score_val did not improve from 0.01270
# Epoch 39/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6758
#
# Epoch 00039: CRPS_score_val did not improve from 0.01270
# Epoch 40/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6721
#
# Epoch 00040: CRPS_score_val did not improve from 0.01270
# Epoch 41/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6661
#
# Epoch 00041: CRPS_score_val did not improve from 0.01270
# Epoch 42/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6713
#
# Epoch 00042: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6622
#
# Epoch 00043: CRPS_score_val improved from 0.01270 to 0.01268, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6618
#
# Epoch 00044: CRPS_score_val did not improve from 0.01268
# Epoch 45/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6578
#
# Epoch 00045: CRPS_score_val did not improve from 0.01268
# Epoch 46/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6574
#
# Epoch 00046: CRPS_score_val did not improve from 0.01268
# Epoch 47/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6518
#
# Epoch 00047: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 48/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6536
#
# Epoch 00048: CRPS_score_val did not improve from 0.01267
# Epoch 49/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6564
#
# Epoch 00049: CRPS_score_val did not improve from 0.01267
# Epoch 50/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6514
#
# Epoch 00050: CRPS_score_val did not improve from 0.01267
# Epoch 51/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6479
#
# Epoch 00051: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6458
#
# Epoch 00052: CRPS_score_val did not improve from 0.01266
# Epoch 53/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6425
#
# Epoch 00053: CRPS_score_val did not improve from 0.01266
# Epoch 54/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.6385
#
# Epoch 00054: CRPS_score_val did not improve from 0.01266
# Epoch 55/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6381
#
# Epoch 00055: CRPS_score_val improved from 0.01266 to 0.01264, saving model to best_model.h5
# Epoch 56/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6318
#
# Epoch 00056: CRPS_score_val did not improve from 0.01264
# Epoch 57/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6297
#
# Epoch 00057: CRPS_score_val did not improve from 0.01264
# Epoch 58/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6270
#
# Epoch 00058: CRPS_score_val did not improve from 0.01264
# Epoch 59/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6267
#
# Epoch 00059: CRPS_score_val did not improve from 0.01264
# Epoch 60/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6244
#
# Epoch 00060: CRPS_score_val did not improve from 0.01264
# Epoch 61/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6289
#
# Epoch 00061: CRPS_score_val did not improve from 0.01264
# Epoch 62/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6245
#
# Epoch 00062: CRPS_score_val did not improve from 0.01264
# Epoch 63/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6208
#
# Epoch 00063: CRPS_score_val did not improve from 0.01264
# Epoch 64/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6216
#
# Epoch 00064: CRPS_score_val did not improve from 0.01264
# Epoch 65/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6157
# Restoring model weights from the end of the best epoch
#
# Epoch 00065: CRPS_score_val did not improve from 0.01264
# Epoch 00065: early stopping
# the 3 fold crps is 0.012645
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 151us/step - loss: 5.5913
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08248, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 5.1130
#
# Epoch 00002: CRPS_score_val improved from 0.08248 to 0.07815, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 4.7074
#
# Epoch 00003: CRPS_score_val improved from 0.07815 to 0.06485, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 4.3072
#
# Epoch 00004: CRPS_score_val improved from 0.06485 to 0.04429, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.9386
#
# Epoch 00005: CRPS_score_val improved from 0.04429 to 0.02704, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 3.5963
#
# Epoch 00006: CRPS_score_val improved from 0.02704 to 0.01873, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.3230
#
# Epoch 00007: CRPS_score_val improved from 0.01873 to 0.01516, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.1313
#
# Epoch 00008: CRPS_score_val improved from 0.01516 to 0.01397, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 3.0155
#
# Epoch 00009: CRPS_score_val improved from 0.01397 to 0.01344, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.9462
#
# Epoch 00010: CRPS_score_val improved from 0.01344 to 0.01322, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.8858
#
# Epoch 00011: CRPS_score_val improved from 0.01322 to 0.01310, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.8613
#
# Epoch 00012: CRPS_score_val improved from 0.01310 to 0.01303, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8302
#
# Epoch 00013: CRPS_score_val improved from 0.01303 to 0.01298, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.8151
#
# Epoch 00014: CRPS_score_val improved from 0.01298 to 0.01294, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 116us/step - loss: 2.8047
#
# Epoch 00015: CRPS_score_val improved from 0.01294 to 0.01290, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.7912
#
# Epoch 00016: CRPS_score_val improved from 0.01290 to 0.01287, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7767
#
# Epoch 00017: CRPS_score_val improved from 0.01287 to 0.01284, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7691
#
# Epoch 00018: CRPS_score_val improved from 0.01284 to 0.01281, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7670
#
# Epoch 00019: CRPS_score_val improved from 0.01281 to 0.01278, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7497
#
# Epoch 00020: CRPS_score_val improved from 0.01278 to 0.01276, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7405
#
# Epoch 00021: CRPS_score_val improved from 0.01276 to 0.01274, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7355
#
# Epoch 00022: CRPS_score_val improved from 0.01274 to 0.01272, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7346
#
# Epoch 00023: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7259
#
# Epoch 00024: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7212
#
# Epoch 00025: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7173
#
# Epoch 00026: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7147
#
# Epoch 00027: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7088
#
# Epoch 00028: CRPS_score_val did not improve from 0.01269
# Epoch 29/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7018
#
# Epoch 00029: CRPS_score_val did not improve from 0.01269
# Epoch 30/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7011
#
# Epoch 00030: CRPS_score_val improved from 0.01269 to 0.01267, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6991
#
# Epoch 00031: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6959
#
# Epoch 00032: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6943
#
# Epoch 00033: CRPS_score_val did not improve from 0.01266
# Epoch 34/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6891
#
# Epoch 00034: CRPS_score_val did not improve from 0.01266
# Epoch 35/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6904
#
# Epoch 00035: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6801
#
# Epoch 00036: CRPS_score_val improved from 0.01265 to 0.01265, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6826
#
# Epoch 00037: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6795
#
# Epoch 00038: CRPS_score_val did not improve from 0.01264
# Epoch 39/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6703
#
# Epoch 00039: CRPS_score_val did not improve from 0.01264
# Epoch 40/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6720
#
# Epoch 00040: CRPS_score_val did not improve from 0.01264
# Epoch 41/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6699
#
# Epoch 00041: CRPS_score_val improved from 0.01264 to 0.01262, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6667
#
# Epoch 00042: CRPS_score_val did not improve from 0.01262
# Epoch 43/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6666
#
# Epoch 00043: CRPS_score_val did not improve from 0.01262
# Epoch 44/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6652
#
# Epoch 00044: CRPS_score_val did not improve from 0.01262
# Epoch 45/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6613
#
# Epoch 00045: CRPS_score_val did not improve from 0.01262
# Epoch 46/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6564
#
# Epoch 00046: CRPS_score_val improved from 0.01262 to 0.01262, saving model to best_model.h5
# Epoch 47/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6537
#
# Epoch 00047: CRPS_score_val improved from 0.01262 to 0.01261, saving model to best_model.h5
# Epoch 48/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6568
#
# Epoch 00048: CRPS_score_val did not improve from 0.01261
# Epoch 49/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6527
#
# Epoch 00049: CRPS_score_val improved from 0.01261 to 0.01261, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6529
#
# Epoch 00050: CRPS_score_val did not improve from 0.01261
# Epoch 51/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6453
#
# Epoch 00051: CRPS_score_val did not improve from 0.01261
# Epoch 52/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6447
#
# Epoch 00052: CRPS_score_val did not improve from 0.01261
# Epoch 53/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6449
#
# Epoch 00053: CRPS_score_val did not improve from 0.01261
# Epoch 54/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6440
#
# Epoch 00054: CRPS_score_val did not improve from 0.01261
# Epoch 55/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6325
#
# Epoch 00055: CRPS_score_val improved from 0.01261 to 0.01260, saving model to best_model.h5
# Epoch 56/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6359
#
# Epoch 00056: CRPS_score_val did not improve from 0.01260
# Epoch 57/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6325
#
# Epoch 00057: CRPS_score_val did not improve from 0.01260
# Epoch 58/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6300
#
# Epoch 00058: CRPS_score_val did not improve from 0.01260
# Epoch 59/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6272
#
# Epoch 00059: CRPS_score_val did not improve from 0.01260
# Epoch 60/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.6259
#
# Epoch 00060: CRPS_score_val improved from 0.01260 to 0.01260, saving model to best_model.h5
# Epoch 61/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6265
#
# Epoch 00061: CRPS_score_val did not improve from 0.01260
# Epoch 62/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6237
#
# Epoch 00062: CRPS_score_val did not improve from 0.01260
# Epoch 63/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6273
#
# Epoch 00063: CRPS_score_val did not improve from 0.01260
# Epoch 64/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6162
#
# Epoch 00064: CRPS_score_val did not improve from 0.01260
# Epoch 65/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6181
#
# Epoch 00065: CRPS_score_val did not improve from 0.01260
# Epoch 66/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6092
#
# Epoch 00066: CRPS_score_val did not improve from 0.01260
# Epoch 67/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6065
#
# Epoch 00067: CRPS_score_val did not improve from 0.01260
# Epoch 68/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6101
#
# Epoch 00068: CRPS_score_val did not improve from 0.01260
# Epoch 69/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6078
#
# Epoch 00069: CRPS_score_val did not improve from 0.01260
# Epoch 70/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6075
# Restoring model weights from the end of the best epoch
#
# Epoch 00070: CRPS_score_val did not improve from 0.01260
# Epoch 00070: early stopping
# the 4 fold crps is 0.012600
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 147us/step - loss: 5.6085
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08315, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 5.1189
#
# Epoch 00002: CRPS_score_val improved from 0.08315 to 0.07866, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 4.7137
#
# Epoch 00003: CRPS_score_val improved from 0.07866 to 0.06587, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 4.3289
#
# Epoch 00004: CRPS_score_val improved from 0.06587 to 0.04501, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.9497
#
# Epoch 00005: CRPS_score_val improved from 0.04501 to 0.02794, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 3.5874
#
# Epoch 00006: CRPS_score_val improved from 0.02794 to 0.01966, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.3239
#
# Epoch 00007: CRPS_score_val improved from 0.01966 to 0.01598, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 3.1254
#
# Epoch 00008: CRPS_score_val improved from 0.01598 to 0.01438, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 3.0112
#
# Epoch 00009: CRPS_score_val improved from 0.01438 to 0.01383, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.9360
#
# Epoch 00010: CRPS_score_val improved from 0.01383 to 0.01366, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8983
#
# Epoch 00011: CRPS_score_val improved from 0.01366 to 0.01355, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.8666
#
# Epoch 00012: CRPS_score_val improved from 0.01355 to 0.01348, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8454
#
# Epoch 00013: CRPS_score_val improved from 0.01348 to 0.01344, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8226
#
# Epoch 00014: CRPS_score_val improved from 0.01344 to 0.01341, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8036
#
# Epoch 00015: CRPS_score_val improved from 0.01341 to 0.01337, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7928
#
# Epoch 00016: CRPS_score_val improved from 0.01337 to 0.01334, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7793
#
# Epoch 00017: CRPS_score_val improved from 0.01334 to 0.01332, saving model to best_model.h5
# Epoch 18/100
# ...
#
# Epoch 00029: CRPS_score_val improved from 0.01345 to 0.01345, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6946
#
# Epoch 00030: CRPS_score_val improved from 0.01345 to 0.01343, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6982
#
# Epoch 00031: CRPS_score_val improved from 0.01343 to 0.01342, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6967
#
# Epoch 00032: CRPS_score_val improved from 0.01342 to 0.01341, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6936
#
# Epoch 00033: CRPS_score_val improved from 0.01341 to 0.01341, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6834
#
# Epoch 00034: CRPS_score_val did not improve from 0.01341
# Epoch 35/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6857
#
# Epoch 00035: CRPS_score_val improved from 0.01341 to 0.01340, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6796
#
# Epoch 00036: CRPS_score_val did not improve from 0.01340
# Epoch 37/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6741
#
# Epoch 00037: CRPS_score_val improved from 0.01340 to 0.01340, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6757
#
# Epoch 00038: CRPS_score_val did not improve from 0.01340
# Epoch 39/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6731
#
# Epoch 00039: CRPS_score_val did not improve from 0.01340
# Epoch 40/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6704
#
# Epoch 00040: CRPS_score_val improved from 0.01340 to 0.01340, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6657
#
# Epoch 00041: CRPS_score_val did not improve from 0.01340
# Epoch 42/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6702
#
# Epoch 00042: CRPS_score_val improved from 0.01340 to 0.01338, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.6634
#
# Epoch 00043: CRPS_score_val improved from 0.01338 to 0.01337, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6573
#
# Epoch 00044: CRPS_score_val improved from 0.01337 to 0.01337, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6585
#
# Epoch 00045: CRPS_score_val did not improve from 0.01337
# Epoch 46/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6524
#
# Epoch 00046: CRPS_score_val did not improve from 0.01337
# Epoch 47/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6553
#
# Epoch 00047: CRPS_score_val improved from 0.01337 to 0.01336, saving model to best_model.h5
# Epoch 48/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6506
#
# Epoch 00048: CRPS_score_val did not improve from 0.01336
# Epoch 49/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6458
#
# Epoch 00049: CRPS_score_val did not improve from 0.01336
# Epoch 50/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6515
#
# Epoch 00050: CRPS_score_val did not improve from 0.01336
# Epoch 51/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6436
#
# Epoch 00051: CRPS_score_val improved from 0.01336 to 0.01335, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6410
#
# Epoch 00052: CRPS_score_val improved from 0.01335 to 0.01334, saving model to best_model.h5
# Epoch 53/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6384
#
# Epoch 00053: CRPS_score_val did not improve from 0.01334
# Epoch 54/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6363
#
# Epoch 00054: CRPS_score_val did not improve from 0.01334
# Epoch 55/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6361
#
# Epoch 00055: CRPS_score_val did not improve from 0.01334
# Epoch 56/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6365
#
# Epoch 00056: CRPS_score_val did not improve from 0.01334
# Epoch 57/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6342
#
# Epoch 00057: CRPS_score_val did not improve from 0.01334
# Epoch 58/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6295
#
# Epoch 00058: CRPS_score_val did not improve from 0.01334
# Epoch 59/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6269
#
# Epoch 00059: CRPS_score_val did not improve from 0.01334
# Epoch 60/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6249
#
# Epoch 00060: CRPS_score_val did not improve from 0.01334
# Epoch 61/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6186
#
# Epoch 00061: CRPS_score_val did not improve from 0.01334
# Epoch 62/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6227
# Restoring model weights from the end of the best epoch
#
# Epoch 00062: CRPS_score_val did not improve from 0.01334
# Epoch 00062: early stopping
# the 4 fold crps is 0.013345
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 186us/step - loss: 5.5737
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08139, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 5.0929
#
# Epoch 00002: CRPS_score_val improved from 0.08139 to 0.07671, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 4.6570
#
# Epoch 00003: CRPS_score_val improved from 0.07671 to 0.06241, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 4.2858
#
# Epoch 00004: CRPS_score_val improved from 0.06241 to 0.04287, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 3.9297
#
# Epoch 00005: CRPS_score_val improved from 0.04287 to 0.02765, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 3.5846
#
# Epoch 00006: CRPS_score_val improved from 0.02765 to 0.01960, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 3.3213
#
# Epoch 00007: CRPS_score_val improved from 0.01960 to 0.01577, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 3.1405
#
# Epoch 00008: CRPS_score_val improved from 0.01577 to 0.01427, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 3.0067
#
# Epoch 00009: CRPS_score_val improved from 0.01427 to 0.01365, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.9404
#
# Epoch 00010: CRPS_score_val improved from 0.01365 to 0.01325, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.9009
#
# Epoch 00011: CRPS_score_val improved from 0.01325 to 0.01318, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.8591
#
# Epoch 00012: CRPS_score_val improved from 0.01318 to 0.01311, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.8320
#
# Epoch 00013: CRPS_score_val improved from 0.01311 to 0.01303, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.8217
#
# Epoch 00014: CRPS_score_val improved from 0.01303 to 0.01299, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.8051
#
# Epoch 00015: CRPS_score_val improved from 0.01299 to 0.01296, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.7847
#
# Epoch 00016: CRPS_score_val improved from 0.01296 to 0.01293, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7721
#
# Epoch 00017: CRPS_score_val improved from 0.01293 to 0.01289, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7609
#
# Epoch 00018: CRPS_score_val improved from 0.01289 to 0.01286, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.7571
#
# Epoch 00019: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7472
#
# Epoch 00020: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7405
#
# Epoch 00021: CRPS_score_val improved from 0.01283 to 0.01281, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.7364
#
# Epoch 00022: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.7267
#
# Epoch 00023: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.7212
#
# Epoch 00024: CRPS_score_val improved from 0.01279 to 0.01276, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7175
#
# Epoch 00025: CRPS_score_val improved from 0.01276 to 0.01276, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7074
#
# Epoch 00026: CRPS_score_val did not improve from 0.01276
# Epoch 27/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.7149
#
# Epoch 00027: CRPS_score_val improved from 0.01276 to 0.01274, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7023
#
# Epoch 00028: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7027
#
# Epoch 00029: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6978
#
# Epoch 00030: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6999
#
# Epoch 00031: CRPS_score_val improved from 0.01272 to 0.01270, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6923
#
# Epoch 00032: CRPS_score_val did not improve from 0.01270
# Epoch 33/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6887
#
# Epoch 00033: CRPS_score_val did not improve from 0.01270
# Epoch 34/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6857
#
# Epoch 00034: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6813
#
# Epoch 00035: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6803
#
# Epoch 00036: CRPS_score_val did not improve from 0.01269
# Epoch 37/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6737
#
# Epoch 00037: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6736
#
# Epoch 00038: CRPS_score_val did not improve from 0.01269
# Epoch 39/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6738
#
# Epoch 00039: CRPS_score_val did not improve from 0.01269
# Epoch 40/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6671
#
# Epoch 00040: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6674
#
# Epoch 00041: CRPS_score_val did not improve from 0.01269
# Epoch 42/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6683
#
# Epoch 00042: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6629
#
# Epoch 00043: CRPS_score_val did not improve from 0.01268
# Epoch 44/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6577
#
# Epoch 00044: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6563
#
# Epoch 00045: CRPS_score_val did not improve from 0.01267
# Epoch 46/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6604
#
# Epoch 00046: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 47/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6532
#
# Epoch 00047: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 48/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6521
#
# Epoch 00048: CRPS_score_val did not improve from 0.01266
# Epoch 49/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6494
#
# Epoch 00049: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6426
#
# Epoch 00050: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 51/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6458
#
# Epoch 00051: CRPS_score_val improved from 0.01265 to 0.01265, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6433
#
# Epoch 00052: CRPS_score_val did not improve from 0.01265
# Epoch 53/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6420
#
# Epoch 00053: CRPS_score_val did not improve from 0.01265
# Epoch 54/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6381
#
# Epoch 00054: CRPS_score_val did not improve from 0.01265
# Epoch 55/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6321
#
# Epoch 00055: CRPS_score_val did not improve from 0.01265
# Epoch 56/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6354
#
# Epoch 00056: CRPS_score_val did not improve from 0.01265
# Epoch 57/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6351
#
# Epoch 00057: CRPS_score_val did not improve from 0.01265
# Epoch 58/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6361
#
# Epoch 00058: CRPS_score_val did not improve from 0.01265
# Epoch 59/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6323
#
# Epoch 00059: CRPS_score_val did not improve from 0.01265
# Epoch 60/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6217
#
# Epoch 00060: CRPS_score_val did not improve from 0.01265
# Epoch 61/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6201
# Restoring model weights from the end of the best epoch
#
# Epoch 00061: CRPS_score_val did not improve from 0.01265
# Epoch 00061: early stopping
# the 5 fold crps is 0.012646
# mean crps is 0.012765

# %%
print("mean crps is %f"%np.mean(crps_csv))
# Out:
# mean crps is 0.012765

# %% [markdown]
# # Prepare and split data for XGB and LGBM

# %%
# split in train and valaidation in case no api for cross validation exists
y = yards.copy()
y = y.to_numpy()
target = y[np.arange(0, len(X_train), 22)]
standard_deviation = np.std(target)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=42)

# %% [markdown]
# # XGBoost Model

# %%
# train xgboost
kf = KFold(n_splits=5, shuffle=True, random_state=42)
n_estim = 150
for train_index, val_index in kf.split(X):
    print('----------')
    xgb_model = xgb.XGBRegressor(n_estimators=n_estim, verbosity=1).fit(X[train_index], y[train_index])
    y_pred = xgb_model.predict(X[val_index])
    y_act = y[val_index]
    err = mtr.mean_squared_error(y_act, y_pred)
    print("MSE: ", err)
# Out:
# ----------
# [20:36:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE:  42.68614674220218
# ----------
# [20:36:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE:  36.23686561214618
# ----------
# [20:36:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE:  37.073210825689756
# ----------
# [20:36:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE:  37.28947128587238
# ----------
# [20:36:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE:  39.96090443049378

# %% [markdown]
# # LGBM Model

# %%
# train lgbm model
kf = KFold(n_splits=5, shuffle=True, random_state=42)
n_estim = 150
for train_index, val_index in kf.split(X):
    print('----------')
    lgbm_model = lgb.LGBMRegressor(num_leaves=30, 
                                  learning_rate=0.1,
                                  n_estimators=n_estim, 
                                  verbosity=1).fit(X[train_index], y[train_index])
    y_pred = lgbm_model.predict(X[val_index], num_iteration=lgbm_model.best_iteration_)
    y_act = y[val_index]
    err = mtr.mean_squared_error(y_act, y_pred)
    print("MSE: ", err)
# Out:
# ----------
# MSE:  42.84865270902574
# ----------
# MSE:  36.64061500953784
# ----------
# MSE:  36.49112025794529
# ----------
# MSE:  37.39607556961241
# ----------
# MSE:  40.47366389550283

# %% [markdown]
# # Model averaging and actual submission

# %%
def to_cumulative_df(df_pred):
    df_pred_first = df_pred[0]
    pred_df = np.zeros((1, 199))

    for col_i in range(len(pred_df[0])):
        current_cdf = scipy.stats.norm(loc = df_pred_first, scale = standard_deviation).cdf(col_i-99)
        pred_df[0][col_i] = current_cdf
    return pred_df.tolist()[0]

# %%
def avg_model_preds(mod_1_pred, mod_2_pred, mod_3_pred, n_models):
    # average element wise
    avg_list = []
    for i in range(0, 199):
        avg_list.append(((mod_1_pred[i]+mod_2_pred[i]+mod_3_pred[i])/n_models))
    
    return avg_list

# %%
# %%time
# make submission
# env can only be created once and kernel needs
# to be restarted on > first run
from kaggle.competitions import nflrush
env = nflrush.make_env()
iter_test = env.iter_test()

for (test_df, sample_prediction_df) in iter_test:
    basetable = create_features(test_df, deploy=True)
    basetable.drop(['GameId','PlayId'], axis=1, inplace=True)
    scaled_basetable = scaler.transform(basetable)

    # make cummulative predictions from NN model
    y_pred_nn = predict_nn(scaled_basetable)
    y_pred_nn = np.clip(np.cumsum(y_pred_nn, axis=1), 0, 1).tolist()[0]
    # make cummulative predictions from XGB model
    y_pred_xgb = xgb_model.predict(scaled_basetable)
    y_pred_xgb = to_cumulative_df(y_pred_xgb)
    # make cummulative predictions from LGBM model
    y_pred_lgbm = lgbm_model.predict(scaled_basetable)
    y_pred_lgbm = to_cumulative_df(y_pred_lgbm)
    # average of cummulative predictions
    y_pred_final = avg_model_preds(y_pred_nn, y_pred_xgb, y_pred_lgbm,3)
    
    preds_df = pd.DataFrame(data=[y_pred_final], columns=sample_prediction_df.columns)
    env.predict(preds_df)

env.write_submission_file()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.
# CPU times: user 37min 20s, sys: 51.6 s, total: 38min 12s
# Wall time: 36min 39s
