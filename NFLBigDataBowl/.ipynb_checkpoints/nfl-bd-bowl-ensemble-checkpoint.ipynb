# %% [markdown]
# # Ensemble averaging from NN and XGB

# %%
import os
import re
import numpy as np
import pandas as pd
import scipy
import sklearn.metrics as mtr
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import f1_score

import xgboost as xgb

from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization
from keras.models import Model
import keras.backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from keras.losses import binary_crossentropy
from keras.utils import to_categorical
import codecs
import datetime
import time

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %% [markdown]
# ## Preprocessing and Feature Engineering

# %%
# helper functions for data cleaning
# and feature engineering

def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"
    
def clean_turf_and_teams(train):
    
    ## Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)
    
    ## Teams
    Teams = {'ARI':'ARZ', 'BAL':'BLT', 'CLE':'CLV', 'HOU':'HST'}
    train['HomeTeamAbbr'] = train['HomeTeamAbbr'].map(Teams)
    train['VisitorTeamAbbr'] = train['VisitorTeamAbbr'].map(Teams)

    return train

# %%
# feature engineering (mainly rusher)
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense
    
    def rusher_features(df):
        
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Dir', 'S', 'A', 'X', 'Y']]
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS', 'RusherA', 'RusherX', 'RusherY']
        
       
        radian_angle = (90 - rusher['RusherDir']) * np.pi / 180.0
        v_horizontal = np.abs(rusher['RusherS'] * np.cos(radian_angle))
        v_vertical = np.abs(rusher['RusherS'] * np.sin(radian_angle)) 
        
       
        rusher['v_horizontal'] = v_horizontal
        rusher['v_vertical'] = v_vertical
        
        
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS','RusherA','RusherX', 'RusherY','v_horizontal', 'v_vertical']
        
        
        return rusher

    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))
        
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Weather
        df['GameWeather_process'] = df['GameWeather'].str.lower()
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
        df['GameWeather_dense'] = df['GameWeather_process'].apply(map_weather)
        add_new_feas.append("GameWeather_dense")
        
        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
    
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Quarter','Down','Distance','DefendersInTheBox']].drop_duplicates()

        static_features.fillna(-999,inplace=True)
       

        return static_features


    def combine_features(relative_to_back, defense,rushing, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,rushing,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    df = clean_turf_and_teams(df)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    rush_feats = rusher_features(df)
    static_feats = static_features(df)
    basetable = combine_features(rel_back, 
                                 def_feats,
                                 rush_feats,
                                 static_feats, 
                                 deploy=deploy)
    
    return basetable

# %%
# %time train_basetable = create_features(train, False)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 5min 11s, sys: 8.11 s, total: 5min 19s
# Wall time: 5min 18s

# %% [markdown]
# # Let's split our data into train/val for Neural Net (NN)

# %%
X = train_basetable.copy()
yards = X.Yards

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
print(X_train.shape, X_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# (19695, 37) (3476, 37)
# (19695, 199) (3476, 199)

# %% [markdown]
# # NN Model

# %%
class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
def get_model(x_tr,y_tr,x_val,y_val):
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(1024, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    #add lookahead
#     lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
#     lookahead.inject(model) # add into model

    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                                   save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    


    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
    crps = np.round(val_s, 6)

    return model,crps

# %%
losses = []
models = []
crps_csv = []

s_time = time.time()


for k in range(2):
    kfold = KFold(5, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print("-----------")
        tr_x,tr_y = X[tr_inds],y[tr_inds]
        val_x,val_y = X[val_inds],y[val_inds]
        model,crps = get_model(tr_x,tr_y,val_x,val_y)
        models.append(model)
        print("the %d fold crps is %f"%((k_fold+1),crps))
        crps_csv.append(crps)
 
print("mean crps is %f"%np.mean(crps_csv))


def predict_nn(x_te):
    model_num = len(models)
    for k,m in enumerate(models):
        if k==0:
            y_pred = m.predict(x_te,batch_size=1024)
        else:
            y_pred+=m.predict(x_te,batch_size=1024)
            
    y_pred = y_pred / model_num
    
    return y_pred
# Out:
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18536/18536 [==============================] - 2s 124us/step - loss: 5.5798
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08240, saving model to best_model.h5
# Epoch 2/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 5.0976
#
# Epoch 00002: CRPS_score_val improved from 0.08240 to 0.07803, saving model to best_model.h5
# Epoch 3/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 4.6736
#
# Epoch 00003: CRPS_score_val improved from 0.07803 to 0.06375, saving model to best_model.h5
# Epoch 4/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 4.2759
#
# Epoch 00004: CRPS_score_val improved from 0.06375 to 0.04221, saving model to best_model.h5
# Epoch 5/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 3.8948
#
# Epoch 00005: CRPS_score_val improved from 0.04221 to 0.02613, saving model to best_model.h5
# Epoch 6/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 3.5644
#
# Epoch 00006: CRPS_score_val improved from 0.02613 to 0.01835, saving model to best_model.h5
# Epoch 7/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 3.3023
#
# Epoch 00007: CRPS_score_val improved from 0.01835 to 0.01519, saving model to best_model.h5
# Epoch 8/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 3.1244
#
# Epoch 00008: CRPS_score_val improved from 0.01519 to 0.01414, saving model to best_model.h5
# Epoch 9/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 3.0032
#
# Epoch 00009: CRPS_score_val improved from 0.01414 to 0.01371, saving model to best_model.h5
# Epoch 10/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.9405
#
# Epoch 00010: CRPS_score_val improved from 0.01371 to 0.01346, saving model to best_model.h5
# Epoch 11/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.9016
#
# Epoch 00011: CRPS_score_val improved from 0.01346 to 0.01337, saving model to best_model.h5
# Epoch 12/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.8672
#
# Epoch 00012: CRPS_score_val improved from 0.01337 to 0.01330, saving model to best_model.h5
# Epoch 13/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.8408
#
# Epoch 00013: CRPS_score_val improved from 0.01330 to 0.01324, saving model to best_model.h5
# Epoch 14/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.8229
#
# Epoch 00014: CRPS_score_val improved from 0.01324 to 0.01319, saving model to best_model.h5
# Epoch 15/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.8059
#
# Epoch 00015: CRPS_score_val improved from 0.01319 to 0.01315, saving model to best_model.h5
# Epoch 16/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7929
#
# Epoch 00016: CRPS_score_val improved from 0.01315 to 0.01312, saving model to best_model.h5
# Epoch 17/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7787
#
# Epoch 00017: CRPS_score_val improved from 0.01312 to 0.01309, saving model to best_model.h5
# Epoch 18/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7708
#
# Epoch 00018: CRPS_score_val improved from 0.01309 to 0.01305, saving model to best_model.h5
# Epoch 19/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7609
#
# Epoch 00019: CRPS_score_val improved from 0.01305 to 0.01303, saving model to best_model.h5
# Epoch 20/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7567
#
# Epoch 00020: CRPS_score_val improved from 0.01303 to 0.01301, saving model to best_model.h5
# Epoch 21/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7440
#
# Epoch 00021: CRPS_score_val improved from 0.01301 to 0.01297, saving model to best_model.h5
# Epoch 22/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7409
#
# Epoch 00022: CRPS_score_val did not improve from 0.01297
# Epoch 23/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7263
#
# Epoch 00023: CRPS_score_val improved from 0.01297 to 0.01295, saving model to best_model.h5
# Epoch 24/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7307
#
# Epoch 00024: CRPS_score_val improved from 0.01295 to 0.01293, saving model to best_model.h5
# Epoch 25/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7223
#
# Epoch 00025: CRPS_score_val improved from 0.01293 to 0.01293, saving model to best_model.h5
# Epoch 26/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7177
#
# Epoch 00026: CRPS_score_val improved from 0.01293 to 0.01291, saving model to best_model.h5
# Epoch 27/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7134
#
# Epoch 00027: CRPS_score_val improved from 0.01291 to 0.01289, saving model to best_model.h5
# Epoch 28/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7143
#
# Epoch 00028: CRPS_score_val improved from 0.01289 to 0.01289, saving model to best_model.h5
# Epoch 29/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7103
#
# Epoch 00029: CRPS_score_val did not improve from 0.01289
# Epoch 30/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7029
#
# Epoch 00030: CRPS_score_val did not improve from 0.01289
# Epoch 31/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7015
#
# Epoch 00031: CRPS_score_val did not improve from 0.01289
# Epoch 32/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6927
#
# Epoch 00032: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 33/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6899
#
# Epoch 00033: CRPS_score_val improved from 0.01288 to 0.01286, saving model to best_model.h5
# Epoch 34/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6898
#
# Epoch 00034: CRPS_score_val did not improve from 0.01286
# Epoch 35/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6875
#
# Epoch 00035: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 36/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6884
#
# Epoch 00036: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 37/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6767
#
# Epoch 00037: CRPS_score_val did not improve from 0.01285
# Epoch 38/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6820
#
# Epoch 00038: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 39/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6785
#
# Epoch 00039: CRPS_score_val did not improve from 0.01284
# Epoch 40/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6732
#
# Epoch 00040: CRPS_score_val did not improve from 0.01284
# Epoch 41/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6733
#
# Epoch 00041: CRPS_score_val did not improve from 0.01284
# Epoch 42/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6716
#
# Epoch 00042: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 43/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6682
#
# Epoch 00043: CRPS_score_val did not improve from 0.01283
# Epoch 44/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6694
#
# Epoch 00044: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 45/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6620
#
# Epoch 00045: CRPS_score_val did not improve from 0.01282
# Epoch 46/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6627
#
# Epoch 00046: CRPS_score_val did not improve from 0.01282
# Epoch 47/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6615
#
# Epoch 00047: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 48/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6533
#
# Epoch 00048: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 49/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6511
#
# Epoch 00049: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 50/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6534
#
# Epoch 00050: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 51/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6534
#
# Epoch 00051: CRPS_score_val did not improve from 0.01279
# Epoch 52/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6430
#
# Epoch 00052: CRPS_score_val did not improve from 0.01279
# Epoch 53/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6434
#
# Epoch 00053: CRPS_score_val did not improve from 0.01279
# Epoch 54/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6417
#
# Epoch 00054: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 55/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6411
#
# Epoch 00055: CRPS_score_val did not improve from 0.01278
# Epoch 56/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6379
#
# Epoch 00056: CRPS_score_val did not improve from 0.01278
# Epoch 57/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6296
#
# Epoch 00057: CRPS_score_val did not improve from 0.01278
# Epoch 58/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6328
#
# Epoch 00058: CRPS_score_val did not improve from 0.01278
# Epoch 59/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6327
#
# Epoch 00059: CRPS_score_val did not improve from 0.01278
# Epoch 60/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6291
#
# Epoch 00060: CRPS_score_val did not improve from 0.01278
# Epoch 61/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6325
#
# Epoch 00061: CRPS_score_val did not improve from 0.01278
# Epoch 62/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6247
#
# Epoch 00062: CRPS_score_val did not improve from 0.01278
# Epoch 63/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6173
#
# Epoch 00063: CRPS_score_val did not improve from 0.01278
# Epoch 64/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6207
# Restoring model weights from the end of the best epoch
#
# Epoch 00064: CRPS_score_val did not improve from 0.01278
# Epoch 00064: early stopping
# the 1 fold crps is 0.012782
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 119us/step - loss: 5.5836
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08195, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 5.0989
#
# Epoch 00002: CRPS_score_val improved from 0.08195 to 0.07849, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 4.6840
#
# Epoch 00003: CRPS_score_val improved from 0.07849 to 0.06599, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 4.2924
#
# Epoch 00004: CRPS_score_val improved from 0.06599 to 0.04638, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.9111
#
# Epoch 00005: CRPS_score_val improved from 0.04638 to 0.02851, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 3.5779
#
# Epoch 00006: CRPS_score_val improved from 0.02851 to 0.02013, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.3131
#
# Epoch 00007: CRPS_score_val improved from 0.02013 to 0.01611, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.1306
#
# Epoch 00008: CRPS_score_val improved from 0.01611 to 0.01438, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.0061
#
# Epoch 00009: CRPS_score_val improved from 0.01438 to 0.01367, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.9284
#
# Epoch 00010: CRPS_score_val improved from 0.01367 to 0.01336, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.8798
#
# Epoch 00011: CRPS_score_val improved from 0.01336 to 0.01326, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8483
#
# Epoch 00012: CRPS_score_val improved from 0.01326 to 0.01317, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8228
#
# Epoch 00013: CRPS_score_val improved from 0.01317 to 0.01311, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8129
#
# Epoch 00014: CRPS_score_val improved from 0.01311 to 0.01307, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7927
#
# Epoch 00015: CRPS_score_val improved from 0.01307 to 0.01306, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7727
#
# Epoch 00016: CRPS_score_val improved from 0.01306 to 0.01302, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7732
#
# Epoch 00017: CRPS_score_val improved from 0.01302 to 0.01299, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7580
#
# Epoch 00018: CRPS_score_val improved from 0.01299 to 0.01296, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7546
#
# Epoch 00019: CRPS_score_val improved from 0.01296 to 0.01295, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7466
#
# Epoch 00020: CRPS_score_val improved from 0.01295 to 0.01293, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7376
#
# Epoch 00021: CRPS_score_val improved from 0.01293 to 0.01291, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7299
#
# Epoch 00022: CRPS_score_val improved from 0.01291 to 0.01287, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7257
#
# Epoch 00023: CRPS_score_val did not improve from 0.01287
# Epoch 24/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7171
#
# Epoch 00024: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7181
#
# Epoch 00025: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7129
#
# Epoch 00026: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7126
#
# Epoch 00027: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7069
#
# Epoch 00028: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7003
#
# Epoch 00029: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6976
#
# Epoch 00030: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6922
#
# Epoch 00031: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6863
#
# Epoch 00032: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6850
#
# Epoch 00033: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6845
#
# Epoch 00034: CRPS_score_val did not improve from 0.01280
# Epoch 35/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6844
#
# Epoch 00035: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6756
#
# Epoch 00036: CRPS_score_val improved from 0.01279 to 0.01279, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6748
#
# Epoch 00037: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6731
#
# Epoch 00038: CRPS_score_val improved from 0.01278 to 0.01278, saving model to best_model.h5
# Epoch 39/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6729
#
# Epoch 00039: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6653
#
# Epoch 00040: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6688
#
# Epoch 00041: CRPS_score_val did not improve from 0.01276
# Epoch 42/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6644
#
# Epoch 00042: CRPS_score_val did not improve from 0.01276
# Epoch 43/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6622
#
# Epoch 00043: CRPS_score_val did not improve from 0.01276
# Epoch 44/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6561
#
# Epoch 00044: CRPS_score_val did not improve from 0.01276
# Epoch 45/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6571
#
# Epoch 00045: CRPS_score_val improved from 0.01276 to 0.01276, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6531
#
# Epoch 00046: CRPS_score_val did not improve from 0.01276
# Epoch 47/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6499
#
# Epoch 00047: CRPS_score_val did not improve from 0.01276
# Epoch 48/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6429
#
# Epoch 00048: CRPS_score_val did not improve from 0.01276
# Epoch 49/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6499
#
# Epoch 00049: CRPS_score_val did not improve from 0.01276
# Epoch 50/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6485
#
# Epoch 00050: CRPS_score_val improved from 0.01276 to 0.01276, saving model to best_model.h5
# Epoch 51/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6401
#
# Epoch 00051: CRPS_score_val improved from 0.01276 to 0.01274, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6424
#
# Epoch 00052: CRPS_score_val did not improve from 0.01274
# Epoch 53/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6341
#
# Epoch 00053: CRPS_score_val did not improve from 0.01274
# Epoch 54/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6315
#
# Epoch 00054: CRPS_score_val did not improve from 0.01274
# Epoch 55/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6344
#
# Epoch 00055: CRPS_score_val did not improve from 0.01274
# Epoch 56/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6296
#
# Epoch 00056: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 57/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6291
#
# Epoch 00057: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# Epoch 58/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6256
#
# Epoch 00058: CRPS_score_val did not improve from 0.01273
# Epoch 59/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6232
#
# Epoch 00059: CRPS_score_val did not improve from 0.01273
# Epoch 60/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6218
#
# Epoch 00060: CRPS_score_val did not improve from 0.01273
# Epoch 61/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6223
#
# Epoch 00061: CRPS_score_val did not improve from 0.01273
# Epoch 62/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6140
#
# Epoch 00062: CRPS_score_val did not improve from 0.01273
# Epoch 63/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6180
#
# Epoch 00063: CRPS_score_val did not improve from 0.01273
# Epoch 64/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6099
#
# Epoch 00064: CRPS_score_val did not improve from 0.01273
# Epoch 65/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6152
#
# Epoch 00065: CRPS_score_val did not improve from 0.01273
# Epoch 66/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6084
#
# Epoch 00066: CRPS_score_val did not improve from 0.01273
# Epoch 67/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6069
# Restoring model weights from the end of the best epoch
#
# Epoch 00067: CRPS_score_val did not improve from 0.01273
# Epoch 00067: early stopping
# the 2 fold crps is 0.012725
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 121us/step - loss: 5.5702
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08148, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 5.0894
#
# Epoch 00002: CRPS_score_val improved from 0.08148 to 0.07760, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 4.6489
#
# Epoch 00003: CRPS_score_val improved from 0.07760 to 0.06374, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 4.2544
#
# Epoch 00004: CRPS_score_val improved from 0.06374 to 0.04442, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.8956
#
# Epoch 00005: CRPS_score_val improved from 0.04442 to 0.02771, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.5678
#
# Epoch 00006: CRPS_score_val improved from 0.02771 to 0.01965, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 3.3047
#
# Epoch 00007: CRPS_score_val improved from 0.01965 to 0.01570, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 3.1174
#
# Epoch 00008: CRPS_score_val improved from 0.01570 to 0.01409, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.0008
#
# Epoch 00009: CRPS_score_val improved from 0.01409 to 0.01355, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.9320
#
# Epoch 00010: CRPS_score_val improved from 0.01355 to 0.01328, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8962
#
# Epoch 00011: CRPS_score_val improved from 0.01328 to 0.01320, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.8524
#
# Epoch 00012: CRPS_score_val improved from 0.01320 to 0.01312, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8279
#
# Epoch 00013: CRPS_score_val improved from 0.01312 to 0.01306, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8081
#
# Epoch 00014: CRPS_score_val improved from 0.01306 to 0.01303, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7858
#
# Epoch 00015: CRPS_score_val improved from 0.01303 to 0.01299, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7832
#
# Epoch 00016: CRPS_score_val improved from 0.01299 to 0.01294, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7692
#
# Epoch 00017: CRPS_score_val improved from 0.01294 to 0.01292, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7671
#
# Epoch 00018: CRPS_score_val improved from 0.01292 to 0.01289, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7547
#
# Epoch 00019: CRPS_score_val improved from 0.01289 to 0.01287, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7430
#
# Epoch 00020: CRPS_score_val improved from 0.01287 to 0.01285, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7393
#
# Epoch 00021: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7285
#
# Epoch 00022: CRPS_score_val improved from 0.01285 to 0.01282, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7231
#
# Epoch 00023: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7205
#
# Epoch 00024: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7247
#
# Epoch 00025: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7152
#
# Epoch 00026: CRPS_score_val improved from 0.01279 to 0.01277, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7129
#
# Epoch 00027: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7075
#
# Epoch 00028: CRPS_score_val improved from 0.01277 to 0.01275, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7005
#
# Epoch 00029: CRPS_score_val improved from 0.01275 to 0.01273, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6980
#
# Epoch 00030: CRPS_score_val did not improve from 0.01273
# Epoch 31/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6961
#
# Epoch 00031: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6925
#
# Epoch 00032: CRPS_score_val did not improve from 0.01273
# Epoch 33/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6884
#
# Epoch 00033: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6825
#
# Epoch 00034: CRPS_score_val did not improve from 0.01272
# Epoch 35/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6808
#
# Epoch 00035: CRPS_score_val did not improve from 0.01272
# Epoch 36/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6816
#
# Epoch 00036: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6765
#
# Epoch 00037: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6773
#
# Epoch 00038: CRPS_score_val did not improve from 0.01270
# Epoch 39/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6746
#
# Epoch 00039: CRPS_score_val did not improve from 0.01270
# Epoch 40/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6653
#
# Epoch 00040: CRPS_score_val did not improve from 0.01270
# Epoch 41/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6658
#
# Epoch 00041: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6647
#
# Epoch 00042: CRPS_score_val did not improve from 0.01270
# Epoch 43/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6649
#
# Epoch 00043: CRPS_score_val did not improve from 0.01270
# Epoch 44/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6587
#
# Epoch 00044: CRPS_score_val did not improve from 0.01270
# Epoch 45/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6596
#
# Epoch 00045: CRPS_score_val did not improve from 0.01270
# Epoch 46/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6591
#
# Epoch 00046: CRPS_score_val did not improve from 0.01270
# Epoch 47/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6519
#
# Epoch 00047: CRPS_score_val did not improve from 0.01270
# Epoch 48/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6560
#
# Epoch 00048: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 49/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6542
#
# Epoch 00049: CRPS_score_val did not improve from 0.01269
# Epoch 50/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 2.6474
#
# Epoch 00050: CRPS_score_val did not improve from 0.01269
# Epoch 51/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6502
#
# Epoch 00051: CRPS_score_val did not improve from 0.01269
# Epoch 52/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6401
#
# Epoch 00052: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 53/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6426
#
# Epoch 00053: CRPS_score_val did not improve from 0.01268
# Epoch 54/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6332
#
# Epoch 00054: CRPS_score_val did not improve from 0.01268
# Epoch 55/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6303
#
# Epoch 00055: CRPS_score_val did not improve from 0.01268
# Epoch 56/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6346
#
# Epoch 00056: CRPS_score_val did not improve from 0.01268
# Epoch 57/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 2.6313
#
# Epoch 00057: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 58/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 2.6315
#
# Epoch 00058: CRPS_score_val did not improve from 0.01267
# Epoch 59/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6289
#
# Epoch 00059: CRPS_score_val did not improve from 0.01267
# Epoch 60/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6262
#
# Epoch 00060: CRPS_score_val did not improve from 0.01267
# Epoch 61/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6218
#
# Epoch 00061: CRPS_score_val did not improve from 0.01267
# Epoch 62/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6235
#
# Epoch 00062: CRPS_score_val did not improve from 0.01267
# Epoch 63/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6231
#
# Epoch 00063: CRPS_score_val did not improve from 0.01267
# Epoch 64/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6225
#
# Epoch 00064: CRPS_score_val did not improve from 0.01267
# Epoch 65/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6137
#
# Epoch 00065: CRPS_score_val did not improve from 0.01267
# Epoch 66/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6093
#
# Epoch 00066: CRPS_score_val did not improve from 0.01267
# Epoch 67/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6047
# Restoring model weights from the end of the best epoch
#
# Epoch 00067: CRPS_score_val did not improve from 0.01267
# Epoch 00067: early stopping
# the 3 fold crps is 0.012669
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 126us/step - loss: 5.6122
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08194, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 5.1482
#
# Epoch 00002: CRPS_score_val improved from 0.08194 to 0.07834, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 4.7283
#
# Epoch 00003: CRPS_score_val improved from 0.07834 to 0.06567, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 4.3207
#
# Epoch 00004: CRPS_score_val improved from 0.06567 to 0.04526, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.9321
#
# Epoch 00005: CRPS_score_val improved from 0.04526 to 0.02799, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.5953
#
# Epoch 00006: CRPS_score_val improved from 0.02799 to 0.01993, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 3.3047
#
# Epoch 00007: CRPS_score_val improved from 0.01993 to 0.01554, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.1284
#
# Epoch 00008: CRPS_score_val improved from 0.01554 to 0.01419, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.9994
#
# Epoch 00009: CRPS_score_val improved from 0.01419 to 0.01344, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.9279
#
# Epoch 00010: CRPS_score_val improved from 0.01344 to 0.01320, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8880
#
# Epoch 00011: CRPS_score_val improved from 0.01320 to 0.01308, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.8492
#
# Epoch 00012: CRPS_score_val improved from 0.01308 to 0.01300, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.8262
#
# Epoch 00013: CRPS_score_val improved from 0.01300 to 0.01296, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.8195
#
# Epoch 00014: CRPS_score_val improved from 0.01296 to 0.01291, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7966
#
# Epoch 00015: CRPS_score_val improved from 0.01291 to 0.01288, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7852
#
# Epoch 00016: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7726
#
# Epoch 00017: CRPS_score_val improved from 0.01287 to 0.01283, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7623
#
# Epoch 00018: CRPS_score_val did not improve from 0.01283
# Epoch 19/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7501
#
# Epoch 00019: CRPS_score_val improved from 0.01283 to 0.01279, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7440
#
# Epoch 00020: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7360
#
# Epoch 00021: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7285
#
# Epoch 00022: CRPS_score_val improved from 0.01277 to 0.01275, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7295
#
# Epoch 00023: CRPS_score_val improved from 0.01275 to 0.01273, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7220
#
# Epoch 00024: CRPS_score_val improved from 0.01273 to 0.01271, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7198
#
# Epoch 00025: CRPS_score_val did not improve from 0.01271
# Epoch 26/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7194
#
# Epoch 00026: CRPS_score_val improved from 0.01271 to 0.01271, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7020
#
# Epoch 00027: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6985
#
# Epoch 00028: CRPS_score_val improved from 0.01270 to 0.01268, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7050
#
# Epoch 00029: CRPS_score_val did not improve from 0.01268
# Epoch 30/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7004
#
# Epoch 00030: CRPS_score_val did not improve from 0.01268
# Epoch 31/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6968
#
# Epoch 00031: CRPS_score_val improved from 0.01268 to 0.01266, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6916
#
# Epoch 00032: CRPS_score_val did not improve from 0.01266
# Epoch 33/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6829
#
# Epoch 00033: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6844
#
# Epoch 00034: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6751
#
# Epoch 00035: CRPS_score_val improved from 0.01265 to 0.01265, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6797
#
# Epoch 00036: CRPS_score_val did not improve from 0.01265
# Epoch 37/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6797
#
# Epoch 00037: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6707
#
# Epoch 00038: CRPS_score_val did not improve from 0.01264
# Epoch 39/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6748
#
# Epoch 00039: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6721
#
# Epoch 00040: CRPS_score_val improved from 0.01264 to 0.01263, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6699
#
# Epoch 00041: CRPS_score_val improved from 0.01263 to 0.01263, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6703
#
# Epoch 00042: CRPS_score_val improved from 0.01263 to 0.01261, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6639
#
# Epoch 00043: CRPS_score_val did not improve from 0.01261
# Epoch 44/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6553
#
# Epoch 00044: CRPS_score_val did not improve from 0.01261
# Epoch 45/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6574
#
# Epoch 00045: CRPS_score_val did not improve from 0.01261
# Epoch 46/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6547
#
# Epoch 00046: CRPS_score_val did not improve from 0.01261
# Epoch 47/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6519
#
# Epoch 00047: CRPS_score_val did not improve from 0.01261
# Epoch 48/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6482
#
# Epoch 00048: CRPS_score_val improved from 0.01261 to 0.01261, saving model to best_model.h5
# Epoch 49/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6513
#
# Epoch 00049: CRPS_score_val improved from 0.01261 to 0.01261, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6466
#
# Epoch 00050: CRPS_score_val did not improve from 0.01261
# Epoch 51/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6412
#
# Epoch 00051: CRPS_score_val did not improve from 0.01261
# Epoch 52/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6458
#
# Epoch 00052: CRPS_score_val did not improve from 0.01261
# Epoch 53/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6404
#
# Epoch 00053: CRPS_score_val did not improve from 0.01261
# Epoch 54/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6349
#
# Epoch 00054: CRPS_score_val did not improve from 0.01261
# Epoch 55/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6347
#
# Epoch 00055: CRPS_score_val did not improve from 0.01261
# Epoch 56/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6319
#
# Epoch 00056: CRPS_score_val did not improve from 0.01261
# Epoch 57/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6331
#
# Epoch 00057: CRPS_score_val did not improve from 0.01261
# Epoch 58/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6264
#
# Epoch 00058: CRPS_score_val improved from 0.01261 to 0.01260, saving model to best_model.h5
# Epoch 59/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6276
#
# Epoch 00059: CRPS_score_val did not improve from 0.01260
# Epoch 60/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6214
#
# Epoch 00060: CRPS_score_val improved from 0.01260 to 0.01260, saving model to best_model.h5
# Epoch 61/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6195
#
# Epoch 00061: CRPS_score_val did not improve from 0.01260
# Epoch 62/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6194
#
# Epoch 00062: CRPS_score_val did not improve from 0.01260
# Epoch 63/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6111
#
# Epoch 00063: CRPS_score_val did not improve from 0.01260
# Epoch 64/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6173
#
# Epoch 00064: CRPS_score_val did not improve from 0.01260
# Epoch 65/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6113
#
# Epoch 00065: CRPS_score_val did not improve from 0.01260
# Epoch 66/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6086
#
# Epoch 00066: CRPS_score_val did not improve from 0.01260
# Epoch 67/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6107
#
# Epoch 00067: CRPS_score_val did not improve from 0.01260
# Epoch 68/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6073
#
# Epoch 00068: CRPS_score_val did not improve from 0.01260
# Epoch 69/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6052
#
# Epoch 00069: CRPS_score_val did not improve from 0.01260
# Epoch 70/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6023
# Restoring model weights from the end of the best epoch
#
# Epoch 00070: CRPS_score_val did not improve from 0.01260
# Epoch 00070: early stopping
# the 4 fold crps is 0.012599
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 129us/step - loss: 5.5819
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08243, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 5.0867
#
# Epoch 00002: CRPS_score_val improved from 0.08243 to 0.07756, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 4.6698
#
# Epoch 00003: CRPS_score_val improved from 0.07756 to 0.06341, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 4.2642
#
# Epoch 00004: CRPS_score_val improved from 0.06341 to 0.04305, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.8874
#
# Epoch 00005: CRPS_score_val improved from 0.04305 to 0.02694, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.5692
#
# Epoch 00006: CRPS_score_val improved from 0.02694 to 0.01875, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.2972
#
# Epoch 00007: CRPS_score_val improved from 0.01875 to 0.01562, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.1252
#
# Epoch 00008: CRPS_score_val improved from 0.01562 to 0.01446, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.0209
#
# Epoch 00009: CRPS_score_val improved from 0.01446 to 0.01394, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.9393
#
# Epoch 00010: CRPS_score_val improved from 0.01394 to 0.01367, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.8996
#
# Epoch 00011: CRPS_score_val improved from 0.01367 to 0.01360, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8601
#
# Epoch 00012: CRPS_score_val improved from 0.01360 to 0.01350, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.8350
#
# Epoch 00013: CRPS_score_val improved from 0.01350 to 0.01346, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8155
#
# Epoch 00014: CRPS_score_val improved from 0.01346 to 0.01339, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8048
#
# Epoch 00015: CRPS_score_val improved from 0.01339 to 0.01337, saving model to best_model.h5
# Epoch 16/100
# ...
# Epoch 45/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6524
#
# Epoch 00045: CRPS_score_val did not improve from 0.01336
# Epoch 46/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6589
#
# Epoch 00046: CRPS_score_val improved from 0.01336 to 0.01335, saving model to best_model.h5
# Epoch 47/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6528
#
# Epoch 00047: CRPS_score_val did not improve from 0.01335
# Epoch 48/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6506
#
# Epoch 00048: CRPS_score_val improved from 0.01335 to 0.01335, saving model to best_model.h5
# Epoch 49/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6491
#
# Epoch 00049: CRPS_score_val did not improve from 0.01335
# Epoch 50/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6453
#
# Epoch 00050: CRPS_score_val did not improve from 0.01335
# Epoch 51/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6420
#
# Epoch 00051: CRPS_score_val did not improve from 0.01335
# Epoch 52/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6445
#
# Epoch 00052: CRPS_score_val did not improve from 0.01335
# Epoch 53/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6397
#
# Epoch 00053: CRPS_score_val improved from 0.01335 to 0.01334, saving model to best_model.h5
# Epoch 54/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6362
#
# Epoch 00054: CRPS_score_val did not improve from 0.01334
# Epoch 55/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6329
#
# Epoch 00055: CRPS_score_val did not improve from 0.01334
# Epoch 56/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6270
#
# Epoch 00056: CRPS_score_val did not improve from 0.01334
# Epoch 57/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6288
#
# Epoch 00057: CRPS_score_val did not improve from 0.01334
# Epoch 58/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6295
#
# Epoch 00058: CRPS_score_val did not improve from 0.01334
# Epoch 59/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6266
#
# Epoch 00059: CRPS_score_val did not improve from 0.01334
# Epoch 60/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6198
#
# Epoch 00060: CRPS_score_val improved from 0.01334 to 0.01334, saving model to best_model.h5
# Epoch 61/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6230
#
# Epoch 00061: CRPS_score_val improved from 0.01334 to 0.01334, saving model to best_model.h5
# Epoch 62/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6174
#
# Epoch 00062: CRPS_score_val did not improve from 0.01334
# Epoch 63/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6167
#
# Epoch 00063: CRPS_score_val improved from 0.01334 to 0.01333, saving model to best_model.h5
# Epoch 64/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6114
#
# Epoch 00064: CRPS_score_val did not improve from 0.01333
# Epoch 65/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6095
#
# Epoch 00065: CRPS_score_val did not improve from 0.01333
# Epoch 66/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6093
#
# Epoch 00066: CRPS_score_val did not improve from 0.01333
# Epoch 67/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6075
#
# Epoch 00067: CRPS_score_val improved from 0.01333 to 0.01333, saving model to best_model.h5
# Epoch 68/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6093
#
# Epoch 00068: CRPS_score_val did not improve from 0.01333
# Epoch 69/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6017
#
# Epoch 00069: CRPS_score_val did not improve from 0.01333
# Epoch 70/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5998
#
# Epoch 00070: CRPS_score_val did not improve from 0.01333
# Epoch 71/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.5939
#
# Epoch 00071: CRPS_score_val did not improve from 0.01333
# Epoch 72/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.5942
#
# Epoch 00072: CRPS_score_val did not improve from 0.01333
# Epoch 73/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.5969
#
# Epoch 00073: CRPS_score_val did not improve from 0.01333
# Epoch 74/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.5909
#
# Epoch 00074: CRPS_score_val did not improve from 0.01333
# Epoch 75/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.5962
#
# Epoch 00075: CRPS_score_val did not improve from 0.01333
# Epoch 76/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.5836
#
# Epoch 00076: CRPS_score_val did not improve from 0.01333
# Epoch 77/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.5839
# Restoring model weights from the end of the best epoch
#
# Epoch 00077: CRPS_score_val did not improve from 0.01333
# Epoch 00077: early stopping
# the 4 fold crps is 0.013330
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 152us/step - loss: 5.5911
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08174, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 5.0974
#
# Epoch 00002: CRPS_score_val improved from 0.08174 to 0.07722, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 4.6800
#
# Epoch 00003: CRPS_score_val improved from 0.07722 to 0.06438, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 4.2904
#
# Epoch 00004: CRPS_score_val improved from 0.06438 to 0.04413, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.9058
#
# Epoch 00005: CRPS_score_val improved from 0.04413 to 0.02723, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.5855
#
# Epoch 00006: CRPS_score_val improved from 0.02723 to 0.01881, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 3.3088
#
# Epoch 00007: CRPS_score_val improved from 0.01881 to 0.01537, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.1305
#
# Epoch 00008: CRPS_score_val improved from 0.01537 to 0.01386, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.0072
#
# Epoch 00009: CRPS_score_val improved from 0.01386 to 0.01344, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.9405
#
# Epoch 00010: CRPS_score_val improved from 0.01344 to 0.01327, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8855
#
# Epoch 00011: CRPS_score_val improved from 0.01327 to 0.01317, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.8639
#
# Epoch 00012: CRPS_score_val improved from 0.01317 to 0.01308, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8373
#
# Epoch 00013: CRPS_score_val improved from 0.01308 to 0.01303, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8124
#
# Epoch 00014: CRPS_score_val improved from 0.01303 to 0.01302, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7946
#
# Epoch 00015: CRPS_score_val improved from 0.01302 to 0.01294, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7811
#
# Epoch 00016: CRPS_score_val improved from 0.01294 to 0.01292, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7738
#
# Epoch 00017: CRPS_score_val improved from 0.01292 to 0.01289, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.7702
#
# Epoch 00018: CRPS_score_val improved from 0.01289 to 0.01287, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7489
#
# Epoch 00019: CRPS_score_val improved from 0.01287 to 0.01285, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.7483
#
# Epoch 00020: CRPS_score_val improved from 0.01285 to 0.01282, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7461
#
# Epoch 00021: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7346
#
# Epoch 00022: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7305
#
# Epoch 00023: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7232
#
# Epoch 00024: CRPS_score_val improved from 0.01279 to 0.01277, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7197
#
# Epoch 00025: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7135
#
# Epoch 00026: CRPS_score_val improved from 0.01276 to 0.01276, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7108
#
# Epoch 00027: CRPS_score_val improved from 0.01276 to 0.01274, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7042
#
# Epoch 00028: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7038
#
# Epoch 00029: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6948
#
# Epoch 00030: CRPS_score_val did not improve from 0.01272
# Epoch 31/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6957
#
# Epoch 00031: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6946
#
# Epoch 00032: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6899
#
# Epoch 00033: CRPS_score_val did not improve from 0.01270
# Epoch 34/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6843
#
# Epoch 00034: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6838
#
# Epoch 00035: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6801
#
# Epoch 00036: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6784
#
# Epoch 00037: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6784
#
# Epoch 00038: CRPS_score_val improved from 0.01269 to 0.01267, saving model to best_model.h5
# Epoch 39/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6739
#
# Epoch 00039: CRPS_score_val did not improve from 0.01267
# Epoch 40/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6737
#
# Epoch 00040: CRPS_score_val did not improve from 0.01267
# Epoch 41/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6707
#
# Epoch 00041: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6649
#
# Epoch 00042: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6634
#
# Epoch 00043: CRPS_score_val did not improve from 0.01266
# Epoch 44/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6564
#
# Epoch 00044: CRPS_score_val did not improve from 0.01266
# Epoch 45/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6573
#
# Epoch 00045: CRPS_score_val did not improve from 0.01266
# Epoch 46/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6547
#
# Epoch 00046: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 47/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6556
#
# Epoch 00047: CRPS_score_val did not improve from 0.01265
# Epoch 48/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6470
#
# Epoch 00048: CRPS_score_val did not improve from 0.01265
# Epoch 49/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6518
#
# Epoch 00049: CRPS_score_val did not improve from 0.01265
# Epoch 50/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6494
#
# Epoch 00050: CRPS_score_val did not improve from 0.01265
# Epoch 51/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6444
#
# Epoch 00051: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6407
#
# Epoch 00052: CRPS_score_val did not improve from 0.01264
# Epoch 53/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6396
#
# Epoch 00053: CRPS_score_val improved from 0.01264 to 0.01263, saving model to best_model.h5
# Epoch 54/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6382
#
# Epoch 00054: CRPS_score_val did not improve from 0.01263
# Epoch 55/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6366
#
# Epoch 00055: CRPS_score_val did not improve from 0.01263
# Epoch 56/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6308
#
# Epoch 00056: CRPS_score_val did not improve from 0.01263
# Epoch 57/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6360
#
# Epoch 00057: CRPS_score_val did not improve from 0.01263
# Epoch 58/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6268
#
# Epoch 00058: CRPS_score_val did not improve from 0.01263
# Epoch 59/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6284
#
# Epoch 00059: CRPS_score_val did not improve from 0.01263
# Epoch 60/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6222
#
# Epoch 00060: CRPS_score_val did not improve from 0.01263
# Epoch 61/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6182
#
# Epoch 00061: CRPS_score_val did not improve from 0.01263
# Epoch 62/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6167
#
# Epoch 00062: CRPS_score_val did not improve from 0.01263
# Epoch 63/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6171
# Restoring model weights from the end of the best epoch
#
# Epoch 00063: CRPS_score_val did not improve from 0.01263
# Epoch 00063: early stopping
# the 5 fold crps is 0.012627
# mean crps is 0.012762

# %%
print("mean crps is %f"%np.mean(crps_csv))
# Out:
# mean crps is 0.012762

# %% [markdown]
# # XGBoost Model

# %%
# split in train and validation in case no api for cross validation exists
y = yards.copy()
y = y.to_numpy()
target = y[np.arange(0, len(X_train), 22)]
standard_deviation = np.std(target)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
# train xgboost
kf = KFold(n_splits=5, shuffle=True, random_state=42)
n_estim = 150
for train_index, val_index in kf.split(X):
    print('----------')
    xgb_model = xgb.XGBRegressor(n_estimators=n_estim, verbosity=1).fit(X[train_index], y[train_index])
    y_pred = xgb_model.predict(X[val_index])
    y_act = y[val_index]
    err = mtr.mean_squared_error(y_act, y_pred)
    print("MSE: ", err)
# Out:
# ----------
# [18:43:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE:  42.68614674220218
# ----------
# [18:43:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE:  36.23686561214618
# ----------
# [18:43:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE:  37.073210825689756
# ----------
# [18:43:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE:  37.28947128587238
# ----------
# [18:43:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE:  39.96090443049378

# %% [markdown]
# # Model averaging and actual submission

# %%
def to_cumulative_df(df_pred):
    df_pred_first = df_pred[0]
    pred_df = np.zeros((1, 199))

    for col_i in range(len(pred_df[0])):
        current_cdf = scipy.stats.norm(loc = df_pred_first, scale = standard_deviation).cdf(col_i-99)
        pred_df[0][col_i] = current_cdf
    return pred_df.tolist()[0]

# %%
def avg_model_preds(mod_1_pred, mod_2_pred, n_models):
    # average element wise
    avg_list = []
    for i in range(0, 199):
        avg_list.append(((mod_1_pred[i]+mod_2_pred[i])/n_models))
    
    return avg_list

# %%
# %%time
# make submission
# env can only be created once and kernel needs
# to be restarted on > first run
from kaggle.competitions import nflrush
env = nflrush.make_env()
iter_test = env.iter_test()

for (test_df, sample_prediction_df) in iter_test:
    basetable = create_features(test_df, deploy=True)
    basetable.drop(['GameId','PlayId'], axis=1, inplace=True)
    scaled_basetable = scaler.transform(basetable)

    # make cummulative predictions from NN model
    y_pred_nn = predict_nn(scaled_basetable)
    y_pred_nn = np.clip(np.cumsum(y_pred_nn, axis=1), 0, 1).tolist()[0]
    # make cummulative predictions from XGB model
    y_pred_xgb = xgb_model.predict(scaled_basetable)
    y_pred_xgb = to_cumulative_df(y_pred_xgb)
    # average of cummulative predictions
    y_pred_final = avg_model_preds(y_pred_nn, y_pred_xgb, 2)
    
    preds_df = pd.DataFrame(data=[y_pred_final], columns=sample_prediction_df.columns)
    env.predict(preds_df)

env.write_submission_file()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.
# CPU times: user 25min 2s, sys: 40.8 s, total: 25min 43s
# Wall time: 24min 32s
