# %%
import os
# os.environ['CUDA_VISIBLE_DEVICES'] = "1"

import numpy as np
import pandas as pd
import sklearn.metrics as mtr
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization
from keras.models import Model
import keras.backend as K
from keras.callbacks import Callback
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import datetime

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %% [markdown]
# ## Preprocessing and Feature Engineering

# %%
# helper functions for data cleaning
# and feature engineering

def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"
    
def clean_turf_and_teams(train):
    
    ## Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)
    
    ## Teams
    Teams = {'ARI':'ARZ', 'BAL':'BLT', 'CLE':'CLV', 'HOU':'HST'}
    train['HomeTeamAbbr'] = train['HomeTeamAbbr'].map(Teams)
    train['VisitorTeamAbbr'] = train['VisitorTeamAbbr'].map(Teams)

    return train

# %%
# feature engineering (mainly rusher)
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense
    
    def rusher_features(df):
        
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Dir', 'S', 'A', 'X', 'Y']]
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS', 'RusherA', 'RusherX', 'RusherY']
        
       
        radian_angle = (90 - rusher['RusherDir']) * np.pi / 180.0
        v_horizontal = np.abs(rusher['RusherS'] * np.cos(radian_angle))
        v_vertical = np.abs(rusher['RusherS'] * np.sin(radian_angle)) 
        
       
        rusher['v_horizontal'] = v_horizontal
        rusher['v_vertical'] = v_vertical
        
        
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS','RusherA','RusherX', 'RusherY','v_horizontal', 'v_vertical']
        
        
        return rusher

    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))
        
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Weather
        df['GameWeather_process'] = df['GameWeather'].str.lower()
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
        df['GameWeather_dense'] = df['GameWeather_process'].apply(map_weather)
        add_new_feas.append("GameWeather_dense")
        
        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
    
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Quarter','Down','Distance','DefendersInTheBox']].drop_duplicates()

        static_features.fillna(-999,inplace=True)
       

        return static_features


    def combine_features(relative_to_back, defense,rushing, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,rushing,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    df = clean_turf_and_teams(df)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    rush_feats = rusher_features(df)
    static_feats = static_features(df)
    basetable = combine_features(rel_back, 
                                 def_feats,
                                 rush_feats,
                                 static_feats, 
                                 deploy=deploy)
    
    return basetable

# %%
# %time train_basetable = create_features(train, False)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 5min 13s, sys: 5.37 s, total: 5min 19s
# Wall time: 5min 18s

# %% [markdown]
# # Let's split our data into train/val

# %%
X = train_basetable.copy()
yards = X.Yards

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.20, random_state=12345)

# %%
print(X_train.shape, X_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# (18536, 37) (4635, 37)
# (18536, 199) (4635, 199)

# %% [markdown]
# # Let's build NN

# %%
from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda
from keras.models import Model
import keras.backend as K
import re
from keras.losses import binary_crossentropy
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import codecs

from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from sklearn.metrics import f1_score




class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
def get_model(x_tr,y_tr,x_val,y_val):
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(1024, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    #add lookahead
#     lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
#     lookahead.inject(model) # add into model

    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                                   save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    


    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
    crps = np.round(val_s, 6)

    return model,crps

# %%
from sklearn.model_selection import train_test_split, KFold
import time

losses = []
models = []
crps_csv = []

s_time = time.time()


for k in range(2):
    kfold = KFold(5, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print("-----------")
        tr_x,tr_y = X[tr_inds],y[tr_inds]
        val_x,val_y = X[val_inds],y[val_inds]
        model,crps = get_model(tr_x,tr_y,val_x,val_y)
        models.append(model)
        print("the %d fold crps is %f"%((k_fold+1),crps))
        crps_csv.append(crps)
 
print("mean crps is %f"%np.mean(crps_csv))


def predict(x_te):
    model_num = len(models)
    for k,m in enumerate(models):
        if k==0:
            y_pred = m.predict(x_te,batch_size=1024)
        else:
            y_pred+=m.predict(x_te,batch_size=1024)
            
    y_pred = y_pred / model_num
    
    return y_pred
# Out:
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18536/18536 [==============================] - 2s 127us/step - loss: 5.5727
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08297, saving model to best_model.h5
# Epoch 2/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 5.0722
#
# Epoch 00002: CRPS_score_val improved from 0.08297 to 0.07794, saving model to best_model.h5
# Epoch 3/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 4.6681
#
# Epoch 00003: CRPS_score_val improved from 0.07794 to 0.06360, saving model to best_model.h5
# Epoch 4/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 4.2869
#
# Epoch 00004: CRPS_score_val improved from 0.06360 to 0.04355, saving model to best_model.h5
# Epoch 5/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 3.9080
#
# Epoch 00005: CRPS_score_val improved from 0.04355 to 0.02727, saving model to best_model.h5
# Epoch 6/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 3.5833
#
# Epoch 00006: CRPS_score_val improved from 0.02727 to 0.01913, saving model to best_model.h5
# Epoch 7/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 3.3133
#
# Epoch 00007: CRPS_score_val improved from 0.01913 to 0.01566, saving model to best_model.h5
# Epoch 8/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 3.1357
#
# Epoch 00008: CRPS_score_val improved from 0.01566 to 0.01436, saving model to best_model.h5
# Epoch 9/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 3.0188
#
# Epoch 00009: CRPS_score_val improved from 0.01436 to 0.01370, saving model to best_model.h5
# Epoch 10/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.9454
#
# Epoch 00010: CRPS_score_val improved from 0.01370 to 0.01345, saving model to best_model.h5
# Epoch 11/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.9011
#
# Epoch 00011: CRPS_score_val improved from 0.01345 to 0.01337, saving model to best_model.h5
# Epoch 12/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.8673
#
# Epoch 00012: CRPS_score_val improved from 0.01337 to 0.01330, saving model to best_model.h5
# Epoch 13/100
# 18536/18536 [==============================] - 2s 84us/step - loss: 2.8485
#
# Epoch 00013: CRPS_score_val improved from 0.01330 to 0.01324, saving model to best_model.h5
# Epoch 14/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.8236
#
# Epoch 00014: CRPS_score_val improved from 0.01324 to 0.01320, saving model to best_model.h5
# Epoch 15/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.8080
#
# Epoch 00015: CRPS_score_val improved from 0.01320 to 0.01315, saving model to best_model.h5
# Epoch 16/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.7861
#
# Epoch 00016: CRPS_score_val improved from 0.01315 to 0.01312, saving model to best_model.h5
# Epoch 17/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.7794
#
# Epoch 00017: CRPS_score_val improved from 0.01312 to 0.01309, saving model to best_model.h5
# Epoch 18/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.7745
#
# Epoch 00018: CRPS_score_val improved from 0.01309 to 0.01307, saving model to best_model.h5
# Epoch 19/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.7576
#
# Epoch 00019: CRPS_score_val improved from 0.01307 to 0.01304, saving model to best_model.h5
# Epoch 20/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.7563
#
# Epoch 00020: CRPS_score_val improved from 0.01304 to 0.01300, saving model to best_model.h5
# Epoch 21/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.7471
#
# Epoch 00021: CRPS_score_val improved from 0.01300 to 0.01298, saving model to best_model.h5
# Epoch 22/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.7413
#
# Epoch 00022: CRPS_score_val improved from 0.01298 to 0.01298, saving model to best_model.h5
# Epoch 23/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.7329
#
# Epoch 00023: CRPS_score_val improved from 0.01298 to 0.01297, saving model to best_model.h5
# Epoch 24/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.7290
#
# Epoch 00024: CRPS_score_val improved from 0.01297 to 0.01297, saving model to best_model.h5
# Epoch 25/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.7181
#
# Epoch 00025: CRPS_score_val improved from 0.01297 to 0.01294, saving model to best_model.h5
# Epoch 26/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.7179
#
# Epoch 00026: CRPS_score_val did not improve from 0.01294
# Epoch 27/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.7118
#
# Epoch 00027: CRPS_score_val improved from 0.01294 to 0.01293, saving model to best_model.h5
# Epoch 28/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.7053
#
# Epoch 00028: CRPS_score_val improved from 0.01293 to 0.01292, saving model to best_model.h5
# Epoch 29/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.7008
#
# Epoch 00029: CRPS_score_val improved from 0.01292 to 0.01290, saving model to best_model.h5
# Epoch 30/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.7013
#
# Epoch 00030: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 31/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.7001
#
# Epoch 00031: CRPS_score_val did not improve from 0.01289
# Epoch 32/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.6985
#
# Epoch 00032: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 33/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6904
#
# Epoch 00033: CRPS_score_val did not improve from 0.01288
# Epoch 34/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6926
#
# Epoch 00034: CRPS_score_val did not improve from 0.01288
# Epoch 35/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6841
#
# Epoch 00035: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 36/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6829
#
# Epoch 00036: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 37/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6841
#
# Epoch 00037: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 38/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6784
#
# Epoch 00038: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 39/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6742
#
# Epoch 00039: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 40/100
# 18536/18536 [==============================] - 2s 84us/step - loss: 2.6777
#
# Epoch 00040: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 41/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6713
#
# Epoch 00041: CRPS_score_val improved from 0.01284 to 0.01284, saving model to best_model.h5
# Epoch 42/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6667
#
# Epoch 00042: CRPS_score_val improved from 0.01284 to 0.01282, saving model to best_model.h5
# Epoch 43/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6642
#
# Epoch 00043: CRPS_score_val did not improve from 0.01282
# Epoch 44/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6640
#
# Epoch 00044: CRPS_score_val did not improve from 0.01282
# Epoch 45/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6605
#
# Epoch 00045: CRPS_score_val did not improve from 0.01282
# Epoch 46/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6564
#
# Epoch 00046: CRPS_score_val did not improve from 0.01282
# Epoch 47/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.6578
#
# Epoch 00047: CRPS_score_val did not improve from 0.01282
# Epoch 48/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6517
#
# Epoch 00048: CRPS_score_val did not improve from 0.01282
# Epoch 49/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6536
#
# Epoch 00049: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 50/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6484
#
# Epoch 00050: CRPS_score_val did not improve from 0.01282
# Epoch 51/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6442
#
# Epoch 00051: CRPS_score_val did not improve from 0.01282
# Epoch 52/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.6432
#
# Epoch 00052: CRPS_score_val did not improve from 0.01282
# Epoch 53/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6406
#
# Epoch 00053: CRPS_score_val did not improve from 0.01282
# Epoch 54/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6386
#
# Epoch 00054: CRPS_score_val did not improve from 0.01282
# Epoch 55/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6344
#
# Epoch 00055: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 56/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6371
#
# Epoch 00056: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 57/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6339
#
# Epoch 00057: CRPS_score_val did not improve from 0.01281
# Epoch 58/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.6298
#
# Epoch 00058: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 59/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6304
#
# Epoch 00059: CRPS_score_val did not improve from 0.01281
# Epoch 60/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6291
#
# Epoch 00060: CRPS_score_val did not improve from 0.01281
# Epoch 61/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6216
#
# Epoch 00061: CRPS_score_val did not improve from 0.01281
# Epoch 62/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6192
#
# Epoch 00062: CRPS_score_val did not improve from 0.01281
# Epoch 63/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6185
#
# Epoch 00063: CRPS_score_val did not improve from 0.01281
# Epoch 64/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6184
#
# Epoch 00064: CRPS_score_val did not improve from 0.01281
# Epoch 65/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6137
#
# Epoch 00065: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 66/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6109
#
# Epoch 00066: CRPS_score_val did not improve from 0.01281
# Epoch 67/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6100
#
# Epoch 00067: CRPS_score_val did not improve from 0.01281
# Epoch 68/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6107
#
# Epoch 00068: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 69/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6056
#
# Epoch 00069: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 70/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6104
#
# Epoch 00070: CRPS_score_val did not improve from 0.01279
# Epoch 71/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6050
#
# Epoch 00071: CRPS_score_val improved from 0.01279 to 0.01279, saving model to best_model.h5
# Epoch 72/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.6005
#
# Epoch 00072: CRPS_score_val did not improve from 0.01279
# Epoch 73/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6009
#
# Epoch 00073: CRPS_score_val did not improve from 0.01279
# Epoch 74/100
# 18536/18536 [==============================] - 1s 81us/step - loss: 2.6000
#
# Epoch 00074: CRPS_score_val did not improve from 0.01279
# Epoch 75/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.5919
#
# Epoch 00075: CRPS_score_val did not improve from 0.01279
# Epoch 76/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.5883
#
# Epoch 00076: CRPS_score_val did not improve from 0.01279
# Epoch 77/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.5852
#
# Epoch 00077: CRPS_score_val did not improve from 0.01279
# Epoch 78/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.5879
#
# Epoch 00078: CRPS_score_val did not improve from 0.01279
# Epoch 79/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.5785
#
# Epoch 00079: CRPS_score_val did not improve from 0.01279
# Epoch 80/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.5825
#
# Epoch 00080: CRPS_score_val did not improve from 0.01279
# Epoch 81/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.5777
# Restoring model weights from the end of the best epoch
#
# Epoch 00081: CRPS_score_val did not improve from 0.01279
# Epoch 00081: early stopping
# the 1 fold crps is 0.012789
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 127us/step - loss: 5.5930
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08197, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 5.1056
#
# Epoch 00002: CRPS_score_val improved from 0.08197 to 0.07729, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 4.6916
#
# Epoch 00003: CRPS_score_val improved from 0.07729 to 0.06356, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 4.2786
#
# Epoch 00004: CRPS_score_val improved from 0.06356 to 0.04399, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 3.9095
#
# Epoch 00005: CRPS_score_val improved from 0.04399 to 0.02755, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 3.5976
#
# Epoch 00006: CRPS_score_val improved from 0.02755 to 0.01989, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 3.3278
#
# Epoch 00007: CRPS_score_val improved from 0.01989 to 0.01586, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 3.1338
#
# Epoch 00008: CRPS_score_val improved from 0.01586 to 0.01426, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 3.0139
#
# Epoch 00009: CRPS_score_val improved from 0.01426 to 0.01357, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.9459
#
# Epoch 00010: CRPS_score_val improved from 0.01357 to 0.01333, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.8920
#
# Epoch 00011: CRPS_score_val improved from 0.01333 to 0.01323, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.8622
#
# Epoch 00012: CRPS_score_val improved from 0.01323 to 0.01316, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.8284
#
# Epoch 00013: CRPS_score_val improved from 0.01316 to 0.01311, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.8086
#
# Epoch 00014: CRPS_score_val improved from 0.01311 to 0.01307, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7917
#
# Epoch 00015: CRPS_score_val improved from 0.01307 to 0.01304, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7794
#
# Epoch 00016: CRPS_score_val improved from 0.01304 to 0.01302, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7752
#
# Epoch 00017: CRPS_score_val improved from 0.01302 to 0.01299, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7615
#
# Epoch 00018: CRPS_score_val improved from 0.01299 to 0.01296, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7526
#
# Epoch 00019: CRPS_score_val improved from 0.01296 to 0.01296, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7373
#
# Epoch 00020: CRPS_score_val improved from 0.01296 to 0.01293, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7362
#
# Epoch 00021: CRPS_score_val did not improve from 0.01293
# Epoch 22/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7309
#
# Epoch 00022: CRPS_score_val improved from 0.01293 to 0.01290, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7298
#
# Epoch 00023: CRPS_score_val improved from 0.01290 to 0.01288, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7182
#
# Epoch 00024: CRPS_score_val did not improve from 0.01288
# Epoch 25/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7165
#
# Epoch 00025: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7115
#
# Epoch 00026: CRPS_score_val improved from 0.01287 to 0.01284, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7074
#
# Epoch 00027: CRPS_score_val improved from 0.01284 to 0.01284, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7036
#
# Epoch 00028: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6941
#
# Epoch 00029: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6979
#
# Epoch 00030: CRPS_score_val did not improve from 0.01282
# Epoch 31/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6875
#
# Epoch 00031: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6900
#
# Epoch 00032: CRPS_score_val did not improve from 0.01282
# Epoch 33/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6902
#
# Epoch 00033: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6870
#
# Epoch 00034: CRPS_score_val did not improve from 0.01281
# Epoch 35/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6817
#
# Epoch 00035: CRPS_score_val did not improve from 0.01281
# Epoch 36/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6860
#
# Epoch 00036: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6728
#
# Epoch 00037: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6709
#
# Epoch 00038: CRPS_score_val did not improve from 0.01280
# Epoch 39/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6712
#
# Epoch 00039: CRPS_score_val did not improve from 0.01280
# Epoch 40/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6694
#
# Epoch 00040: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6738
#
# Epoch 00041: CRPS_score_val did not improve from 0.01278
# Epoch 42/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6650
#
# Epoch 00042: CRPS_score_val improved from 0.01278 to 0.01278, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6609
#
# Epoch 00043: CRPS_score_val did not improve from 0.01278
# Epoch 44/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6587
#
# Epoch 00044: CRPS_score_val improved from 0.01278 to 0.01278, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6544
#
# Epoch 00045: CRPS_score_val did not improve from 0.01278
# Epoch 46/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6500
#
# Epoch 00046: CRPS_score_val did not improve from 0.01278
# Epoch 47/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6515
#
# Epoch 00047: CRPS_score_val did not improve from 0.01278
# Epoch 48/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6521
#
# Epoch 00048: CRPS_score_val did not improve from 0.01278
# Epoch 49/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6422
#
# Epoch 00049: CRPS_score_val did not improve from 0.01278
# Epoch 50/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6412
#
# Epoch 00050: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 51/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6393
#
# Epoch 00051: CRPS_score_val did not improve from 0.01277
# Epoch 52/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6381
#
# Epoch 00052: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 53/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6393
#
# Epoch 00053: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 54/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6350
#
# Epoch 00054: CRPS_score_val did not improve from 0.01276
# Epoch 55/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6364
#
# Epoch 00055: CRPS_score_val did not improve from 0.01276
# Epoch 56/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6352
#
# Epoch 00056: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 57/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6331
#
# Epoch 00057: CRPS_score_val did not improve from 0.01275
# Epoch 58/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6238
#
# Epoch 00058: CRPS_score_val did not improve from 0.01275
# Epoch 59/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6314
#
# Epoch 00059: CRPS_score_val did not improve from 0.01275
# Epoch 60/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6236
#
# Epoch 00060: CRPS_score_val improved from 0.01275 to 0.01275, saving model to best_model.h5
# Epoch 61/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6215
#
# Epoch 00061: CRPS_score_val did not improve from 0.01275
# Epoch 62/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6225
#
# Epoch 00062: CRPS_score_val improved from 0.01275 to 0.01273, saving model to best_model.h5
# Epoch 63/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6134
#
# Epoch 00063: CRPS_score_val did not improve from 0.01273
# Epoch 64/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6153
#
# Epoch 00064: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# Epoch 65/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6152
#
# Epoch 00065: CRPS_score_val did not improve from 0.01273
# Epoch 66/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6037
#
# Epoch 00066: CRPS_score_val did not improve from 0.01273
# Epoch 67/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6085
#
# Epoch 00067: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 68/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6060
#
# Epoch 00068: CRPS_score_val did not improve from 0.01272
# Epoch 69/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.6033
#
# Epoch 00069: CRPS_score_val did not improve from 0.01272
# Epoch 70/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.5985
#
# Epoch 00070: CRPS_score_val did not improve from 0.01272
# Epoch 71/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6000
#
# Epoch 00071: CRPS_score_val did not improve from 0.01272
# Epoch 72/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.5959
#
# Epoch 00072: CRPS_score_val did not improve from 0.01272
# Epoch 73/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.5879
#
# Epoch 00073: CRPS_score_val did not improve from 0.01272
# Epoch 74/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.5885
#
# Epoch 00074: CRPS_score_val did not improve from 0.01272
# Epoch 75/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.5930
#
# Epoch 00075: CRPS_score_val did not improve from 0.01272
# Epoch 76/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.5838
#
# Epoch 00076: CRPS_score_val did not improve from 0.01272
# Epoch 77/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.5826
# Restoring model weights from the end of the best epoch
#
# Epoch 00077: CRPS_score_val did not improve from 0.01272
# Epoch 00077: early stopping
# the 2 fold crps is 0.012721
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 131us/step - loss: 5.6046
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08214, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 5.0936
#
# Epoch 00002: CRPS_score_val improved from 0.08214 to 0.07819, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 4.6735
#
# Epoch 00003: CRPS_score_val improved from 0.07819 to 0.06560, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 4.2809
#
# Epoch 00004: CRPS_score_val improved from 0.06560 to 0.04487, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 3.9113
#
# Epoch 00005: CRPS_score_val improved from 0.04487 to 0.02711, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 3.5771
#
# Epoch 00006: CRPS_score_val improved from 0.02711 to 0.01877, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 3.3169
#
# Epoch 00007: CRPS_score_val improved from 0.01877 to 0.01555, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 3.1187
#
# Epoch 00008: CRPS_score_val improved from 0.01555 to 0.01400, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.9960
#
# Epoch 00009: CRPS_score_val improved from 0.01400 to 0.01351, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.9343
#
# Epoch 00010: CRPS_score_val improved from 0.01351 to 0.01327, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8787
#
# Epoch 00011: CRPS_score_val improved from 0.01327 to 0.01315, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8477
#
# Epoch 00012: CRPS_score_val improved from 0.01315 to 0.01307, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8324
#
# Epoch 00013: CRPS_score_val improved from 0.01307 to 0.01302, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8105
#
# Epoch 00014: CRPS_score_val improved from 0.01302 to 0.01299, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8047
#
# Epoch 00015: CRPS_score_val improved from 0.01299 to 0.01295, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7834
#
# Epoch 00016: CRPS_score_val improved from 0.01295 to 0.01291, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7675
#
# Epoch 00017: CRPS_score_val improved from 0.01291 to 0.01289, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7624
#
# Epoch 00018: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7520
#
# Epoch 00019: CRPS_score_val improved from 0.01288 to 0.01285, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7441
#
# Epoch 00020: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7435
#
# Epoch 00021: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7351
#
# Epoch 00022: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7267
#
# Epoch 00023: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7253
#
# Epoch 00024: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7144
#
# Epoch 00025: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7170
#
# Epoch 00026: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7061
#
# Epoch 00027: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7037
#
# Epoch 00028: CRPS_score_val improved from 0.01275 to 0.01275, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7044
#
# Epoch 00029: CRPS_score_val did not improve from 0.01275
# Epoch 30/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7027
#
# Epoch 00030: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6918
#
# Epoch 00031: CRPS_score_val did not improve from 0.01274
# Epoch 32/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6893
#
# Epoch 00032: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6884
#
# Epoch 00033: CRPS_score_val did not improve from 0.01273
# Epoch 34/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6905
#
# Epoch 00034: CRPS_score_val did not improve from 0.01273
# Epoch 35/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6871
#
# Epoch 00035: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6786
#
# Epoch 00036: CRPS_score_val did not improve from 0.01273
# Epoch 37/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6783
#
# Epoch 00037: CRPS_score_val improved from 0.01273 to 0.01271, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6766
#
# Epoch 00038: CRPS_score_val did not improve from 0.01271
# Epoch 39/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6730
#
# Epoch 00039: CRPS_score_val improved from 0.01271 to 0.01271, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6711
#
# Epoch 00040: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6713
#
# Epoch 00041: CRPS_score_val did not improve from 0.01270
# Epoch 42/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6698
#
# Epoch 00042: CRPS_score_val did not improve from 0.01270
# Epoch 43/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6621
#
# Epoch 00043: CRPS_score_val did not improve from 0.01270
# Epoch 44/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6606
#
# Epoch 00044: CRPS_score_val did not improve from 0.01270
# Epoch 45/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6549
#
# Epoch 00045: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6596
#
# Epoch 00046: CRPS_score_val did not improve from 0.01270
# Epoch 47/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6539
#
# Epoch 00047: CRPS_score_val did not improve from 0.01270
# Epoch 48/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6510
#
# Epoch 00048: CRPS_score_val did not improve from 0.01270
# Epoch 49/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6471
#
# Epoch 00049: CRPS_score_val improved from 0.01270 to 0.01268, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6509
#
# Epoch 00050: CRPS_score_val did not improve from 0.01268
# Epoch 51/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6426
#
# Epoch 00051: CRPS_score_val did not improve from 0.01268
# Epoch 52/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6463
#
# Epoch 00052: CRPS_score_val did not improve from 0.01268
# Epoch 53/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6380
#
# Epoch 00053: CRPS_score_val did not improve from 0.01268
# Epoch 54/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6364
#
# Epoch 00054: CRPS_score_val did not improve from 0.01268
# Epoch 55/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6388
#
# Epoch 00055: CRPS_score_val did not improve from 0.01268
# Epoch 56/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6337
#
# Epoch 00056: CRPS_score_val did not improve from 0.01268
# Epoch 57/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6335
#
# Epoch 00057: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 58/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6331
#
# Epoch 00058: CRPS_score_val did not improve from 0.01268
# Epoch 59/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6280
#
# Epoch 00059: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 60/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6223
#
# Epoch 00060: CRPS_score_val did not improve from 0.01268
# Epoch 61/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6246
#
# Epoch 00061: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 62/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6254
#
# Epoch 00062: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 63/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6185
#
# Epoch 00063: CRPS_score_val did not improve from 0.01267
# Epoch 64/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6217
#
# Epoch 00064: CRPS_score_val did not improve from 0.01267
# Epoch 65/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6144
#
# Epoch 00065: CRPS_score_val did not improve from 0.01267
# Epoch 66/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6132
#
# Epoch 00066: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 67/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6100
#
# Epoch 00067: CRPS_score_val did not improve from 0.01267
# Epoch 68/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6083
#
# Epoch 00068: CRPS_score_val did not improve from 0.01267
# Epoch 69/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6106
#
# Epoch 00069: CRPS_score_val did not improve from 0.01267
# Epoch 70/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6049
#
# Epoch 00070: CRPS_score_val did not improve from 0.01267
# Epoch 71/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6077
#
# Epoch 00071: CRPS_score_val did not improve from 0.01267
# Epoch 72/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.5972
#
# Epoch 00072: CRPS_score_val did not improve from 0.01267
# Epoch 73/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.5972
#
# Epoch 00073: CRPS_score_val did not improve from 0.01267
# Epoch 74/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.5962
#
# Epoch 00074: CRPS_score_val did not improve from 0.01267
# Epoch 75/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.5948
#
# Epoch 00075: CRPS_score_val did not improve from 0.01267
# Epoch 76/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.5903
# Restoring model weights from the end of the best epoch
#
# Epoch 00076: CRPS_score_val did not improve from 0.01267
# Epoch 00076: early stopping
# the 3 fold crps is 0.012667
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 136us/step - loss: 5.5726
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08224, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 5.0993
#
# Epoch 00002: CRPS_score_val improved from 0.08224 to 0.07803, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 4.6791
#
# Epoch 00003: CRPS_score_val improved from 0.07803 to 0.06557, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 4.2996
#
# Epoch 00004: CRPS_score_val improved from 0.06557 to 0.04440, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 3.9118
#
# Epoch 00005: CRPS_score_val improved from 0.04440 to 0.02713, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 3.5680
#
# Epoch 00006: CRPS_score_val improved from 0.02713 to 0.01859, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 3.2974
#
# Epoch 00007: CRPS_score_val improved from 0.01859 to 0.01508, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 3.1033
#
# Epoch 00008: CRPS_score_val improved from 0.01508 to 0.01386, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.9977
#
# Epoch 00009: CRPS_score_val improved from 0.01386 to 0.01335, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.9258
#
# Epoch 00010: CRPS_score_val improved from 0.01335 to 0.01316, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8840
#
# Epoch 00011: CRPS_score_val improved from 0.01316 to 0.01309, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8528
#
# Epoch 00012: CRPS_score_val improved from 0.01309 to 0.01301, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.8298
#
# Epoch 00013: CRPS_score_val improved from 0.01301 to 0.01295, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.8088
#
# Epoch 00014: CRPS_score_val improved from 0.01295 to 0.01293, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7900
#
# Epoch 00015: CRPS_score_val improved from 0.01293 to 0.01289, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7775
#
# Epoch 00016: CRPS_score_val improved from 0.01289 to 0.01284, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7652
#
# Epoch 00017: CRPS_score_val improved from 0.01284 to 0.01282, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7625
#
# Epoch 00018: CRPS_score_val improved from 0.01282 to 0.01280, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7465
#
# Epoch 00019: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7408
#
# Epoch 00020: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7418
#
# Epoch 00021: CRPS_score_val improved from 0.01277 to 0.01274, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7357
#
# Epoch 00022: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7289
#
# Epoch 00023: CRPS_score_val did not improve from 0.01273
# Epoch 24/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7207
#
# Epoch 00024: CRPS_score_val improved from 0.01273 to 0.01271, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7206
#
# Epoch 00025: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7162
#
# Epoch 00026: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7098
#
# Epoch 00027: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7050
#
# Epoch 00028: CRPS_score_val improved from 0.01268 to 0.01266, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6985
#
# Epoch 00029: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6954
#
# Epoch 00030: CRPS_score_val did not improve from 0.01266
# Epoch 31/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6941
#
# Epoch 00031: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6888
#
# Epoch 00032: CRPS_score_val did not improve from 0.01266
# Epoch 33/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6866
#
# Epoch 00033: CRPS_score_val improved from 0.01266 to 0.01264, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6850
#
# Epoch 00034: CRPS_score_val did not improve from 0.01264
# Epoch 35/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6858
#
# Epoch 00035: CRPS_score_val did not improve from 0.01264
# Epoch 36/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6834
#
# Epoch 00036: CRPS_score_val did not improve from 0.01264
# Epoch 37/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6782
#
# Epoch 00037: CRPS_score_val did not improve from 0.01264
# Epoch 38/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6749
#
# Epoch 00038: CRPS_score_val did not improve from 0.01264
# Epoch 39/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6737
#
# Epoch 00039: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6686
#
# Epoch 00040: CRPS_score_val improved from 0.01264 to 0.01263, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6701
#
# Epoch 00041: CRPS_score_val did not improve from 0.01263
# Epoch 42/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6644
#
# Epoch 00042: CRPS_score_val did not improve from 0.01263
# Epoch 43/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6664
#
# Epoch 00043: CRPS_score_val did not improve from 0.01263
# Epoch 44/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6579
#
# Epoch 00044: CRPS_score_val did not improve from 0.01263
# Epoch 45/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6624
#
# Epoch 00045: CRPS_score_val did not improve from 0.01263
# Epoch 46/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6527
#
# Epoch 00046: CRPS_score_val did not improve from 0.01263
# Epoch 47/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6523
#
# Epoch 00047: CRPS_score_val improved from 0.01263 to 0.01261, saving model to best_model.h5
# Epoch 48/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6530
#
# Epoch 00048: CRPS_score_val did not improve from 0.01261
# Epoch 49/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6532
#
# Epoch 00049: CRPS_score_val did not improve from 0.01261
# Epoch 50/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6463
#
# Epoch 00050: CRPS_score_val did not improve from 0.01261
# Epoch 51/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6440
#
# Epoch 00051: CRPS_score_val did not improve from 0.01261
# Epoch 52/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6432
#
# Epoch 00052: CRPS_score_val did not improve from 0.01261
# Epoch 53/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6443
#
# ...
#
# Epoch 00025: CRPS_score_val did not improve from 0.01343
# Epoch 26/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7155
#
# Epoch 00026: CRPS_score_val improved from 0.01343 to 0.01342, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7080
#
# Epoch 00027: CRPS_score_val did not improve from 0.01342
# Epoch 28/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.7005
#
# Epoch 00028: CRPS_score_val improved from 0.01342 to 0.01342, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.7057
#
# Epoch 00029: CRPS_score_val improved from 0.01342 to 0.01341, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7008
#
# Epoch 00030: CRPS_score_val improved from 0.01341 to 0.01340, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6922
#
# Epoch 00031: CRPS_score_val did not improve from 0.01340
# Epoch 32/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6879
#
# Epoch 00032: CRPS_score_val improved from 0.01340 to 0.01339, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6872
#
# Epoch 00033: CRPS_score_val did not improve from 0.01339
# Epoch 34/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6862
#
# Epoch 00034: CRPS_score_val improved from 0.01339 to 0.01338, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6833
#
# Epoch 00035: CRPS_score_val did not improve from 0.01338
# Epoch 36/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6753
#
# Epoch 00036: CRPS_score_val did not improve from 0.01338
# Epoch 37/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6727
#
# Epoch 00037: CRPS_score_val improved from 0.01338 to 0.01338, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6753
#
# Epoch 00038: CRPS_score_val did not improve from 0.01338
# Epoch 39/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6670
#
# Epoch 00039: CRPS_score_val did not improve from 0.01338
# Epoch 40/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6701
#
# Epoch 00040: CRPS_score_val improved from 0.01338 to 0.01337, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6612
#
# Epoch 00041: CRPS_score_val did not improve from 0.01337
# Epoch 42/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6652
#
# Epoch 00042: CRPS_score_val did not improve from 0.01337
# Epoch 43/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6658
#
# Epoch 00043: CRPS_score_val improved from 0.01337 to 0.01336, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6574
#
# Epoch 00044: CRPS_score_val did not improve from 0.01336
# Epoch 45/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6549
#
# Epoch 00045: CRPS_score_val did not improve from 0.01336
# Epoch 46/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6541
#
# Epoch 00046: CRPS_score_val did not improve from 0.01336
# Epoch 47/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6510
#
# Epoch 00047: CRPS_score_val did not improve from 0.01336
# Epoch 48/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6539
#
# Epoch 00048: CRPS_score_val improved from 0.01336 to 0.01334, saving model to best_model.h5
# Epoch 49/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6501
#
# Epoch 00049: CRPS_score_val did not improve from 0.01334
# Epoch 50/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.6424
#
# Epoch 00050: CRPS_score_val did not improve from 0.01334
# Epoch 51/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6456
#
# Epoch 00051: CRPS_score_val did not improve from 0.01334
# Epoch 52/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.6374
#
# Epoch 00052: CRPS_score_val improved from 0.01334 to 0.01334, saving model to best_model.h5
# Epoch 53/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6389
#
# Epoch 00053: CRPS_score_val did not improve from 0.01334
# Epoch 54/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6353
#
# Epoch 00054: CRPS_score_val did not improve from 0.01334
# Epoch 55/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6310
#
# Epoch 00055: CRPS_score_val did not improve from 0.01334
# Epoch 56/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6330
#
# Epoch 00056: CRPS_score_val did not improve from 0.01334
# Epoch 57/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6302
#
# Epoch 00057: CRPS_score_val improved from 0.01334 to 0.01333, saving model to best_model.h5
# Epoch 58/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6280
#
# Epoch 00058: CRPS_score_val improved from 0.01333 to 0.01333, saving model to best_model.h5
# Epoch 59/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6235
#
# Epoch 00059: CRPS_score_val did not improve from 0.01333
# Epoch 60/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6244
#
# Epoch 00060: CRPS_score_val did not improve from 0.01333
# Epoch 61/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6185
#
# Epoch 00061: CRPS_score_val did not improve from 0.01333
# Epoch 62/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6209
#
# Epoch 00062: CRPS_score_val did not improve from 0.01333
# Epoch 63/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6165
#
# Epoch 00063: CRPS_score_val did not improve from 0.01333
# Epoch 64/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6167
#
# Epoch 00064: CRPS_score_val did not improve from 0.01333
# Epoch 65/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6141
#
# Epoch 00065: CRPS_score_val did not improve from 0.01333
# Epoch 66/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6095
#
# Epoch 00066: CRPS_score_val did not improve from 0.01333
# Epoch 67/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6083
#
# Epoch 00067: CRPS_score_val did not improve from 0.01333
# Epoch 68/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6057
# Restoring model weights from the end of the best epoch
#
# Epoch 00068: CRPS_score_val did not improve from 0.01333
# Epoch 00068: early stopping
# the 4 fold crps is 0.013326
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 171us/step - loss: 5.5808
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08213, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 5.1022
#
# Epoch 00002: CRPS_score_val improved from 0.08213 to 0.07742, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 4.7010
#
# Epoch 00003: CRPS_score_val improved from 0.07742 to 0.06481, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 4.3082
#
# Epoch 00004: CRPS_score_val improved from 0.06481 to 0.04513, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 3.9331
#
# Epoch 00005: CRPS_score_val improved from 0.04513 to 0.02841, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 3.6027
#
# Epoch 00006: CRPS_score_val improved from 0.02841 to 0.02022, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 3.3292
#
# Epoch 00007: CRPS_score_val improved from 0.02022 to 0.01597, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 3.1532
#
# Epoch 00008: CRPS_score_val improved from 0.01597 to 0.01408, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 3.0245
#
# Epoch 00009: CRPS_score_val improved from 0.01408 to 0.01349, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.9444
#
# Epoch 00010: CRPS_score_val improved from 0.01349 to 0.01320, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.9035
#
# Epoch 00011: CRPS_score_val improved from 0.01320 to 0.01310, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8642
#
# Epoch 00012: CRPS_score_val improved from 0.01310 to 0.01304, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8449
#
# Epoch 00013: CRPS_score_val improved from 0.01304 to 0.01299, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8233
#
# Epoch 00014: CRPS_score_val improved from 0.01299 to 0.01294, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8051
#
# Epoch 00015: CRPS_score_val improved from 0.01294 to 0.01291, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7922
#
# Epoch 00016: CRPS_score_val improved from 0.01291 to 0.01288, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7837
#
# Epoch 00017: CRPS_score_val improved from 0.01288 to 0.01285, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7694
#
# Epoch 00018: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7556
#
# Epoch 00019: CRPS_score_val improved from 0.01283 to 0.01280, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7529
#
# Epoch 00020: CRPS_score_val improved from 0.01280 to 0.01277, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7447
#
# Epoch 00021: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7450
#
# Epoch 00022: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7315
#
# Epoch 00023: CRPS_score_val improved from 0.01276 to 0.01274, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7319
#
# Epoch 00024: CRPS_score_val improved from 0.01274 to 0.01272, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7222
#
# Epoch 00025: CRPS_score_val did not improve from 0.01272
# Epoch 26/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7148
#
# Epoch 00026: CRPS_score_val did not improve from 0.01272
# Epoch 27/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7111
#
# Epoch 00027: CRPS_score_val improved from 0.01272 to 0.01270, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.7080
#
# Epoch 00028: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7071
#
# Epoch 00029: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6976
#
# Epoch 00030: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6964
#
# Epoch 00031: CRPS_score_val did not improve from 0.01269
# Epoch 32/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6986
#
# Epoch 00032: CRPS_score_val did not improve from 0.01269
# Epoch 33/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6934
#
# Epoch 00033: CRPS_score_val did not improve from 0.01269
# Epoch 34/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6932
#
# Epoch 00034: CRPS_score_val did not improve from 0.01269
# Epoch 35/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6840
#
# Epoch 00035: CRPS_score_val improved from 0.01269 to 0.01267, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6823
#
# Epoch 00036: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6790
#
# Epoch 00037: CRPS_score_val did not improve from 0.01267
# Epoch 38/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6789
#
# Epoch 00038: CRPS_score_val did not improve from 0.01267
# Epoch 39/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6731
#
# Epoch 00039: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6720
#
# Epoch 00040: CRPS_score_val did not improve from 0.01266
# Epoch 41/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6740
#
# Epoch 00041: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6704
#
# Epoch 00042: CRPS_score_val did not improve from 0.01266
# Epoch 43/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6684
#
# Epoch 00043: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6604
#
# Epoch 00044: CRPS_score_val did not improve from 0.01265
# Epoch 45/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6557
#
# Epoch 00045: CRPS_score_val did not improve from 0.01265
# Epoch 46/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6558
#
# Epoch 00046: CRPS_score_val did not improve from 0.01265
# Epoch 47/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6567
#
# Epoch 00047: CRPS_score_val did not improve from 0.01265
# Epoch 48/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6555
#
# Epoch 00048: CRPS_score_val did not improve from 0.01265
# Epoch 49/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6483
#
# Epoch 00049: CRPS_score_val did not improve from 0.01265
# Epoch 50/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6535
#
# Epoch 00050: CRPS_score_val did not improve from 0.01265
# Epoch 51/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6466
#
# Epoch 00051: CRPS_score_val did not improve from 0.01265
# Epoch 52/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6413
#
# Epoch 00052: CRPS_score_val did not improve from 0.01265
# Epoch 53/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6388
# Restoring model weights from the end of the best epoch
#
# Epoch 00053: CRPS_score_val did not improve from 0.01265
# Epoch 00053: early stopping
# the 5 fold crps is 0.012649
# mean crps is 0.012761

# %%
print("mean crps is %f"%np.mean(crps_csv))
# Out:
# mean crps is 0.012761

# %% [markdown]
# # Time for the actual submission

# %%
# %%time

from kaggle.competitions import nflrush
env = nflrush.make_env()
iter_test = env.iter_test()

for (test_df, sample_prediction_df) in iter_test:
    basetable = create_features(test_df, deploy=True)
    basetable.drop(['GameId','PlayId'], axis=1, inplace=True)
    scaled_basetable = scaler.transform(basetable)

    y_pred = predict(scaled_basetable)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1).tolist()[0]

    preds_df = pd.DataFrame(data=[y_pred], columns=sample_prediction_df.columns)
    env.predict(preds_df)

env.write_submission_file()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.
# CPU times: user 13min 35s, sys: 23.1 s, total: 13min 58s
# Wall time: 13min 9s
