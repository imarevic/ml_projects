# %%
import os
# os.environ['CUDA_VISIBLE_DEVICES'] = "1"

import numpy as np
import pandas as pd
import sklearn.metrics as mtr
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization
from keras.models import Model
import keras.backend as K
from keras.callbacks import Callback
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import datetime

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %% [markdown]
# ## Preprocessing and Feature Engineering

# %%
# helper functions for data cleaning
# and feature engineering

def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"
    
def clean_turf_and_teams(train):
    
    ## Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)
    
    ## Teams
    Teams = {'ARI':'ARZ', 'BAL':'BLT', 'CLE':'CLV', 'HOU':'HST'}
    train['HomeTeamAbbr'] = train['HomeTeamAbbr'].map(Teams)
    train['VisitorTeamAbbr'] = train['VisitorTeamAbbr'].map(Teams)

    return train

# %%
# feature engineering (mainly rusher)
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense
    
    def rusher_features(df):
        
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Dir', 'S', 'A', 'X', 'Y']]
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS', 'RusherA', 'RusherX', 'RusherY']
        
       
        radian_angle = (90 - rusher['RusherDir']) * np.pi / 180.0
        v_horizontal = np.abs(rusher['RusherS'] * np.cos(radian_angle))
        v_vertical = np.abs(rusher['RusherS'] * np.sin(radian_angle)) 
        
       
        rusher['v_horizontal'] = v_horizontal
        rusher['v_vertical'] = v_vertical
        
        
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS','RusherA','RusherX', 'RusherY','v_horizontal', 'v_vertical']
        
        
        return rusher

    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))
        
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Weather
        df['GameWeather_process'] = df['GameWeather'].str.lower()
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
        df['GameWeather_dense'] = df['GameWeather_process'].apply(map_weather)
        add_new_feas.append("GameWeather_dense")
        
        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
    
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Quarter','Down','Distance','DefendersInTheBox']].drop_duplicates()

        static_features.fillna(-999,inplace=True)
       

        return static_features


    def combine_features(relative_to_back, defense,rushing, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,rushing,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    df = clean_turf_and_teams(df)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    rush_feats = rusher_features(df)
    static_feats = static_features(df)
    basetable = combine_features(rel_back, 
                                 def_feats,
                                 rush_feats,
                                 static_feats, 
                                 deploy=deploy)
    
    return basetable

# %%
# %time train_basetable = create_features(train, False)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 5min 45s, sys: 6.04 s, total: 5min 51s
# Wall time: 5min 50s

# %% [markdown]
# # Let's split our data into train/val

# %%
X = train_basetable.copy()
yards = X.Yards

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=12345)

# %%
print(X_train.shape, X_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# (19695, 37) (3476, 37)
# (19695, 199) (3476, 199)

# %% [markdown]
# # Let's build NN

# %%
from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda
from keras.models import Model
import keras.backend as K
import re
from keras.losses import binary_crossentropy
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import codecs

from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from sklearn.metrics import f1_score




class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
def get_model(x_tr,y_tr,x_val,y_val):
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(1024, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    #add lookahead
#     lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
#     lookahead.inject(model) # add into model

    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                                   save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    


    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
    crps = np.round(val_s, 6)

    return model,crps

# %%
from sklearn.model_selection import train_test_split, KFold
import time

losses = []
models = []
crps_csv = []

s_time = time.time()


for k in range(2):
    kfold = KFold(5, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print("-----------")
        tr_x,tr_y = X[tr_inds],y[tr_inds]
        val_x,val_y = X[val_inds],y[val_inds]
        model,crps = get_model(tr_x,tr_y,val_x,val_y)
        models.append(model)
        print("the %d fold crps is %f"%((k_fold+1),crps))
        crps_csv.append(crps)
 
print("mean crps is %f"%np.mean(crps_csv))


def predict(x_te):
    model_num = len(models)
    for k,m in enumerate(models):
        if k==0:
            y_pred = m.predict(x_te,batch_size=1024)
        else:
            y_pred+=m.predict(x_te,batch_size=1024)
            
    y_pred = y_pred / model_num
    
    return y_pred
# Out:
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18536/18536 [==============================] - 3s 158us/step - loss: 5.6047
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08278, saving model to best_model.h5
# Epoch 2/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 5.1044
#
# Epoch 00002: CRPS_score_val improved from 0.08278 to 0.07828, saving model to best_model.h5
# Epoch 3/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 4.7105
#
# Epoch 00003: CRPS_score_val improved from 0.07828 to 0.06506, saving model to best_model.h5
# Epoch 4/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 4.3099
#
# Epoch 00004: CRPS_score_val improved from 0.06506 to 0.04297, saving model to best_model.h5
# Epoch 5/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 3.9293
#
# Epoch 00005: CRPS_score_val improved from 0.04297 to 0.02578, saving model to best_model.h5
# Epoch 6/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 3.5688
#
# Epoch 00006: CRPS_score_val improved from 0.02578 to 0.01843, saving model to best_model.h5
# Epoch 7/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 3.3015
#
# Epoch 00007: CRPS_score_val improved from 0.01843 to 0.01562, saving model to best_model.h5
# Epoch 8/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 3.1092
#
# Epoch 00008: CRPS_score_val improved from 0.01562 to 0.01425, saving model to best_model.h5
# Epoch 9/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 3.0007
#
# Epoch 00009: CRPS_score_val improved from 0.01425 to 0.01363, saving model to best_model.h5
# Epoch 10/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.9315
#
# Epoch 00010: CRPS_score_val improved from 0.01363 to 0.01343, saving model to best_model.h5
# Epoch 11/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.8877
#
# Epoch 00011: CRPS_score_val improved from 0.01343 to 0.01332, saving model to best_model.h5
# Epoch 12/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.8552
#
# Epoch 00012: CRPS_score_val improved from 0.01332 to 0.01326, saving model to best_model.h5
# Epoch 13/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.8325
#
# Epoch 00013: CRPS_score_val improved from 0.01326 to 0.01321, saving model to best_model.h5
# Epoch 14/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.8121
#
# Epoch 00014: CRPS_score_val improved from 0.01321 to 0.01316, saving model to best_model.h5
# Epoch 15/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.8002
#
# Epoch 00015: CRPS_score_val improved from 0.01316 to 0.01312, saving model to best_model.h5
# Epoch 16/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.7896
#
# Epoch 00016: CRPS_score_val improved from 0.01312 to 0.01308, saving model to best_model.h5
# Epoch 17/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.7741
#
# Epoch 00017: CRPS_score_val improved from 0.01308 to 0.01306, saving model to best_model.h5
# Epoch 18/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.7653
#
# Epoch 00018: CRPS_score_val improved from 0.01306 to 0.01304, saving model to best_model.h5
# Epoch 19/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.7583
#
# Epoch 00019: CRPS_score_val improved from 0.01304 to 0.01302, saving model to best_model.h5
# Epoch 20/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.7496
#
# Epoch 00020: CRPS_score_val improved from 0.01302 to 0.01300, saving model to best_model.h5
# Epoch 21/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.7486
#
# Epoch 00021: CRPS_score_val improved from 0.01300 to 0.01299, saving model to best_model.h5
# Epoch 22/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.7288
#
# Epoch 00022: CRPS_score_val improved from 0.01299 to 0.01296, saving model to best_model.h5
# Epoch 23/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.7290
#
# Epoch 00023: CRPS_score_val did not improve from 0.01296
# Epoch 24/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.7273
#
# Epoch 00024: CRPS_score_val improved from 0.01296 to 0.01295, saving model to best_model.h5
# Epoch 25/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.7190
#
# Epoch 00025: CRPS_score_val improved from 0.01295 to 0.01293, saving model to best_model.h5
# Epoch 26/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.7102
#
# Epoch 00026: CRPS_score_val improved from 0.01293 to 0.01291, saving model to best_model.h5
# Epoch 27/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.7148
#
# Epoch 00027: CRPS_score_val improved from 0.01291 to 0.01291, saving model to best_model.h5
# Epoch 28/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.7135
#
# Epoch 00028: CRPS_score_val improved from 0.01291 to 0.01290, saving model to best_model.h5
# Epoch 29/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.7002
#
# Epoch 00029: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 30/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6949
#
# Epoch 00030: CRPS_score_val improved from 0.01289 to 0.01289, saving model to best_model.h5
# Epoch 31/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.7010
#
# Epoch 00031: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 32/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6953
#
# Epoch 00032: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 33/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6898
#
# Epoch 00033: CRPS_score_val improved from 0.01287 to 0.01287, saving model to best_model.h5
# Epoch 34/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.6853
#
# Epoch 00034: CRPS_score_val improved from 0.01287 to 0.01287, saving model to best_model.h5
# Epoch 35/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6879
#
# Epoch 00035: CRPS_score_val did not improve from 0.01287
# Epoch 36/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.6840
#
# Epoch 00036: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 37/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6843
#
# Epoch 00037: CRPS_score_val did not improve from 0.01286
# Epoch 38/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6780
#
# Epoch 00038: CRPS_score_val did not improve from 0.01286
# Epoch 39/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6742
#
# Epoch 00039: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 40/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6735
#
# Epoch 00040: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 41/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.6666
#
# Epoch 00041: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# Epoch 42/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6672
#
# Epoch 00042: CRPS_score_val did not improve from 0.01283
# Epoch 43/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6669
#
# Epoch 00043: CRPS_score_val did not improve from 0.01283
# Epoch 44/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6551
#
# Epoch 00044: CRPS_score_val did not improve from 0.01283
# Epoch 45/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.6626
#
# Epoch 00045: CRPS_score_val did not improve from 0.01283
# Epoch 46/100
# 18536/18536 [==============================] - 2s 86us/step - loss: 2.6568
#
# Epoch 00046: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# Epoch 47/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.6552
#
# Epoch 00047: CRPS_score_val did not improve from 0.01283
# Epoch 48/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.6552
#
# Epoch 00048: CRPS_score_val did not improve from 0.01283
# Epoch 49/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6480
#
# Epoch 00049: CRPS_score_val did not improve from 0.01283
# Epoch 50/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.6517
#
# Epoch 00050: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 51/100
# 18536/18536 [==============================] - 2s 86us/step - loss: 2.6490
#
# Epoch 00051: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 52/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6472
#
# Epoch 00052: CRPS_score_val did not improve from 0.01282
# Epoch 53/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6445
#
# Epoch 00053: CRPS_score_val did not improve from 0.01282
# Epoch 54/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6399
#
# Epoch 00054: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 55/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6350
#
# Epoch 00055: CRPS_score_val did not improve from 0.01281
# Epoch 56/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.6344
#
# Epoch 00056: CRPS_score_val did not improve from 0.01281
# Epoch 57/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6363
#
# Epoch 00057: CRPS_score_val did not improve from 0.01281
# Epoch 58/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6319
#
# Epoch 00058: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 59/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6205
#
# Epoch 00059: CRPS_score_val did not improve from 0.01280
# Epoch 60/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6254
#
# Epoch 00060: CRPS_score_val did not improve from 0.01280
# Epoch 61/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6236
#
# Epoch 00061: CRPS_score_val did not improve from 0.01280
# Epoch 62/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6193
#
# Epoch 00062: CRPS_score_val did not improve from 0.01280
# Epoch 63/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 2.6127
#
# Epoch 00063: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 64/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6161
#
# Epoch 00064: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 65/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6144
#
# Epoch 00065: CRPS_score_val did not improve from 0.01277
# Epoch 66/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6168
#
# Epoch 00066: CRPS_score_val did not improve from 0.01277
# Epoch 67/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6071
#
# Epoch 00067: CRPS_score_val did not improve from 0.01277
# Epoch 68/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6053
#
# Epoch 00068: CRPS_score_val did not improve from 0.01277
# Epoch 69/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6121
#
# Epoch 00069: CRPS_score_val did not improve from 0.01277
# Epoch 70/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.5989
#
# Epoch 00070: CRPS_score_val did not improve from 0.01277
# Epoch 71/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.6082
#
# Epoch 00071: CRPS_score_val did not improve from 0.01277
# Epoch 72/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.5996
#
# Epoch 00072: CRPS_score_val did not improve from 0.01277
# Epoch 73/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.5957
#
# Epoch 00073: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 74/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.5912
#
# Epoch 00074: CRPS_score_val did not improve from 0.01277
# Epoch 75/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.5915
#
# Epoch 00075: CRPS_score_val did not improve from 0.01277
# Epoch 76/100
# 18536/18536 [==============================] - 2s 86us/step - loss: 2.5909
#
# Epoch 00076: CRPS_score_val did not improve from 0.01277
# Epoch 77/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.5859
#
# Epoch 00077: CRPS_score_val did not improve from 0.01277
# Epoch 78/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.5888
#
# Epoch 00078: CRPS_score_val did not improve from 0.01277
# Epoch 79/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.5832
#
# Epoch 00079: CRPS_score_val did not improve from 0.01277
# Epoch 80/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.5756
#
# Epoch 00080: CRPS_score_val did not improve from 0.01277
# Epoch 81/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.5783
#
# Epoch 00081: CRPS_score_val did not improve from 0.01277
# Epoch 82/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 2.5797
#
# Epoch 00082: CRPS_score_val did not improve from 0.01277
# Epoch 83/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.5722
# Restoring model weights from the end of the best epoch
#
# Epoch 00083: CRPS_score_val did not improve from 0.01277
# Epoch 00083: early stopping
# the 1 fold crps is 0.012765
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 127us/step - loss: 5.6123
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08259, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 5.0876
#
# Epoch 00002: CRPS_score_val improved from 0.08259 to 0.07872, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 4.6738
#
# Epoch 00003: CRPS_score_val improved from 0.07872 to 0.06579, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 4.2884
#
# Epoch 00004: CRPS_score_val improved from 0.06579 to 0.04475, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 3.9210
#
# Epoch 00005: CRPS_score_val improved from 0.04475 to 0.02758, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 3.6032
#
# Epoch 00006: CRPS_score_val improved from 0.02758 to 0.01911, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 3.3193
#
# Epoch 00007: CRPS_score_val improved from 0.01911 to 0.01537, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 3.1258
#
# Epoch 00008: CRPS_score_val improved from 0.01537 to 0.01409, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.9946
#
# Epoch 00009: CRPS_score_val improved from 0.01409 to 0.01354, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.9233
#
# Epoch 00010: CRPS_score_val improved from 0.01354 to 0.01331, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.8803
#
# Epoch 00011: CRPS_score_val improved from 0.01331 to 0.01321, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.8513
#
# Epoch 00012: CRPS_score_val improved from 0.01321 to 0.01315, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.8240
#
# Epoch 00013: CRPS_score_val improved from 0.01315 to 0.01310, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.8018
#
# Epoch 00014: CRPS_score_val improved from 0.01310 to 0.01307, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7891
#
# Epoch 00015: CRPS_score_val improved from 0.01307 to 0.01302, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.7766
#
# Epoch 00016: CRPS_score_val improved from 0.01302 to 0.01299, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.7669
#
# Epoch 00017: CRPS_score_val improved from 0.01299 to 0.01298, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.7606
#
# Epoch 00018: CRPS_score_val improved from 0.01298 to 0.01295, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.7469
#
# Epoch 00019: CRPS_score_val did not improve from 0.01295
# Epoch 20/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.7367
#
# Epoch 00020: CRPS_score_val improved from 0.01295 to 0.01293, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.7333
#
# Epoch 00021: CRPS_score_val improved from 0.01293 to 0.01292, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7278
#
# Epoch 00022: CRPS_score_val improved from 0.01292 to 0.01289, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7181
#
# Epoch 00023: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7166
#
# Epoch 00024: CRPS_score_val did not improve from 0.01288
# Epoch 25/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7122
#
# Epoch 00025: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7149
#
# Epoch 00026: CRPS_score_val improved from 0.01287 to 0.01285, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 132us/step - loss: 2.7043
#
# Epoch 00027: CRPS_score_val did not improve from 0.01285
# Epoch 28/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7035
#
# Epoch 00028: CRPS_score_val did not improve from 0.01285
# Epoch 29/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7016
#
# Epoch 00029: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6911
#
# Epoch 00030: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6932
#
# Epoch 00031: CRPS_score_val did not improve from 0.01284
# Epoch 32/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6831
#
# Epoch 00032: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6819
#
# Epoch 00033: CRPS_score_val did not improve from 0.01283
# Epoch 34/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6778
#
# Epoch 00034: CRPS_score_val did not improve from 0.01283
# Epoch 35/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6803
#
# Epoch 00035: CRPS_score_val did not improve from 0.01283
# Epoch 36/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6768
#
# Epoch 00036: CRPS_score_val did not improve from 0.01283
# Epoch 37/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6729
#
# Epoch 00037: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6716
#
# Epoch 00038: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 39/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6717
#
# Epoch 00039: CRPS_score_val improved from 0.01282 to 0.01280, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6628
#
# Epoch 00040: CRPS_score_val did not improve from 0.01280
# Epoch 41/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6568
#
# Epoch 00041: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6607
#
# Epoch 00042: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6579
#
# Epoch 00043: CRPS_score_val did not improve from 0.01278
# Epoch 44/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6509
#
# Epoch 00044: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6551
#
# Epoch 00045: CRPS_score_val did not improve from 0.01277
# Epoch 46/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6506
#
# Epoch 00046: CRPS_score_val did not improve from 0.01277
# Epoch 47/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6502
#
# Epoch 00047: CRPS_score_val did not improve from 0.01277
# Epoch 48/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6420
#
# Epoch 00048: CRPS_score_val did not improve from 0.01277
# Epoch 49/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6506
#
# Epoch 00049: CRPS_score_val did not improve from 0.01277
# Epoch 50/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.6409
#
# Epoch 00050: CRPS_score_val did not improve from 0.01277
# Epoch 51/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6400
#
# Epoch 00051: CRPS_score_val did not improve from 0.01277
# Epoch 52/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6349
#
# Epoch 00052: CRPS_score_val did not improve from 0.01277
# Epoch 53/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6402
#
# Epoch 00053: CRPS_score_val did not improve from 0.01277
# Epoch 54/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6327
# Restoring model weights from the end of the best epoch
#
# Epoch 00054: CRPS_score_val did not improve from 0.01277
# Epoch 00054: early stopping
# the 2 fold crps is 0.012775
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 131us/step - loss: 5.5823
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08212, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 5.0798
#
# Epoch 00002: CRPS_score_val improved from 0.08212 to 0.07810, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 4.6616
#
# Epoch 00003: CRPS_score_val improved from 0.07810 to 0.06502, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 4.2599
#
# Epoch 00004: CRPS_score_val improved from 0.06502 to 0.04463, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 3.8960
#
# Epoch 00005: CRPS_score_val improved from 0.04463 to 0.02789, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 3.5607
#
# Epoch 00006: CRPS_score_val improved from 0.02789 to 0.01921, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 3.3035
#
# Epoch 00007: CRPS_score_val improved from 0.01921 to 0.01553, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 3.1199
#
# Epoch 00008: CRPS_score_val improved from 0.01553 to 0.01406, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 3.0114
#
# Epoch 00009: CRPS_score_val improved from 0.01406 to 0.01346, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.9441
#
# Epoch 00010: CRPS_score_val improved from 0.01346 to 0.01327, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.8861
#
# Epoch 00011: CRPS_score_val improved from 0.01327 to 0.01316, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.8625
#
# Epoch 00012: CRPS_score_val improved from 0.01316 to 0.01309, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.8368
#
# Epoch 00013: CRPS_score_val improved from 0.01309 to 0.01304, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.8199
#
# Epoch 00014: CRPS_score_val improved from 0.01304 to 0.01301, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.8093
#
# Epoch 00015: CRPS_score_val improved from 0.01301 to 0.01297, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7961
#
# Epoch 00016: CRPS_score_val improved from 0.01297 to 0.01295, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7713
#
# Epoch 00017: CRPS_score_val improved from 0.01295 to 0.01290, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.7657
#
# Epoch 00018: CRPS_score_val improved from 0.01290 to 0.01286, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7568
#
# Epoch 00019: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.7440
#
# Epoch 00020: CRPS_score_val improved from 0.01286 to 0.01284, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7353
#
# Epoch 00021: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7357
#
# Epoch 00022: CRPS_score_val improved from 0.01283 to 0.01281, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7309
#
# Epoch 00023: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7245
#
# Epoch 00024: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7122
#
# Epoch 00025: CRPS_score_val did not improve from 0.01279
# Epoch 26/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7149
#
# Epoch 00026: CRPS_score_val improved from 0.01279 to 0.01277, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7164
#
# Epoch 00027: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7107
#
# Epoch 00028: CRPS_score_val improved from 0.01276 to 0.01276, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7041
#
# Epoch 00029: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6966
#
# Epoch 00030: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6987
#
# Epoch 00031: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6958
#
# Epoch 00032: CRPS_score_val did not improve from 0.01273
# Epoch 33/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6935
#
# Epoch 00033: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6839
#
# Epoch 00034: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6868
#
# Epoch 00035: CRPS_score_val did not improve from 0.01272
# Epoch 36/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6810
#
# Epoch 00036: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6798
#
# Epoch 00037: CRPS_score_val did not improve from 0.01272
# Epoch 38/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6766
#
# Epoch 00038: CRPS_score_val did not improve from 0.01272
# Epoch 39/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6788
#
# Epoch 00039: CRPS_score_val did not improve from 0.01272
# Epoch 40/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6718
#
# Epoch 00040: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6709
#
# Epoch 00041: CRPS_score_val did not improve from 0.01271
# Epoch 42/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6652
#
# Epoch 00042: CRPS_score_val did not improve from 0.01271
# Epoch 43/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6638
#
# Epoch 00043: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6641
#
# Epoch 00044: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6569
#
# Epoch 00045: CRPS_score_val did not improve from 0.01269
# Epoch 46/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6582
#
# Epoch 00046: CRPS_score_val did not improve from 0.01269
# Epoch 47/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6540
#
# Epoch 00047: CRPS_score_val did not improve from 0.01269
# Epoch 48/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6562
#
# Epoch 00048: CRPS_score_val did not improve from 0.01269
# Epoch 49/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6476
#
# Epoch 00049: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6515
#
# Epoch 00050: CRPS_score_val did not improve from 0.01268
# Epoch 51/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6507
#
# Epoch 00051: CRPS_score_val did not improve from 0.01268
# Epoch 52/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6437
#
# Epoch 00052: CRPS_score_val did not improve from 0.01268
# Epoch 53/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6471
#
# Epoch 00053: CRPS_score_val did not improve from 0.01268
# Epoch 54/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6396
#
# Epoch 00054: CRPS_score_val did not improve from 0.01268
# Epoch 55/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6382
#
# Epoch 00055: CRPS_score_val did not improve from 0.01268
# Epoch 56/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6381
#
# Epoch 00056: CRPS_score_val did not improve from 0.01268
# Epoch 57/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6311
#
# Epoch 00057: CRPS_score_val did not improve from 0.01268
# Epoch 58/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6331
#
# Epoch 00058: CRPS_score_val did not improve from 0.01268
# Epoch 59/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6316
# Restoring model weights from the end of the best epoch
#
# Epoch 00059: CRPS_score_val did not improve from 0.01268
# Epoch 00059: early stopping
# the 3 fold crps is 0.012683
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 135us/step - loss: 5.6011
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08228, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 5.0822
#
# Epoch 00002: CRPS_score_val improved from 0.08228 to 0.07731, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 4.6644
#
# Epoch 00003: CRPS_score_val improved from 0.07731 to 0.06395, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 4.2496
#
# Epoch 00004: CRPS_score_val improved from 0.06395 to 0.04375, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 3.9054
#
# Epoch 00005: CRPS_score_val improved from 0.04375 to 0.02721, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 3.5804
#
# Epoch 00006: CRPS_score_val improved from 0.02721 to 0.01904, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 3.3164
#
# Epoch 00007: CRPS_score_val improved from 0.01904 to 0.01518, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 3.1379
#
# Epoch 00008: CRPS_score_val improved from 0.01518 to 0.01390, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 3.0238
#
# Epoch 00009: CRPS_score_val improved from 0.01390 to 0.01344, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.9439
#
# Epoch 00010: CRPS_score_val improved from 0.01344 to 0.01323, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.9032
#
# Epoch 00011: CRPS_score_val improved from 0.01323 to 0.01313, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.8668
#
# Epoch 00012: CRPS_score_val improved from 0.01313 to 0.01301, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.8386
#
# Epoch 00013: CRPS_score_val improved from 0.01301 to 0.01295, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.8172
#
# Epoch 00014: CRPS_score_val improved from 0.01295 to 0.01293, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.8020
#
# Epoch 00015: CRPS_score_val improved from 0.01293 to 0.01288, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7831
#
# Epoch 00016: CRPS_score_val improved from 0.01288 to 0.01286, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7691
#
# Epoch 00017: CRPS_score_val improved from 0.01286 to 0.01282, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7693
#
# Epoch 00018: CRPS_score_val improved from 0.01282 to 0.01280, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7566
#
# Epoch 00019: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7400
#
# Epoch 00020: CRPS_score_val improved from 0.01278 to 0.01276, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7419
#
# Epoch 00021: CRPS_score_val improved from 0.01276 to 0.01274, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7320
#
# Epoch 00022: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.7309
#
# Epoch 00023: CRPS_score_val did not improve from 0.01273
# Epoch 24/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7244
#
# Epoch 00024: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7187
#
# Epoch 00025: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7125
#
# Epoch 00026: CRPS_score_val did not improve from 0.01271
# Epoch 27/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7107
#
# Epoch 00027: CRPS_score_val did not improve from 0.01271
# Epoch 28/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7059
#
# Epoch 00028: CRPS_score_val improved from 0.01271 to 0.01269, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7041
#
# Epoch 00029: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7027
#
# Epoch 00030: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6966
#
# Epoch 00031: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6863
#
# Epoch 00032: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6924
#
# Epoch 00033: CRPS_score_val did not improve from 0.01267
# Epoch 34/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6884
#
# Epoch 00034: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6809
#
# Epoch 00035: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6856
#
# Epoch 00036: CRPS_score_val did not improve from 0.01265
# Epoch 37/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6789
#
# Epoch 00037: CRPS_score_val did not improve from 0.01265
# Epoch 38/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6779
#
# Epoch 00038: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# Epoch 39/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6719
#
# Epoch 00039: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6748
#
# Epoch 00040: CRPS_score_val did not improve from 0.01264
# Epoch 41/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6658
#
# Epoch 00041: CRPS_score_val did not improve from 0.01264
# Epoch 42/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6732
#
# Epoch 00042: CRPS_score_val did not improve from 0.01264
# Epoch 43/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6666
#
# Epoch 00043: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6640
#
# Epoch 00044: CRPS_score_val did not improve from 0.01264
# Epoch 45/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6601
#
# Epoch 00045: CRPS_score_val improved from 0.01264 to 0.01263, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6568
#
# Epoch 00046: CRPS_score_val did not improve from 0.01263
# Epoch 47/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6584
#
# Epoch 00047: CRPS_score_val did not improve from 0.01263
# Epoch 48/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6580
#
# Epoch 00048: CRPS_score_val improved from 0.01263 to 0.01262, saving model to best_model.h5
# Epoch 49/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6544
#
# Epoch 00049: CRPS_score_val improved from 0.01262 to 0.01262, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6454
#
# Epoch 00050: CRPS_score_val did not improve from 0.01262
# Epoch 51/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6394
#
# Epoch 00051: CRPS_score_val improved from 0.01262 to 0.01262, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.6416
#
# Epoch 00052: CRPS_score_val did not improve from 0.01262
# Epoch 53/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6433
#
# Epoch 00053: CRPS_score_val did not improve from 0.01262
# Epoch 54/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6386
#
# Epoch 00054: CRPS_score_val improved from 0.01262 to 0.01261, saving model to best_model.h5
# Epoch 55/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.6379
#
# Epoch 00055: CRPS_score_val did not improve from 0.01261
# Epoch 56/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6358
#
# Epoch 00056: CRPS_score_val did not improve from 0.01261
# Epoch 57/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6334
#
# Epoch 00057: CRPS_score_val did not improve from 0.01261
# Epoch 58/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6323
#
# Epoch 00058: CRPS_score_val did not improve from 0.01261
# Epoch 59/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6322
#
# Epoch 00059: CRPS_score_val did not improve from 0.01261
# Epoch 60/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6337
#
# Epoch 00060: CRPS_score_val improved from 0.01261 to 0.01261, saving model to best_model.h5
# Epoch 61/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6217
#
# Epoch 00061: CRPS_score_val did not improve from 0.01261
# Epoch 62/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6257
#
# Epoch 00062: CRPS_score_val did not improve from 0.01261
# Epoch 63/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6214
#
# Epoch 00063: CRPS_score_val did not improve from 0.01261
# Epoch 64/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6197
#
# Epoch 00064: CRPS_score_val did not improve from 0.01261
# Epoch 65/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6156
#
# Epoch 00065: CRPS_score_val did not improve from 0.01261
# Epoch 66/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6125
#
# Epoch 00066: CRPS_score_val improved from 0.01261 to 0.01261, saving model to best_model.h5
# Epoch 67/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.6090
#
# Epoch 00067: CRPS_score_val did not improve from 0.01261
# Epoch 68/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6093
#
# Epoch 00068: CRPS_score_val did not improve from 0.01261
# Epoch 69/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6092
#
# Epoch 00069: CRPS_score_val did not improve from 0.01261
# Epoch 70/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6071
#
# Epoch 00070: CRPS_score_val did not improve from 0.01261
# Epoch 71/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.5993
#
# Epoch 00071: CRPS_score_val did not improve from 0.01261
# Epoch 72/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.5983
#
# Epoch 00072: CRPS_score_val improved from 0.01261 to 0.01260, saving model to best_model.h5
# Epoch 73/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6009
#
# Epoch 00073: CRPS_score_val did not improve from 0.01260
# Epoch 74/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.5946
#
# Epoch 00074: CRPS_score_val did not improve from 0.01260
# Epoch 75/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.5915
#
# Epoch 00075: CRPS_score_val did not improve from 0.01260
# Epoch 76/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.5936
#
# Epoch 00076: CRPS_score_val did not improve from 0.01260
# Epoch 77/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.5878
#
# Epoch 00077: CRPS_score_val did not improve from 0.01260
# Epoch 78/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.5842
#
# Epoch 00078: CRPS_score_val did not improve from 0.01260
# Epoch 79/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.5848
#
# Epoch 00079: CRPS_score_val did not improve from 0.01260
# Epoch 80/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.5802
#
# Epoch 00080: CRPS_score_val did not improve from 0.01260
# Epoch 81/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.5774
#
# Epoch 00081: CRPS_score_val did not improve from 0.01260
# Epoch 82/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.5771
# Restoring model weights from the end of the best epoch
#
# Epoch 00082: CRPS_score_val did not improve from 0.01260
# Epoch 00082: early stopping
# the 4 fold crps is 0.012605
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 144us/step - loss: 5.5993
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08260, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 5.1007
#
# Epoch 00002: CRPS_score_val improved from 0.08260 to 0.07804, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 4.6804
#
# Epoch 00003: CRPS_score_val improved from 0.07804 to 0.06475, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 4.3035
#
# Epoch 00004: CRPS_score_val improved from 0.06475 to 0.04455, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 3.9307
#
# Epoch 00005: CRPS_score_val improved from 0.04455 to 0.02809, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 3.5875
#
# Epoch 00006: CRPS_score_val improved from 0.02809 to 0.01978, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 3.3419
#
# Epoch 00007: CRPS_score_val improved from 0.01978 to 0.01617, saving model to best_model.h5
# Epoch 8/100
# ...
# Epoch 49/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6468
#
# Epoch 00049: CRPS_score_val did not improve from 0.01335
# Epoch 50/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6459
#
# Epoch 00050: CRPS_score_val did not improve from 0.01335
# Epoch 51/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6441
#
# Epoch 00051: CRPS_score_val improved from 0.01335 to 0.01334, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6398
#
# Epoch 00052: CRPS_score_val did not improve from 0.01334
# Epoch 53/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6368
#
# Epoch 00053: CRPS_score_val did not improve from 0.01334
# Epoch 54/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6327
#
# Epoch 00054: CRPS_score_val did not improve from 0.01334
# Epoch 55/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6306
#
# Epoch 00055: CRPS_score_val did not improve from 0.01334
# Epoch 56/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6320
#
# Epoch 00056: CRPS_score_val did not improve from 0.01334
# Epoch 57/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6341
#
# Epoch 00057: CRPS_score_val did not improve from 0.01334
# Epoch 58/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6319
#
# Epoch 00058: CRPS_score_val improved from 0.01334 to 0.01333, saving model to best_model.h5
# Epoch 59/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6277
#
# Epoch 00059: CRPS_score_val did not improve from 0.01333
# Epoch 60/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6256
#
# Epoch 00060: CRPS_score_val did not improve from 0.01333
# Epoch 61/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6238
#
# Epoch 00061: CRPS_score_val did not improve from 0.01333
# Epoch 62/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6180
#
# Epoch 00062: CRPS_score_val improved from 0.01333 to 0.01333, saving model to best_model.h5
# Epoch 63/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6157
#
# Epoch 00063: CRPS_score_val did not improve from 0.01333
# Epoch 64/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6097
#
# Epoch 00064: CRPS_score_val did not improve from 0.01333
# Epoch 65/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6182
#
# Epoch 00065: CRPS_score_val did not improve from 0.01333
# Epoch 66/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6130
#
# Epoch 00066: CRPS_score_val did not improve from 0.01333
# Epoch 67/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6090
#
# Epoch 00067: CRPS_score_val did not improve from 0.01333
# Epoch 68/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6095
#
# Epoch 00068: CRPS_score_val did not improve from 0.01333
# Epoch 69/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.5951
#
# Epoch 00069: CRPS_score_val did not improve from 0.01333
# Epoch 70/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.5996
#
# Epoch 00070: CRPS_score_val did not improve from 0.01333
# Epoch 71/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6006
#
# Epoch 00071: CRPS_score_val did not improve from 0.01333
# Epoch 72/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6005
# Restoring model weights from the end of the best epoch
#
# Epoch 00072: CRPS_score_val did not improve from 0.01333
# Epoch 00072: early stopping
# the 4 fold crps is 0.013333
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 174us/step - loss: 5.5753
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08213, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 5.0734
#
# Epoch 00002: CRPS_score_val improved from 0.08213 to 0.07809, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 4.6582
#
# Epoch 00003: CRPS_score_val improved from 0.07809 to 0.06561, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 4.2785
#
# Epoch 00004: CRPS_score_val improved from 0.06561 to 0.04685, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 3.9232
#
# Epoch 00005: CRPS_score_val improved from 0.04685 to 0.02928, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.5691
#
# Epoch 00006: CRPS_score_val improved from 0.02928 to 0.01993, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 3.3113
#
# Epoch 00007: CRPS_score_val improved from 0.01993 to 0.01594, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 3.1337
#
# Epoch 00008: CRPS_score_val improved from 0.01594 to 0.01413, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 3.0122
#
# Epoch 00009: CRPS_score_val improved from 0.01413 to 0.01354, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.9440
#
# Epoch 00010: CRPS_score_val improved from 0.01354 to 0.01333, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8864
#
# Epoch 00011: CRPS_score_val improved from 0.01333 to 0.01319, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.8636
#
# Epoch 00012: CRPS_score_val improved from 0.01319 to 0.01308, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8304
#
# Epoch 00013: CRPS_score_val improved from 0.01308 to 0.01305, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.8167
#
# Epoch 00014: CRPS_score_val improved from 0.01305 to 0.01301, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7992
#
# Epoch 00015: CRPS_score_val improved from 0.01301 to 0.01298, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7849
#
# Epoch 00016: CRPS_score_val improved from 0.01298 to 0.01293, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7750
#
# Epoch 00017: CRPS_score_val improved from 0.01293 to 0.01290, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7699
#
# Epoch 00018: CRPS_score_val improved from 0.01290 to 0.01288, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7567
#
# Epoch 00019: CRPS_score_val improved from 0.01288 to 0.01286, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7446
#
# Epoch 00020: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7485
#
# Epoch 00021: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.7351
#
# Epoch 00022: CRPS_score_val improved from 0.01283 to 0.01281, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7253
#
# Epoch 00023: CRPS_score_val improved from 0.01281 to 0.01278, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7309
#
# Epoch 00024: CRPS_score_val did not improve from 0.01278
# Epoch 25/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7206
#
# Epoch 00025: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7168
#
# Epoch 00026: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7087
#
# Epoch 00027: CRPS_score_val improved from 0.01277 to 0.01275, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7078
#
# Epoch 00028: CRPS_score_val improved from 0.01275 to 0.01275, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7027
#
# Epoch 00029: CRPS_score_val improved from 0.01275 to 0.01272, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6993
#
# Epoch 00030: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6968
#
# Epoch 00031: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6971
#
# Epoch 00032: CRPS_score_val did not improve from 0.01270
# Epoch 33/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6857
#
# Epoch 00033: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6875
#
# Epoch 00034: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6823
#
# Epoch 00035: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6848
#
# Epoch 00036: CRPS_score_val did not improve from 0.01269
# Epoch 37/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6799
#
# Epoch 00037: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6766
#
# Epoch 00038: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 39/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6741
#
# Epoch 00039: CRPS_score_val did not improve from 0.01267
# Epoch 40/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6734
#
# Epoch 00040: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6656
#
# Epoch 00041: CRPS_score_val did not improve from 0.01267
# Epoch 42/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6696
#
# Epoch 00042: CRPS_score_val did not improve from 0.01267
# Epoch 43/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6633
#
# Epoch 00043: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6577
#
# Epoch 00044: CRPS_score_val did not improve from 0.01267
# Epoch 45/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6589
#
# Epoch 00045: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6560
#
# Epoch 00046: CRPS_score_val did not improve from 0.01266
# Epoch 47/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6549
#
# Epoch 00047: CRPS_score_val did not improve from 0.01266
# Epoch 48/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6506
#
# Epoch 00048: CRPS_score_val did not improve from 0.01266
# Epoch 49/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6518
#
# Epoch 00049: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6437
#
# Epoch 00050: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 51/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6477
#
# Epoch 00051: CRPS_score_val did not improve from 0.01265
# Epoch 52/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6470
#
# Epoch 00052: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# Epoch 53/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6444
#
# Epoch 00053: CRPS_score_val did not improve from 0.01264
# Epoch 54/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6354
#
# Epoch 00054: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 55/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6344
#
# Epoch 00055: CRPS_score_val did not improve from 0.01264
# Epoch 56/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6338
#
# Epoch 00056: CRPS_score_val did not improve from 0.01264
# Epoch 57/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6348
#
# Epoch 00057: CRPS_score_val improved from 0.01264 to 0.01263, saving model to best_model.h5
# Epoch 58/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6333
#
# Epoch 00058: CRPS_score_val did not improve from 0.01263
# Epoch 59/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6283
#
# Epoch 00059: CRPS_score_val did not improve from 0.01263
# Epoch 60/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6302
#
# Epoch 00060: CRPS_score_val did not improve from 0.01263
# Epoch 61/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6250
#
# Epoch 00061: CRPS_score_val did not improve from 0.01263
# Epoch 62/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6207
#
# Epoch 00062: CRPS_score_val improved from 0.01263 to 0.01262, saving model to best_model.h5
# Epoch 63/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6223
#
# Epoch 00063: CRPS_score_val did not improve from 0.01262
# Epoch 64/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6117
#
# Epoch 00064: CRPS_score_val did not improve from 0.01262
# Epoch 65/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6161
#
# Epoch 00065: CRPS_score_val did not improve from 0.01262
# Epoch 66/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6111
#
# Epoch 00066: CRPS_score_val did not improve from 0.01262
# Epoch 67/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6076
#
# Epoch 00067: CRPS_score_val did not improve from 0.01262
# Epoch 68/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6110
#
# Epoch 00068: CRPS_score_val did not improve from 0.01262
# Epoch 69/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6008
#
# Epoch 00069: CRPS_score_val did not improve from 0.01262
# Epoch 70/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.5995
#
# Epoch 00070: CRPS_score_val did not improve from 0.01262
# Epoch 71/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6004
#
# Epoch 00071: CRPS_score_val did not improve from 0.01262
# Epoch 72/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.5972
# Restoring model weights from the end of the best epoch
#
# Epoch 00072: CRPS_score_val did not improve from 0.01262
# Epoch 00072: early stopping
# the 5 fold crps is 0.012617
# mean crps is 0.012771

# %%
print("mean crps is %f"%np.mean(crps_csv))
# Out:
# mean crps is 0.012771

# %% [markdown]
# # Time for the actual submission

# %%
# %%time

from kaggle.competitions import nflrush
env = nflrush.make_env()
iter_test = env.iter_test()

for (test_df, sample_prediction_df) in iter_test:
    basetable = create_features(test_df, deploy=True)
    basetable.drop(['GameId','PlayId'], axis=1, inplace=True)
    scaled_basetable = scaler.transform(basetable)

    y_pred = predict(scaled_basetable)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1).tolist()[0]

    preds_df = pd.DataFrame(data=[y_pred], columns=sample_prediction_df.columns)
    env.predict(preds_df)

env.write_submission_file()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.
# CPU times: user 15min 12s, sys: 24.1 s, total: 15min 36s
# Wall time: 14min 39s
